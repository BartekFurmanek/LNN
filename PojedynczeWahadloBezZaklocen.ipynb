# %%
#imports
import math
import jax
import jax.numpy as jnp
from jax.experimental.ode import odeint
import numpy as np
from functools import partial
import matplotlib.pyplot as plt
from jax.example_libraries import stax
from jax.example_libraries import optimizers
import random as rd
import pickle
import os

# %%
#METODA AUTOGRAD

#Definicja Lagrangianu dla pojedynńczego wachadła liczonego w sposób analityczny
#Argumenty funkcji:
#  -q   - położenie ciała
#  -q_t - prędkość ciała
#  -m   - masa ciała
#  -l   - długość liny
#  -g   - wartość przyśpieszenia ziemskiego
#Zwracane: wartość Lagrangianu w danym momencie.
def lagrangian_analitical(q, q_t, m, l, g):
    #Eneriga kinetyczna
    Ek=0.5*m*l*jnp.square(q_t)
    
    #Energia potencjalna
    Ep=m*g*(l-l*jnp.cos(q))
    
    #Lagrangian
    return jnp.sum(Ek - Ep)

#Obliczenie energi potencjalnej i kinetycznej układu na podstawie aktualnego stanu
#Argumenty funkcji:
#  -q   - położenie ciała
#  -q_t - prędkość ciała
#  -m   - masa ciała
#  -l   - długość liny
#  -g   - wartość przyśpieszenia ziemskiego
#Zwracane: 
#  -Ek  - Energia kinetyczna
#  -Ep  - Energia potencjalna
def compute_energy(q, q_t, m, l, g):
    #Eneriga kinetyczna
    Ek=0.5*m*l*jnp.square(q_t)
    
    #Energia potencjalna
    Ep=m*g*(l-l*jnp.cos(q))
    
    #Lagrangian
    return Ek, Ep

#Funkcja ma za zadanie reprezenotwanie równania różniczkowego, wynikającego z rozwiązania
#równanie Eulera-Lagrange'a
#Argumenty funkcji:
#   -lagrangian - Funkcja opisująca Lagrangian. Funkcja musi być typu ,,callable'' żeby,
#                 pochodne Lagrangianu zostały policzone.
#   -state      - Wektor zawierający wartości początkowe położenia i prędkości
#   -empty      - Aby ta funkcja mogła zostać poprawnie wywoływana w dalszej części programu
#                 koniecznym było dodanie ,,pustego'' argumentu, które nie będzie pełnił żadnej
#                 funkcji, ale pozwoli na poprawną kompilację
#Zwracane: Wektor zawiercający przyśpieszenia oraz prędkości w danym momencie.
def equation_of_motion(lagrangian, state, empty=None):
    #Rozdzilenie danych startowych na położenia i prędkości
    q, q_t = jnp.split(state, 2)
    #Obliczanie przyśpieszenia na podstawie lagrangianu
    q_tt = jax.numpy.linalg.pinv(jax.hessian(lagrangian, 1)(q, q_t)) @ (
		jax.grad(lagrangian, 0)(q, q_t)
		- jax.jacfwd(jax.grad(lagrangian, 1), 0)(q, q_t) @ q_t)
    return jnp.concatenate([q_t, q_tt])

#Funkcja wyznaczająca trajektorię ruchu przy użyciu Lagrangianu wyznaczonego
#w sposób analityczny
#Argumenty funkcji:
#   -initial_state - Początkowego położenie oraz prędkości
#   -times         - Czas wyznaczanej trajektori
#   -m             - masa wachadła
#   -l             - długość liny wachadła
#   -g             - przyśpieszenie ziemskie
#Zwraca:
#   Wektor trajektori ruchu w zależności od czasu
@partial(jax.jit, backend='cpu')
def solve_autograd(initial_state, times, m=1, l=1, g=9.8):
  lagrangian = partial(lagrangian_analitical, m=m, l=l, g=g)
  equation = partial(equation_of_motion, lagrangian)
  return odeint(equation, initial_state, times, rtol=1e-10, atol=1e-10)

# %%
#METODA ANALICTYCZNA

#Funkcja obliczająca przyśpieszenie wahadła na podstawie aktualnego położenia i prędkości.
#Argumenty funkcji:
#   -initial_state - Początkowego położenie oraz prędkości
#   -empty         - Aby ta funkcja mogła zostać poprawnie wywoływana w dalszej części programu
#                   koniecznym było dodanie ,,pustego'' argumentu, które nie będzie pełnił żadnej
#                   funkcji, ale pozwoli na poprawną kompilację
#   -l             - długość liny wachadła
#   -g             - przyśpieszenie ziemskie
#Zwraca:
#   Wektor trajektori ruchu w zależności od czasu
def analitical(initial_state, empty=None, l=1, g=9.8):
    q = initial_state[0]
    q_t = initial_state[1]
    q_tt = -g / l * jnp.sin(q)
    return jnp.concatenate((jnp.expand_dims(q_t, axis=0), jnp.expand_dims(q_tt, axis=0)), axis=0)

#Funkcja wyznaczająca trajektorię ruchu obliczoną przy użyciu analitycznie wyznaczonego 
# równiania różniczkowego (funkcja analitical)
#Argumenty funkcji:
#   -initial_state - Początkowego położenie oraz prędkości
#   -times         - Czas wyznaczanej trajektori
#   -l             - długość liny wachadła
#   -g             - przyśpieszenie ziemskie
#Zwraca:
#   Wektor trajektori ruchu w zależności od czasu
@partial(jax.jit, backend='cpu')
def solve_analitical(initial_state, times, l=1, g=9.8):
    function = partial(analitical, l=l, g=g)
    return odeint(function, initial_state, t=times, rtol=1e-10, atol=1e-10)

# %%
#WYZNACZENIE PUNKTU STARTOWEGO, SZUMU, ORAZ CZASU DLA TESTU POWYŻSZYCH METOD WYZNACZANIA TRAJEKTORI

#Punkt startowy
x0 = jnp.array([0.5,0.2], dtype=np.float32)
#Szum
noise = np.random.RandomState(0).randn(x0.size)
#Wektor czasów
t = np.linspace(0, 40, num=401, dtype=np.float32)

# %%
#WYZNACZENIE TRAJEKTORI METODĄ AUTOGRAD ORAZ ANALITYCZNĄ

#Autograd
# %time autograd_clean = jax.device_get(solve_autograd(x0, t))
#Autograd z małym szumem
# %time autograd_noise1 = jax.device_get(solve_autograd(x0 + 1e-10*noise, t))
#Autograd z dużym szumem
# %time autograd_noise2 = jax.device_get(solve_autograd(x0 + 1e-2*noise, t))

#Analitycznie
# %time analitical_clean = jax.device_get(solve_analitical(x0, t))
#Analitycznie z małym szumem
# %time analitical_noise1 = jax.device_get(solve_analitical(x0 + 1e-10*noise, t))
#Analitycznie z dużym szumem
# %time analitical_noise2 = jax.device_get(solve_analitical(x0 + 1e-2*noise, t))
# Out:
# CPU times: user 560 ms, sys: 10.2 ms, total: 571 ms
# Wall time: 562 ms
# CPU times: user 1.46 ms, sys: 35 µs, total: 1.49 ms
# Wall time: 1.43 ms
# CPU times: user 1.13 ms, sys: 27 µs, total: 1.16 ms
# Wall time: 1.17 ms
# CPU times: user 387 ms, sys: 0 ns, total: 387 ms
# Wall time: 397 ms
# CPU times: user 1.34 ms, sys: 0 ns, total: 1.34 ms
# Wall time: 1.33 ms
# CPU times: user 1.15 ms, sys: 0 ns, total: 1.15 ms
# Wall time: 1.16 ms

# %%
#WYŚWIETLENIE TRAJEKTORI (AUTOGRAD)

fig, axes = plt.subplots(1, 2, figsize=(10, 5), dpi=120)

fig.suptitle("Wpływ zakłóceń na trajektorie ruchu wyznaczoną przy użyciu funkcji autograd")

#Położenie (kąt)
axes[0].plot(t, autograd_clean[:, 0], 'r', label='noise=0')
axes[0].plot(t, autograd_noise1[:, 0], 'g--', label='noise=1e-10')
axes[0].plot(t, autograd_noise2[:, 0], 'b.', label='noise=1e-2')
axes[0].set_xlabel('t')
axes[0].set_ylabel('$q$')
axes[0].legend()
axes[0].grid()

#Prędkość (kątowa)
axes[1].plot(t, autograd_clean[:, 1], 'r', label='noise=0')
axes[1].plot(t, autograd_noise1[:, 1], 'g--', label='noise=1e-10')
axes[1].plot(t, autograd_noise2[:, 1], 'b.', label='noise=1e-2')
axes[1].set_xlabel('t')
axes[1].set_ylabel('$\dot q$')
axes[1].legend()
axes[1].grid()

plt.tight_layout()

# %%
#WYŚWIETLENIE TRAJEKTORI (METODA ANALITYCZNA)

fig, axes = plt.subplots(1, 2, figsize=(10, 5), dpi=120)
fig.suptitle('Wpływ zakłóceń na trajektorie ruchu wyznaczoną przy użyciu rozwiązania analitycznego')

#Położenie (kąt)
axes[0].plot(t, analitical_clean[:, 0], 'r', label='noise=0')
axes[0].plot(t, analitical_noise1[:, 0], 'g--', label='noise=1e-10')
axes[0].plot(t, analitical_noise2[:, 0], 'b.', label='noise=1e-2')
axes[0].set_xlabel('t')
axes[0].set_ylabel('$q$')
axes[0].legend()
axes[0].grid()

#Prędkość (kątowa)
axes[1].plot(t, analitical_clean[:, 1], 'r', label='noise=0')
axes[1].plot(t, analitical_noise1[:, 1], 'g--', label='noise=1e-10')
axes[1].plot(t, analitical_noise2[:, 1], 'b.', label='noise=1e-2')
axes[1].set_xlabel('t')
axes[1].set_ylabel('$\dot q$')
axes[1].grid()

plt.tight_layout()

# %%
#PORÓWNANIE TRAJEKTORI OTRZYMANYCH PRZY UŻYCIU OBU METOD

fig, axes = plt.subplots(1, 2, figsize=(10, 5), dpi=120)
fig.suptitle('Porównanie trajektori ruchu otrzymanych metodą analityczną i metodą autograd')


#Położenie (kąt)
axes[0].plot(t, analitical_clean[:, 0], 'r', label='analityczne')
axes[0].plot(t, autograd_clean[:, 0], 'g--', label='autograd')
axes[0].set_xlabel('t')
axes[0].set_ylabel('$q$')
axes[0].legend()
axes[0].grid()

#Prędkość (kątowa)
axes[1].plot(t, analitical_clean[:, 1], 'r', label='analityczne')
axes[1].plot(t, autograd_clean[:, 1], 'g--', label='autograd')
axes[1].set_xlabel('t')
axes[1].set_ylabel('$\dot q$')
axes[1].grid()


plt.tight_layout()

# %%
#Funkcja normalizująca wektor stanu (położenie i prędkość). W przypadku położenia wartości 
#normalizowane są do zakresów <-Pi;Pi>. W przypadku prędkości wartości pozostają bez zmian.
#Argumenty:
#   state - wektor stanu [położenie, prędkość].
#Zwraca:
#   Unormowany wektor stanu.
def normalize(state):
    dim = int(len(state)/2)
    return jnp.concatenate([(state[:dim] + np.pi) % (2 * np.pi) - np.pi, state[dim:]])

# %%
#BUDOWA ZBIORU UCZĄCEGO NA PODSTAWIE TRAJEKTORI WACHADŁA
N=1000

#Wektor punktów początkowych (3 warianty do testu)
x0 = jnp.array([[0.1,0.1], [0.5,0.2], [0.3, 0.3]], dtype=np.float32)

#Wektor czasów dla zbioru uczącego
t_train = np.arange(0,N, dtype=np.float32)
#Wektor czasów dla zbioru testowego
t_test = np.arange(N,2*N, dtype=np.float32)


fig, axes = plt.subplots(1, 2, figsize=(6, 3), dpi=120)

#Wyznaczenie 3 różnych zbiorów uczących na podstawie trajektori
#o różnych punktach startowych.
for i in range(x0.shape[0]):

    #Zbiór uczący
    x_train = jax.device_get(solve_analitical(x0[i], t_train))  #Dane wejściowe zbudowane na podstawie trajektori
    x_train = jax.device_get(jax.vmap(normalize)(x_train))      #Normalizacja danych wejściowych
    y_train = jax.device_get(jax.vmap(analitical)(x_train))     #Wyznaczenie danych wyjściowych (przyśpieszenie dla danych wektorów stanu [położenie, prędkość])

    #Zbiór testowy
    x_test = jax.device_get(solve_analitical(x_train[-1], t_train)) #Dane wejściowe zbudowane na podstawie trajektori
    x_test = jax.device_get(jax.vmap(normalize)(x_test))            #Normalizacja danych wejściowych
    y_test = jax.device_get(jax.vmap(analitical)(x_test))           #Wyznaczenie danych wyjściowych (przyśpieszenie dla danych wektorów stanu [położenie, prędkość])

    #Wyświetlenie wartość wejściowych na wykresie
    axes[0].scatter(x_train[:, 0], x_train[:, 1], s=6, alpha=1)
    axes[1].scatter(x_test[:, 0], x_test[:, 1], s=6, alpha=1)


#Wykres
fig.suptitle("Analiza punktów w zbiorach uczących i testowych")
axes[0].set_xlabel('q')
axes[0].set_ylabel('$\dot q$')
axes[0].set_title('Zbiór uczący')
axes[0].grid()
axes[1].set_xlabel('q')
axes[1].set_ylabel('$\dot q$')
axes[1].set_title('Zbiór testowy')
axes[1].grid()
fig.legend(['$q_0$=0.1, $\dot q_0$=0.1','$q_0$=0.5, $\dot q_0$=0.2', '$q_0$=0.3, $\dot q_0$=0.3'],fontsize="8", loc='lower center')
plt.tight_layout()

# %%
#BUDOWA ZBIORU UCZĄCEGO I TESTOWEGO NA PODSTAWIE WARTOŚCI LOSOWYCH

N=1000  #Liczność zbioru testowego i uczącego

#Maksymalne wartości prędkości w zbiorze
v_max=2*np.sqrt(9.81)

x_test_train = np.zeros([2*N, 2])
#Wyznaczenie losowych wartości położenia i prędkości 
x_test_train[:,0] = np.random.rand(N*2)*2*np.pi - np.pi  #Zakres wartości położenia <-Pi;Pi>
x_test_train[:,1] = np.random.rand(N*2)*2*v_max - v_max  #Zakres wartości <-Vmax;Vmax>
#Obliczenie wartości wyjściowych (przyśpieszenia) dla otrzymanych losowych punktów położenia i prędkości
#przy użyciu równania różniczkowego otrzymanego w sposób analityczny 
y_test_train = jax.device_get(jax.vmap(analitical)(x_test_train))

#Rozbicie zbioru na uczący i testowy
x_train = x_test_train[0:N]
y_train = y_test_train[0:N]

x_test = x_test_train[N:2*N]
y_test = y_test_train[N:2*N]

# %%
#WIZUALIZACJA ZBIORU DANYCH

fig, axes = plt.subplots(1, 2, figsize=(6, 3), dpi=120)
fig.suptitle("Analiza punktów w zbiorach uczących i testowych")
axes[0].scatter(x_train[:, 0], x_train[:, 1], s=6)
axes[0].set_xlabel('q')
axes[0].set_ylabel('$\dot q$')
axes[0].set_title('Zbiór uczący')
axes[0].grid()
axes[1].scatter(x_test[:, 0], x_test[:, 1], s=6)
axes[1].set_xlabel('q')
axes[1].set_ylabel('$\dot q$')
axes[1].set_title('Zbiór testowy')
axes[1].grid()
plt.tight_layout()

# %%
#ARCHITEKUTRA SIECI NEURONOWEJ
init_random_params, nn_forward_fn = stax.serial(
    stax.Dense(64),
    stax.Softplus,
    stax.Dense(64),
    stax.Softplus,
    stax.Dense(1),
)

#Funkcja modelująca lagrangian (wyjście sieci neuronowej)
#Argumenty:
#   params - parametry sieci neuronowej
#   q, q_t - wektor wartości wejściowych dla sieci (położenie, przyśpieszenie)
#Zwraca:
#   lagrangian - wartość lagrangianu dla danego wektora stanu
def learned_lagrangian(params):
  def lagrangian(q, q_t):
    assert q.shape == (1,)
    state = normalize(jnp.concatenate([q, q_t]))
    return jnp.squeeze(nn_forward_fn(params, state), axis=-1)
  return lagrangian

#Funkcja wyznaczająca trajektorię ruchu przy użyciu Lagrangianu zamodlowanego za pomocą sieci neuronowej
#Argumenty funkcji:
#   -params        - Parametry sieci neuronowej
#   -initial_state - Początkowego położenie oraz prędkości
#   -times         - Czas wyznaczanej trajektori
#Zwraca:
#   Wektor trajektori ruchu w zależności od czasu
@partial(jax.jit, backend='cpu')
def solve_lagrangian(params, initial_state, times):
  return odeint(partial(equation_of_motion, learned_lagrangian(params)),
                  initial_state, times, rtol=1e-10, atol=1e-10)
  
  
#Funkcja ma za zadanie obliczenie przyśpieszenia na podstawie aktualnego stanu
#(położenie i przyśpieszenie) przy użyciu lagrangianu zamodelowanego przez sieć LNN.
#Argumenty funkcji:
#   -params     - Parametry sieci.
#   -state      - Wektor zawierający wartości początkowe położenia i prędkości [q, q_t].
#Zwracane:  Przyśpieszenie wynikającego z aktulanego wektora stanu.  
def acceleration_learned(params, initial_state):
  acc = partial(equation_of_motion, learned_lagrangian(params))
  return acc(initial_state)[1]


#DEFINICJA BŁĘDU DLA SIECI
#Argumenty:
#   params  - parametry sieci neuronowej
#   state   - wektor stanu [położenie, prędkość]
#   target  - oczekiwany wektor wyjściowy sieci [prędkość, przyśpieszenie]
@partial(jax.jit, backend='cpu')
def MSE_loss(params, state, targets):
  preds = jax.vmap(partial(equation_of_motion, learned_lagrangian(params)))(state)
  return jnp.mean((preds[:,1] - targets[:,1]) ** 2)


#Funkcja zamieniająca losowe elementy 2 wektorów w ten sam sposób.
#Argumenty:
#   a, b - Wektory, które mają zostać przemieszane.
#Zawracane:
#   a, b - Przetasowane wektory.
def shuffle(a, b):
    assert len(a) == len(b)
    p = np.random.permutation(a.shape[0])
    return a[p], b[p]

# %%
# %%time
#UCZENIE SIECI NEURONOWEJ



Training=True      #Uczenie sieci
Epochs=2000       #Maksymalna liczba epok
StopError=0.01      #Wartość błędu MSE dla zbioru testowego, przy której uczenie zostanie szybciej zakończone
#!!!!WAZNE - STOP ERROR MAX 0.005, PONIZEJ PRZEUCZENIE
Learning_rate=1e-2  #Współczynnik uczenia
Batch_size= 64


train_error=[]      #Wektor błędów MSE dla zbioru uczącego
test_error=[]       ##Wektor błędów MSE dla zbioru testowego

#Wektory wag
w1=[]
w2=[]
w3=[]
w4=[]

#Ścieżka dla pliku przechowującego parametry sieci
config = {"ckpt_path": "Checkpoints"}

#Inicjalizacja parametrów sieci
rng = jax.random.PRNGKey(0)
output_shape, params_initial = init_random_params(rng, (-1, 2))

#Wybór optymalizotra sieci ADAM
init, update, get_params = optimizers.adam(step_size=Learning_rate)
update = jax.jit(update)
get_params = jax.jit(get_params)


#Wykonanie uczenia sieci
if(Training):

    best_error = float('inf')

    opt_state = init(params_initial)
    for i in range(Epochs):
        #Realizacja minibatcha
        x_train, y_train = shuffle(x_train, y_train)
        start=0
        while start < x_train.shape[0]:
            #Podział danych na batche
            end = start+Batch_size
            if end > x_train.shape[0]:
                end = x_train.shape[0]
            x_batch = x_train[start:end, :]
            y_batch = y_train[start:end, :]

            #Obliczenie błędu MSE i optymalizacja wag
            params = get_params(opt_state)
            grad = jax.grad(MSE_loss)(params, x_batch, y_batch)
            opt_state = update(i, grad, opt_state)

            start += Batch_size


        #Zapisanie błędu na podstawie zbioru uczącego i testowego w każdej epoce
        train_error.append(MSE_loss(params, x_train, y_train))
        test_error.append(MSE_loss(params, x_test, y_test))

        #Zapamiętywanie najlepszych parametrów sieci
        if test_error[-1]<best_error:
            best_error = test_error[-1]
            best_params = params

        #Zapisywanie pewnych wag
        w1.append(params[2][0][1][2])
        w2.append(params[0][1][2])
        w3.append(params[2][0][1][3])
        w4.append(params[0][1][1])

        #Wcześciejsze kończenie uczenia
        if test_error[-1]<=StopError:
            print(f"iteration={i}, train_loss={train_error[-1]:.6f}, test_loss={test_error[-1]:.6f}, best_loss={best_error:.6f}")
            break

        #Wyświetlanie informacji o postępie uczenia
        if i%1==0:
            print(f"iteration={i}, train_loss={train_error[-1]:.6f}, test_loss={test_error[-1]:.6f}, best_loss={best_error:.6f}")
    
    #Wybór najlepszych parametrów
    params = best_params

    #Zapisanie parametrów do pliku
    pickle.dump(params, open(os.path.join(config["ckpt_path"], "PojedynczeWahadloBezZaklocen.pkl"), "wb"))

#Brak uczenia - odczyt parametrów z pliku
else:
    params = pickle.load(open(os.path.join(config["ckpt_path"], "PojedynczeWahadloBezZaklocen.pkl"), "rb"))
    #opt_state = optimizers.pack_optimizer_state(params)
# Out:
# iteration=0, train_loss=64.370705, test_loss=65.761963, best_loss=65.761963
# iteration=1, train_loss=66.207298, test_loss=67.872337, best_loss=65.761963
# iteration=2, train_loss=66.486816, test_loss=68.193092, best_loss=65.761963
# iteration=3, train_loss=66.506706, test_loss=68.217468, best_loss=65.761963
# iteration=4, train_loss=66.483833, test_loss=68.192848, best_loss=65.761963
# iteration=5, train_loss=66.453568, test_loss=68.159698, best_loss=65.761963
# iteration=6, train_loss=66.422707, test_loss=68.125740, best_loss=65.761963
# iteration=7, train_loss=66.392334, test_loss=68.092346, best_loss=65.761963
# iteration=8, train_loss=66.363739, test_loss=68.061127, best_loss=65.761963
# iteration=9, train_loss=66.332863, test_loss=68.026985, best_loss=65.761963
# iteration=10, train_loss=66.304565, test_loss=67.996094, best_loss=65.761963
# iteration=11, train_loss=66.273865, test_loss=67.962204, best_loss=65.761963
# iteration=12, train_loss=66.244301, test_loss=67.929726, best_loss=65.761963
# iteration=13, train_loss=66.215431, test_loss=67.898247, best_loss=65.761963
# iteration=14, train_loss=66.185493, test_loss=67.865410, best_loss=65.761963
# iteration=15, train_loss=66.155678, test_loss=67.832596, best_loss=65.761963
# iteration=16, train_loss=66.123703, test_loss=67.797470, best_loss=65.761963
# iteration=17, train_loss=66.092873, test_loss=67.763512, best_loss=65.761963
# iteration=18, train_loss=66.062614, test_loss=67.730629, best_loss=65.761963
# iteration=19, train_loss=66.028976, test_loss=67.693268, best_loss=65.761963
# iteration=20, train_loss=65.996674, test_loss=67.657799, best_loss=65.761963
# iteration=21, train_loss=65.963882, test_loss=67.621674, best_loss=65.761963
# iteration=22, train_loss=65.929985, test_loss=67.584419, best_loss=65.761963
# iteration=23, train_loss=65.895805, test_loss=67.546638, best_loss=65.761963
# iteration=24, train_loss=65.862061, test_loss=67.509773, best_loss=65.761963
# iteration=25, train_loss=65.827660, test_loss=67.472015, best_loss=65.761963
# iteration=26, train_loss=65.791550, test_loss=67.432205, best_loss=65.761963
# iteration=27, train_loss=65.755013, test_loss=67.391747, best_loss=65.761963
# iteration=28, train_loss=65.718613, test_loss=67.351723, best_loss=65.761963
# iteration=29, train_loss=65.679932, test_loss=67.308891, best_loss=65.761963
# iteration=30, train_loss=65.642662, test_loss=67.267754, best_loss=65.761963
# iteration=31, train_loss=65.602509, test_loss=67.223068, best_loss=65.761963
# iteration=32, train_loss=65.564209, test_loss=67.181000, best_loss=65.761963
# iteration=33, train_loss=65.524612, test_loss=67.137451, best_loss=65.761963
# iteration=34, train_loss=65.485344, test_loss=67.094406, best_loss=65.761963
# iteration=35, train_loss=65.444756, test_loss=67.049599, best_loss=65.761963
# iteration=36, train_loss=65.403816, test_loss=67.004547, best_loss=65.761963
# iteration=37, train_loss=65.361404, test_loss=66.957489, best_loss=65.761963
# iteration=38, train_loss=65.317207, test_loss=66.908302, best_loss=65.761963
# iteration=39, train_loss=65.275024, test_loss=66.861954, best_loss=65.761963
# iteration=40, train_loss=65.230995, test_loss=66.813309, best_loss=65.761963
# iteration=41, train_loss=65.185654, test_loss=66.762894, best_loss=65.761963
# iteration=42, train_loss=65.140594, test_loss=66.712929, best_loss=65.761963
# iteration=43, train_loss=65.092216, test_loss=66.658920, best_loss=65.761963
# iteration=44, train_loss=65.045540, test_loss=66.607216, best_loss=65.761963
# iteration=45, train_loss=64.997040, test_loss=66.553268, best_loss=65.761963
# iteration=46, train_loss=64.952415, test_loss=66.504387, best_loss=65.761963
# iteration=47, train_loss=64.903061, test_loss=66.449753, best_loss=65.761963
# iteration=48, train_loss=64.854126, test_loss=66.395462, best_loss=65.761963
# iteration=49, train_loss=64.802956, test_loss=66.338600, best_loss=65.761963
# iteration=50, train_loss=64.752014, test_loss=66.282021, best_loss=65.761963
# iteration=51, train_loss=64.700882, test_loss=66.224953, best_loss=65.761963
# iteration=52, train_loss=64.647743, test_loss=66.165749, best_loss=65.761963
# iteration=53, train_loss=64.595276, test_loss=66.107552, best_loss=65.761963
# iteration=54, train_loss=64.542633, test_loss=66.049408, best_loss=65.761963
# iteration=55, train_loss=64.486710, test_loss=65.986626, best_loss=65.761963
# iteration=56, train_loss=64.431740, test_loss=65.925140, best_loss=65.761963
# iteration=57, train_loss=64.377213, test_loss=65.864777, best_loss=65.761963
# iteration=58, train_loss=64.321266, test_loss=65.802383, best_loss=65.761963
# iteration=59, train_loss=64.265152, test_loss=65.740570, best_loss=65.740570
# iteration=60, train_loss=64.205658, test_loss=65.673721, best_loss=65.673721
# iteration=61, train_loss=64.145805, test_loss=65.606705, best_loss=65.606705
# iteration=62, train_loss=64.086166, test_loss=65.540176, best_loss=65.540176
# iteration=63, train_loss=64.024666, test_loss=65.471031, best_loss=65.471031
# iteration=64, train_loss=63.966114, test_loss=65.406036, best_loss=65.406036
# iteration=65, train_loss=63.902332, test_loss=65.333900, best_loss=65.333900
# iteration=66, train_loss=63.840630, test_loss=65.265129, best_loss=65.265129
# iteration=67, train_loss=63.779007, test_loss=65.196579, best_loss=65.196579
# iteration=68, train_loss=63.714684, test_loss=65.124306, best_loss=65.124306
# iteration=69, train_loss=63.649731, test_loss=65.051216, best_loss=65.051216
# iteration=70, train_loss=63.583714, test_loss=64.976601, best_loss=64.976601
# iteration=71, train_loss=63.517071, test_loss=64.901520, best_loss=64.901520
# iteration=72, train_loss=63.449833, test_loss=64.826553, best_loss=64.826553
# iteration=73, train_loss=63.383202, test_loss=64.751976, best_loss=64.751976
# iteration=74, train_loss=63.312988, test_loss=64.672028, best_loss=64.672028
# iteration=75, train_loss=63.243095, test_loss=64.593277, best_loss=64.593277
# iteration=76, train_loss=63.174168, test_loss=64.515770, best_loss=64.515770
# iteration=77, train_loss=63.102314, test_loss=64.434273, best_loss=64.434273
# iteration=78, train_loss=63.028973, test_loss=64.351974, best_loss=64.351974
# iteration=79, train_loss=62.957268, test_loss=64.271835, best_loss=64.271835
# iteration=80, train_loss=62.887028, test_loss=64.192345, best_loss=64.192345
# iteration=81, train_loss=62.810097, test_loss=64.104065, best_loss=64.104065
# iteration=82, train_loss=62.735775, test_loss=64.019997, best_loss=64.019997
# iteration=83, train_loss=62.659264, test_loss=63.932991, best_loss=63.932991
# iteration=84, train_loss=62.584347, test_loss=63.848888, best_loss=63.848888
# iteration=85, train_loss=62.506783, test_loss=63.760628, best_loss=63.760628
# iteration=86, train_loss=62.427322, test_loss=63.669724, best_loss=63.669724
# iteration=87, train_loss=62.347908, test_loss=63.577915, best_loss=63.577915
# iteration=88, train_loss=62.266144, test_loss=63.485649, best_loss=63.485649
# iteration=89, train_loss=62.186188, test_loss=63.394455, best_loss=63.394455
# iteration=90, train_loss=62.107502, test_loss=63.304623, best_loss=63.304623
# iteration=91, train_loss=62.027050, test_loss=63.212673, best_loss=63.212673
# iteration=92, train_loss=61.944885, test_loss=63.118183, best_loss=63.118183
# iteration=93, train_loss=61.860981, test_loss=63.021431, best_loss=63.021431
# iteration=94, train_loss=61.778999, test_loss=62.929016, best_loss=62.929016
# iteration=95, train_loss=61.696140, test_loss=62.834316, best_loss=62.834316
# iteration=96, train_loss=61.615234, test_loss=62.741714, best_loss=62.741714
# iteration=97, train_loss=61.530048, test_loss=62.643612, best_loss=62.643612
# iteration=98, train_loss=61.444244, test_loss=62.545265, best_loss=62.545265
# iteration=99, train_loss=61.359993, test_loss=62.448833, best_loss=62.448833
# iteration=100, train_loss=61.271767, test_loss=62.344742, best_loss=62.344742
# iteration=101, train_loss=61.186176, test_loss=62.251057, best_loss=62.251057
# iteration=102, train_loss=61.098885, test_loss=62.147247, best_loss=62.147247
# iteration=103, train_loss=61.011658, test_loss=62.044682, best_loss=62.044682
# iteration=104, train_loss=60.926636, test_loss=61.950287, best_loss=61.950287
# iteration=105, train_loss=60.840046, test_loss=61.850822, best_loss=61.850822
# iteration=106, train_loss=60.751480, test_loss=61.748180, best_loss=61.748180
# iteration=107, train_loss=60.661808, test_loss=61.646439, best_loss=61.646439
# iteration=108, train_loss=60.572762, test_loss=61.542454, best_loss=61.542454
# iteration=109, train_loss=60.489330, test_loss=61.448166, best_loss=61.448166
# iteration=110, train_loss=60.394917, test_loss=61.333630, best_loss=61.333630
# iteration=111, train_loss=60.306091, test_loss=61.235035, best_loss=61.235035
# iteration=112, train_loss=60.216179, test_loss=61.129463, best_loss=61.129463
# iteration=113, train_loss=60.127789, test_loss=61.027050, best_loss=61.027050
# iteration=114, train_loss=60.038925, test_loss=60.924240, best_loss=60.924240
# iteration=115, train_loss=59.948822, test_loss=60.818134, best_loss=60.818134
# iteration=116, train_loss=59.857250, test_loss=60.714745, best_loss=60.714745
# iteration=117, train_loss=59.768246, test_loss=60.609436, best_loss=60.609436
# iteration=118, train_loss=59.673393, test_loss=60.501114, best_loss=60.501114
# iteration=119, train_loss=59.587273, test_loss=60.405106, best_loss=60.405106
# iteration=120, train_loss=59.493031, test_loss=60.291546, best_loss=60.291546
# iteration=121, train_loss=59.402042, test_loss=60.183987, best_loss=60.183987
# iteration=122, train_loss=59.314690, test_loss=60.089996, best_loss=60.089996
# iteration=123, train_loss=59.224792, test_loss=59.991589, best_loss=59.991589
# iteration=124, train_loss=59.131237, test_loss=59.877747, best_loss=59.877747
# iteration=125, train_loss=59.041908, test_loss=59.768608, best_loss=59.768608
# iteration=126, train_loss=58.952122, test_loss=59.669308, best_loss=59.669308
# iteration=127, train_loss=58.860996, test_loss=59.572464, best_loss=59.572464
# iteration=128, train_loss=58.764347, test_loss=59.453106, best_loss=59.453106
# iteration=129, train_loss=58.673077, test_loss=59.348904, best_loss=59.348904
# iteration=130, train_loss=58.582115, test_loss=59.242085, best_loss=59.242085
# iteration=131, train_loss=58.488003, test_loss=59.141407, best_loss=59.141407
# iteration=132, train_loss=58.397964, test_loss=59.037102, best_loss=59.037102
# iteration=133, train_loss=58.304317, test_loss=58.930164, best_loss=58.930164
# iteration=134, train_loss=58.211365, test_loss=58.818367, best_loss=58.818367
# iteration=135, train_loss=58.116463, test_loss=58.708553, best_loss=58.708553
# iteration=136, train_loss=58.025143, test_loss=58.613331, best_loss=58.613331
# iteration=137, train_loss=57.930798, test_loss=58.505386, best_loss=58.505386
# iteration=138, train_loss=57.837727, test_loss=58.398083, best_loss=58.398083
# iteration=139, train_loss=57.743187, test_loss=58.287731, best_loss=58.287731
# iteration=140, train_loss=57.647003, test_loss=58.179630, best_loss=58.179630
# iteration=141, train_loss=57.550507, test_loss=58.073742, best_loss=58.073742
# iteration=142, train_loss=57.454128, test_loss=57.957348, best_loss=57.957348
# iteration=143, train_loss=57.358471, test_loss=57.852589, best_loss=57.852589
# iteration=144, train_loss=57.260754, test_loss=57.746021, best_loss=57.746021
# iteration=145, train_loss=57.165462, test_loss=57.641876, best_loss=57.641876
# iteration=146, train_loss=57.068356, test_loss=57.534908, best_loss=57.534908
# iteration=147, train_loss=56.967789, test_loss=57.412376, best_loss=57.412376
# iteration=148, train_loss=56.871361, test_loss=57.312275, best_loss=57.312275
# iteration=149, train_loss=56.770790, test_loss=57.192448, best_loss=57.192448
# iteration=150, train_loss=56.667931, test_loss=57.082428, best_loss=57.082428
# iteration=151, train_loss=56.567142, test_loss=56.960934, best_loss=56.960934
# iteration=152, train_loss=56.463802, test_loss=56.857609, best_loss=56.857609
# iteration=153, train_loss=56.361809, test_loss=56.744751, best_loss=56.744751
# iteration=154, train_loss=56.261784, test_loss=56.625332, best_loss=56.625332
# iteration=155, train_loss=56.156612, test_loss=56.518272, best_loss=56.518272
# iteration=156, train_loss=56.049252, test_loss=56.397560, best_loss=56.397560
# iteration=157, train_loss=55.943642, test_loss=56.276176, best_loss=56.276176
# iteration=158, train_loss=55.836369, test_loss=56.163052, best_loss=56.163052
# iteration=159, train_loss=55.727036, test_loss=56.034893, best_loss=56.034893
# iteration=160, train_loss=55.617611, test_loss=55.917603, best_loss=55.917603
# iteration=161, train_loss=55.507816, test_loss=55.797958, best_loss=55.797958
# iteration=162, train_loss=55.400974, test_loss=55.695480, best_loss=55.695480
# iteration=163, train_loss=55.286198, test_loss=55.557964, best_loss=55.557964
# iteration=164, train_loss=55.170132, test_loss=55.428432, best_loss=55.428432
# iteration=165, train_loss=55.054947, test_loss=55.308361, best_loss=55.308361
# iteration=166, train_loss=54.939415, test_loss=55.184391, best_loss=55.184391
# iteration=167, train_loss=54.821930, test_loss=55.052670, best_loss=55.052670
# iteration=168, train_loss=54.702080, test_loss=54.929440, best_loss=54.929440
# iteration=169, train_loss=54.579567, test_loss=54.797142, best_loss=54.797142
# iteration=170, train_loss=54.452511, test_loss=54.652164, best_loss=54.652164
# iteration=171, train_loss=54.326363, test_loss=54.520119, best_loss=54.520119
# iteration=172, train_loss=54.200260, test_loss=54.386162, best_loss=54.386162
# iteration=173, train_loss=54.071316, test_loss=54.245647, best_loss=54.245647
# iteration=174, train_loss=53.941502, test_loss=54.111725, best_loss=54.111725
# iteration=175, train_loss=53.813332, test_loss=53.988033, best_loss=53.988033
# iteration=176, train_loss=53.673729, test_loss=53.821533, best_loss=53.821533
# iteration=177, train_loss=53.532963, test_loss=53.676113, best_loss=53.676113
# iteration=178, train_loss=53.390339, test_loss=53.521534, best_loss=53.521534
# iteration=179, train_loss=53.248501, test_loss=53.374912, best_loss=53.374912
# iteration=180, train_loss=53.101204, test_loss=53.216766, best_loss=53.216766
# iteration=181, train_loss=52.953354, test_loss=53.058270, best_loss=53.058270
# iteration=182, train_loss=52.799721, test_loss=52.899986, best_loss=52.899986
# iteration=183, train_loss=52.642643, test_loss=52.731853, best_loss=52.731853
# iteration=184, train_loss=52.487129, test_loss=52.566742, best_loss=52.566742
# iteration=185, train_loss=52.322086, test_loss=52.395222, best_loss=52.395222
# iteration=186, train_loss=52.153347, test_loss=52.218197, best_loss=52.218197
# iteration=187, train_loss=51.987175, test_loss=52.045311, best_loss=52.045311
# iteration=188, train_loss=51.809868, test_loss=51.859509, best_loss=51.859509
# iteration=189, train_loss=51.635517, test_loss=51.685555, best_loss=51.685555
# iteration=190, train_loss=51.446144, test_loss=51.480137, best_loss=51.480137
# iteration=191, train_loss=51.259197, test_loss=51.283421, best_loss=51.283421
# iteration=192, train_loss=51.062603, test_loss=51.078934, best_loss=51.078934
# iteration=193, train_loss=50.864906, test_loss=50.874149, best_loss=50.874149
# iteration=194, train_loss=50.658840, test_loss=50.670300, best_loss=50.670300
# iteration=195, train_loss=50.444004, test_loss=50.442486, best_loss=50.442486
# iteration=196, train_loss=50.223759, test_loss=50.212009, best_loss=50.212009
# iteration=197, train_loss=50.002773, test_loss=49.982090, best_loss=49.982090
# iteration=198, train_loss=49.766243, test_loss=49.738129, best_loss=49.738129
# iteration=199, train_loss=49.529366, test_loss=49.499878, best_loss=49.499878
# iteration=200, train_loss=49.286304, test_loss=49.255447, best_loss=49.255447
# iteration=201, train_loss=49.026249, test_loss=48.985603, best_loss=48.985603
# iteration=202, train_loss=48.758957, test_loss=48.707024, best_loss=48.707024
# iteration=203, train_loss=48.479305, test_loss=48.414619, best_loss=48.414619
# iteration=204, train_loss=48.188587, test_loss=48.117371, best_loss=48.117371
# iteration=205, train_loss=47.893581, test_loss=47.818222, best_loss=47.818222
# iteration=206, train_loss=47.581009, test_loss=47.499550, best_loss=47.499550
# iteration=207, train_loss=47.258205, test_loss=47.170860, best_loss=47.170860
# iteration=208, train_loss=46.922428, test_loss=46.831989, best_loss=46.831989
# iteration=209, train_loss=46.571884, test_loss=46.476925, best_loss=46.476925
# iteration=210, train_loss=46.200314, test_loss=46.092022, best_loss=46.092022
# iteration=211, train_loss=45.815464, test_loss=45.707355, best_loss=45.707355
# iteration=212, train_loss=45.412479, test_loss=45.297173, best_loss=45.297173
# iteration=213, train_loss=44.990368, test_loss=44.868122, best_loss=44.868122
# iteration=214, train_loss=44.545204, test_loss=44.414097, best_loss=44.414097
# iteration=215, train_loss=44.086342, test_loss=43.938610, best_loss=43.938610
# iteration=216, train_loss=43.607765, test_loss=43.451977, best_loss=43.451977
# iteration=217, train_loss=43.093063, test_loss=42.931248, best_loss=42.931248
# iteration=218, train_loss=42.554314, test_loss=42.375431, best_loss=42.375431
# iteration=219, train_loss=42.005821, test_loss=41.815258, best_loss=41.815258
# iteration=220, train_loss=41.407352, test_loss=41.198940, best_loss=41.198940
# iteration=221, train_loss=40.793800, test_loss=40.582691, best_loss=40.582691
# iteration=222, train_loss=40.143768, test_loss=39.929756, best_loss=39.929756
# iteration=223, train_loss=39.459354, test_loss=39.225719, best_loss=39.225719
# iteration=224, train_loss=38.739368, test_loss=38.482056, best_loss=38.482056
# iteration=225, train_loss=37.982315, test_loss=37.711533, best_loss=37.711533
# iteration=226, train_loss=37.205868, test_loss=36.923557, best_loss=36.923557
# iteration=227, train_loss=36.370548, test_loss=36.052399, best_loss=36.052399
# iteration=228, train_loss=35.534081, test_loss=35.189003, best_loss=35.189003
# iteration=229, train_loss=34.657845, test_loss=34.288017, best_loss=34.288017
# iteration=230, train_loss=33.759869, test_loss=33.362404, best_loss=33.362404
# iteration=231, train_loss=32.823528, test_loss=32.371712, best_loss=32.371712
# iteration=232, train_loss=31.924974, test_loss=31.441341, best_loss=31.441341
# iteration=233, train_loss=31.012259, test_loss=30.493484, best_loss=30.493484
# iteration=234, train_loss=30.106920, test_loss=29.524115, best_loss=29.524115
# iteration=235, train_loss=29.260111, test_loss=28.605217, best_loss=28.605217
# iteration=236, train_loss=28.441139, test_loss=27.707747, best_loss=27.707747
# iteration=237, train_loss=27.716328, test_loss=26.961552, best_loss=26.961552
# iteration=238, train_loss=27.028290, test_loss=26.168877, best_loss=26.168877
# iteration=239, train_loss=26.384886, test_loss=25.456450, best_loss=25.456450
# iteration=240, train_loss=25.824987, test_loss=24.999783, best_loss=24.999783
# iteration=241, train_loss=25.309248, test_loss=24.481567, best_loss=24.481567
# iteration=242, train_loss=24.822376, test_loss=23.988993, best_loss=23.988993
# iteration=243, train_loss=24.385414, test_loss=23.550993, best_loss=23.550993
# iteration=244, train_loss=23.966206, test_loss=23.247232, best_loss=23.247232
# iteration=245, train_loss=23.586386, test_loss=22.847469, best_loss=22.847469
# iteration=246, train_loss=23.194332, test_loss=22.518700, best_loss=22.518700
# iteration=247, train_loss=22.819990, test_loss=22.080341, best_loss=22.080341
# iteration=248, train_loss=22.485554, test_loss=21.776203, best_loss=21.776203
# iteration=249, train_loss=22.144773, test_loss=21.379692, best_loss=21.379692
# iteration=250, train_loss=21.802290, test_loss=21.119482, best_loss=21.119482
# iteration=251, train_loss=21.482670, test_loss=20.760004, best_loss=20.760004
# iteration=252, train_loss=21.165987, test_loss=20.498991, best_loss=20.498991
# iteration=253, train_loss=20.868748, test_loss=20.275576, best_loss=20.275576
# iteration=254, train_loss=20.574692, test_loss=20.016153, best_loss=20.016153
# iteration=255, train_loss=20.281931, test_loss=19.697889, best_loss=19.697889
# iteration=256, train_loss=19.996353, test_loss=19.407045, best_loss=19.407045
# iteration=257, train_loss=19.722073, test_loss=19.177807, best_loss=19.177807
# iteration=258, train_loss=19.445827, test_loss=18.857391, best_loss=18.857391
# iteration=259, train_loss=19.182978, test_loss=18.640825, best_loss=18.640825
# iteration=260, train_loss=18.926294, test_loss=18.455009, best_loss=18.455009
# iteration=261, train_loss=18.670664, test_loss=18.112396, best_loss=18.112396
# iteration=262, train_loss=18.415802, test_loss=17.853270, best_loss=17.853270
# iteration=263, train_loss=18.168121, test_loss=17.768969, best_loss=17.768969
# iteration=264, train_loss=17.936451, test_loss=17.520973, best_loss=17.520973
# iteration=265, train_loss=17.704485, test_loss=17.178679, best_loss=17.178679
# iteration=266, train_loss=17.472555, test_loss=17.154715, best_loss=17.154715
# iteration=267, train_loss=17.232973, test_loss=16.909678, best_loss=16.909678
# iteration=268, train_loss=17.006567, test_loss=16.578613, best_loss=16.578613
# iteration=269, train_loss=16.781195, test_loss=16.415922, best_loss=16.415922
# iteration=270, train_loss=16.570066, test_loss=16.291794, best_loss=16.291794
# iteration=271, train_loss=16.356325, test_loss=16.039679, best_loss=16.039679
# iteration=272, train_loss=16.156092, test_loss=15.881119, best_loss=15.881119
# iteration=273, train_loss=15.952833, test_loss=15.649540, best_loss=15.649540
# iteration=274, train_loss=15.756014, test_loss=15.531723, best_loss=15.531723
# iteration=275, train_loss=15.562364, test_loss=15.360704, best_loss=15.360704
# iteration=276, train_loss=15.374701, test_loss=15.154226, best_loss=15.154226
# iteration=277, train_loss=15.184641, test_loss=15.000543, best_loss=15.000543
# iteration=278, train_loss=15.001414, test_loss=14.858117, best_loss=14.858117
# iteration=279, train_loss=14.834700, test_loss=14.771804, best_loss=14.771804
# iteration=280, train_loss=14.657240, test_loss=14.535156, best_loss=14.535156
# iteration=281, train_loss=14.487593, test_loss=14.353368, best_loss=14.353368
# iteration=282, train_loss=14.324215, test_loss=14.266478, best_loss=14.266478
# iteration=283, train_loss=14.166339, test_loss=14.141285, best_loss=14.141285
# iteration=284, train_loss=14.002213, test_loss=13.969683, best_loss=13.969683
# iteration=285, train_loss=13.849785, test_loss=13.835262, best_loss=13.835262
# iteration=286, train_loss=13.702889, test_loss=13.678591, best_loss=13.678591
# iteration=287, train_loss=13.552771, test_loss=13.578889, best_loss=13.578889
# iteration=288, train_loss=13.402880, test_loss=13.482318, best_loss=13.482318
# iteration=289, train_loss=13.260893, test_loss=13.336831, best_loss=13.336831
# iteration=290, train_loss=13.115785, test_loss=13.206434, best_loss=13.206434
# iteration=291, train_loss=12.975192, test_loss=13.096256, best_loss=13.096256
# iteration=292, train_loss=12.843800, test_loss=12.904162, best_loss=12.904162
# iteration=293, train_loss=12.707134, test_loss=12.804430, best_loss=12.804430
# iteration=294, train_loss=12.573618, test_loss=12.702586, best_loss=12.702586
# iteration=295, train_loss=12.444577, test_loss=12.620590, best_loss=12.620590
# iteration=296, train_loss=12.317596, test_loss=12.477916, best_loss=12.477916
# iteration=297, train_loss=12.193477, test_loss=12.320399, best_loss=12.320399
# iteration=298, train_loss=12.068649, test_loss=12.256569, best_loss=12.256569
# iteration=299, train_loss=11.946141, test_loss=12.107038, best_loss=12.107038
# iteration=300, train_loss=11.824608, test_loss=11.998342, best_loss=11.998342
# iteration=301, train_loss=11.711787, test_loss=11.959750, best_loss=11.959750
# iteration=302, train_loss=11.589328, test_loss=11.805284, best_loss=11.805284
# iteration=303, train_loss=11.471433, test_loss=11.712276, best_loss=11.712276
# iteration=304, train_loss=11.355474, test_loss=11.595055, best_loss=11.595055
# iteration=305, train_loss=11.241946, test_loss=11.472967, best_loss=11.472967
# iteration=306, train_loss=11.133039, test_loss=11.390976, best_loss=11.390976
# iteration=307, train_loss=11.023094, test_loss=11.284634, best_loss=11.284634
# iteration=308, train_loss=10.915048, test_loss=11.170229, best_loss=11.170229
# iteration=309, train_loss=10.811264, test_loss=11.050874, best_loss=11.050874
# iteration=310, train_loss=10.700221, test_loss=10.944674, best_loss=10.944674
# iteration=311, train_loss=10.593575, test_loss=10.875593, best_loss=10.875593
# iteration=312, train_loss=10.488688, test_loss=10.762146, best_loss=10.762146
# iteration=313, train_loss=10.386699, test_loss=10.679237, best_loss=10.679237
# iteration=314, train_loss=10.285224, test_loss=10.552288, best_loss=10.552288
# iteration=315, train_loss=10.183975, test_loss=10.466457, best_loss=10.466457
# iteration=316, train_loss=10.083600, test_loss=10.391395, best_loss=10.391395
# iteration=317, train_loss=9.982664, test_loss=10.288464, best_loss=10.288464
# iteration=318, train_loss=9.885069, test_loss=10.207124, best_loss=10.207124
# iteration=319, train_loss=9.785452, test_loss=10.074756, best_loss=10.074756
# iteration=320, train_loss=9.686766, test_loss=9.995307, best_loss=9.995307
# iteration=321, train_loss=9.592974, test_loss=9.935213, best_loss=9.935213
# iteration=322, train_loss=9.493194, test_loss=9.800344, best_loss=9.800344
# iteration=323, train_loss=9.396044, test_loss=9.688210, best_loss=9.688210
# iteration=324, train_loss=9.303746, test_loss=9.621403, best_loss=9.621403
# iteration=325, train_loss=9.210717, test_loss=9.539088, best_loss=9.539088
# iteration=326, train_loss=9.116214, test_loss=9.457270, best_loss=9.457270
# iteration=327, train_loss=9.023184, test_loss=9.336877, best_loss=9.336877
# iteration=328, train_loss=8.937919, test_loss=9.232053, best_loss=9.232053
# iteration=329, train_loss=8.847682, test_loss=9.171141, best_loss=9.171141
# iteration=330, train_loss=8.752335, test_loss=9.084064, best_loss=9.084064
# iteration=331, train_loss=8.658060, test_loss=8.991430, best_loss=8.991430
# iteration=332, train_loss=8.590622, test_loss=8.906928, best_loss=8.906928
# iteration=333, train_loss=8.504317, test_loss=8.806286, best_loss=8.806286
# iteration=334, train_loss=8.408643, test_loss=8.707357, best_loss=8.707357
# iteration=335, train_loss=8.312636, test_loss=8.629495, best_loss=8.629495
# iteration=336, train_loss=8.217383, test_loss=8.525514, best_loss=8.525514
# iteration=337, train_loss=8.132900, test_loss=8.442682, best_loss=8.442682
# iteration=338, train_loss=8.042623, test_loss=8.382049, best_loss=8.382049
# iteration=339, train_loss=7.955708, test_loss=8.279929, best_loss=8.279929
# iteration=340, train_loss=7.871388, test_loss=8.185163, best_loss=8.185163
# iteration=341, train_loss=7.790210, test_loss=8.109299, best_loss=8.109299
# iteration=342, train_loss=7.712679, test_loss=8.002097, best_loss=8.002097
# iteration=343, train_loss=7.632825, test_loss=7.927872, best_loss=7.927872
# iteration=344, train_loss=7.548884, test_loss=7.853791, best_loss=7.853791
# iteration=345, train_loss=7.474384, test_loss=7.776100, best_loss=7.776100
# iteration=346, train_loss=7.397820, test_loss=7.702479, best_loss=7.702479
# iteration=347, train_loss=7.328066, test_loss=7.627396, best_loss=7.627396
# iteration=348, train_loss=7.256288, test_loss=7.554430, best_loss=7.554430
# iteration=349, train_loss=7.182193, test_loss=7.489051, best_loss=7.489051
# iteration=350, train_loss=7.112657, test_loss=7.403011, best_loss=7.403011
# iteration=351, train_loss=7.052530, test_loss=7.315883, best_loss=7.315883
# iteration=352, train_loss=6.981709, test_loss=7.283102, best_loss=7.283102
# iteration=353, train_loss=6.923610, test_loss=7.234917, best_loss=7.234917
# iteration=354, train_loss=6.857566, test_loss=7.148286, best_loss=7.148286
# iteration=355, train_loss=6.794861, test_loss=7.080787, best_loss=7.080787
# iteration=356, train_loss=6.737088, test_loss=7.013331, best_loss=7.013331
# iteration=357, train_loss=6.678289, test_loss=6.963324, best_loss=6.963324
# iteration=358, train_loss=6.620491, test_loss=6.887657, best_loss=6.887657
# iteration=359, train_loss=6.564263, test_loss=6.831774, best_loss=6.831774
# iteration=360, train_loss=6.509750, test_loss=6.797358, best_loss=6.797358
# iteration=361, train_loss=6.456740, test_loss=6.735936, best_loss=6.735936
# iteration=362, train_loss=6.404376, test_loss=6.671757, best_loss=6.671757
# iteration=363, train_loss=6.342755, test_loss=6.586329, best_loss=6.586329
# iteration=364, train_loss=6.289872, test_loss=6.553579, best_loss=6.553579
# iteration=365, train_loss=6.240981, test_loss=6.487903, best_loss=6.487903
# iteration=366, train_loss=6.186296, test_loss=6.443822, best_loss=6.443822
# iteration=367, train_loss=6.132317, test_loss=6.394442, best_loss=6.394442
# iteration=368, train_loss=6.078322, test_loss=6.328936, best_loss=6.328936
# iteration=369, train_loss=6.025900, test_loss=6.265318, best_loss=6.265318
# iteration=370, train_loss=5.980677, test_loss=6.239963, best_loss=6.239963
# iteration=371, train_loss=5.928808, test_loss=6.148808, best_loss=6.148808
# iteration=372, train_loss=5.875890, test_loss=6.128374, best_loss=6.128374
# iteration=373, train_loss=5.819987, test_loss=6.050978, best_loss=6.050978
# iteration=374, train_loss=5.768188, test_loss=6.001529, best_loss=6.001529
# iteration=375, train_loss=5.717512, test_loss=5.959968, best_loss=5.959968
# iteration=376, train_loss=5.669302, test_loss=5.931155, best_loss=5.931155
# iteration=377, train_loss=5.618714, test_loss=5.879610, best_loss=5.879610
# iteration=378, train_loss=5.563861, test_loss=5.781079, best_loss=5.781079
# iteration=379, train_loss=5.521713, test_loss=5.734804, best_loss=5.734804
# iteration=380, train_loss=5.463957, test_loss=5.700401, best_loss=5.700401
# iteration=381, train_loss=5.410575, test_loss=5.643835, best_loss=5.643835
# iteration=382, train_loss=5.362929, test_loss=5.594016, best_loss=5.594016
# iteration=383, train_loss=5.313019, test_loss=5.548767, best_loss=5.548767
# iteration=384, train_loss=5.260750, test_loss=5.502888, best_loss=5.502888
# iteration=385, train_loss=5.210700, test_loss=5.438941, best_loss=5.438941
# iteration=386, train_loss=5.159275, test_loss=5.398044, best_loss=5.398044
# iteration=387, train_loss=5.107767, test_loss=5.355453, best_loss=5.355453
# iteration=388, train_loss=5.059215, test_loss=5.299767, best_loss=5.299767
# iteration=389, train_loss=5.008240, test_loss=5.258296, best_loss=5.258296
# iteration=390, train_loss=4.956807, test_loss=5.201903, best_loss=5.201903
# iteration=391, train_loss=4.903932, test_loss=5.143128, best_loss=5.143128
# iteration=392, train_loss=4.853182, test_loss=5.101179, best_loss=5.101179
# iteration=393, train_loss=4.806522, test_loss=5.080059, best_loss=5.080059
# iteration=394, train_loss=4.749912, test_loss=5.002391, best_loss=5.002391
# iteration=395, train_loss=4.699149, test_loss=4.966179, best_loss=4.966179
# iteration=396, train_loss=4.642508, test_loss=4.916784, best_loss=4.916784
# iteration=397, train_loss=4.586196, test_loss=4.886598, best_loss=4.886598
# iteration=398, train_loss=4.530409, test_loss=4.809983, best_loss=4.809983
# iteration=399, train_loss=4.464023, test_loss=4.785481, best_loss=4.785481
# iteration=400, train_loss=4.402061, test_loss=4.720366, best_loss=4.720366
# iteration=401, train_loss=4.333626, test_loss=4.666426, best_loss=4.666426
# iteration=402, train_loss=4.259792, test_loss=4.647848, best_loss=4.647848
# iteration=403, train_loss=4.174100, test_loss=4.556444, best_loss=4.556444
# iteration=404, train_loss=4.071323, test_loss=4.537942, best_loss=4.537942
# iteration=405, train_loss=3.961588, test_loss=4.442662, best_loss=4.442662
# iteration=406, train_loss=3.860071, test_loss=4.377910, best_loss=4.377910
# iteration=407, train_loss=3.734127, test_loss=4.273669, best_loss=4.273669
# iteration=408, train_loss=3.596103, test_loss=4.114111, best_loss=4.114111
# iteration=409, train_loss=3.423768, test_loss=3.972542, best_loss=3.972542
# iteration=410, train_loss=3.242604, test_loss=3.763319, best_loss=3.763319
# iteration=411, train_loss=3.043319, test_loss=3.597620, best_loss=3.597620
# iteration=412, train_loss=2.850309, test_loss=3.341200, best_loss=3.341200
# iteration=413, train_loss=2.705421, test_loss=3.208827, best_loss=3.208827
# iteration=414, train_loss=2.570846, test_loss=3.039975, best_loss=3.039975
# iteration=415, train_loss=2.447278, test_loss=2.908498, best_loss=2.908498
# iteration=416, train_loss=2.356435, test_loss=2.811752, best_loss=2.811752
# iteration=417, train_loss=2.262057, test_loss=2.704019, best_loss=2.704019
# iteration=418, train_loss=2.193522, test_loss=2.629237, best_loss=2.629237
# iteration=419, train_loss=2.108425, test_loss=2.537308, best_loss=2.537308
# iteration=420, train_loss=2.047210, test_loss=2.481463, best_loss=2.481463
# iteration=421, train_loss=2.002667, test_loss=2.431620, best_loss=2.431620
# iteration=422, train_loss=1.946601, test_loss=2.344993, best_loss=2.344993
# iteration=423, train_loss=1.908646, test_loss=2.318498, best_loss=2.318498
# iteration=424, train_loss=1.871641, test_loss=2.257334, best_loss=2.257334
# iteration=425, train_loss=1.835509, test_loss=2.242274, best_loss=2.242274
# iteration=426, train_loss=1.805837, test_loss=2.180415, best_loss=2.180415
# iteration=427, train_loss=1.778479, test_loss=2.157451, best_loss=2.157451
# iteration=428, train_loss=1.755033, test_loss=2.131776, best_loss=2.131776
# iteration=429, train_loss=1.733855, test_loss=2.090212, best_loss=2.090212
# iteration=430, train_loss=1.712809, test_loss=2.080099, best_loss=2.080099
# iteration=431, train_loss=1.692023, test_loss=2.048104, best_loss=2.048104
# iteration=432, train_loss=1.667977, test_loss=2.005116, best_loss=2.005116
# iteration=433, train_loss=1.648864, test_loss=1.978130, best_loss=1.978130
# iteration=434, train_loss=1.639509, test_loss=1.983304, best_loss=1.978130
# iteration=435, train_loss=1.614040, test_loss=1.916227, best_loss=1.916227
# iteration=436, train_loss=1.589468, test_loss=1.900265, best_loss=1.900265
# iteration=437, train_loss=1.569734, test_loss=1.871180, best_loss=1.871180
# iteration=438, train_loss=1.559672, test_loss=1.857420, best_loss=1.857420
# iteration=439, train_loss=1.532895, test_loss=1.813256, best_loss=1.813256
# iteration=440, train_loss=1.515020, test_loss=1.793930, best_loss=1.793930
# iteration=441, train_loss=1.495025, test_loss=1.753867, best_loss=1.753867
# iteration=442, train_loss=1.473715, test_loss=1.738202, best_loss=1.738202
# iteration=443, train_loss=1.468065, test_loss=1.713312, best_loss=1.713312
# iteration=444, train_loss=1.432016, test_loss=1.676477, best_loss=1.676477
# iteration=445, train_loss=1.413168, test_loss=1.648208, best_loss=1.648208
# iteration=446, train_loss=1.398393, test_loss=1.624289, best_loss=1.624289
# iteration=447, train_loss=1.374735, test_loss=1.596449, best_loss=1.596449
# iteration=448, train_loss=1.356923, test_loss=1.577870, best_loss=1.577870
# iteration=449, train_loss=1.339465, test_loss=1.550785, best_loss=1.550785
# iteration=450, train_loss=1.322820, test_loss=1.526162, best_loss=1.526162
# iteration=451, train_loss=1.309270, test_loss=1.514789, best_loss=1.514789
# iteration=452, train_loss=1.287334, test_loss=1.482591, best_loss=1.482591
# iteration=453, train_loss=1.282295, test_loss=1.470590, best_loss=1.470590
# iteration=454, train_loss=1.260220, test_loss=1.447370, best_loss=1.447370
# iteration=455, train_loss=1.250952, test_loss=1.438757, best_loss=1.438757
# iteration=456, train_loss=1.235021, test_loss=1.414641, best_loss=1.414641
# iteration=457, train_loss=1.219327, test_loss=1.393068, best_loss=1.393068
# iteration=458, train_loss=1.208665, test_loss=1.389402, best_loss=1.389402
# iteration=459, train_loss=1.191653, test_loss=1.364776, best_loss=1.364776
# iteration=460, train_loss=1.187320, test_loss=1.351853, best_loss=1.351853
# iteration=461, train_loss=1.174892, test_loss=1.345590, best_loss=1.345590
# iteration=462, train_loss=1.167623, test_loss=1.324311, best_loss=1.324311
# iteration=463, train_loss=1.148464, test_loss=1.302866, best_loss=1.302866
# iteration=464, train_loss=1.150774, test_loss=1.313277, best_loss=1.302866
# iteration=465, train_loss=1.128391, test_loss=1.279771, best_loss=1.279771
# iteration=466, train_loss=1.116530, test_loss=1.265534, best_loss=1.265534
# iteration=467, train_loss=1.105689, test_loss=1.256742, best_loss=1.256742
# iteration=468, train_loss=1.100232, test_loss=1.244588, best_loss=1.244588
# iteration=469, train_loss=1.103187, test_loss=1.248493, best_loss=1.244588
# iteration=470, train_loss=1.081795, test_loss=1.221798, best_loss=1.221798
# iteration=471, train_loss=1.070459, test_loss=1.208260, best_loss=1.208260
# iteration=472, train_loss=1.061531, test_loss=1.200422, best_loss=1.200422
# iteration=473, train_loss=1.052686, test_loss=1.187290, best_loss=1.187290
# iteration=474, train_loss=1.047348, test_loss=1.184846, best_loss=1.184846
# iteration=475, train_loss=1.037485, test_loss=1.165403, best_loss=1.165403
# iteration=476, train_loss=1.032867, test_loss=1.161289, best_loss=1.161289
# iteration=477, train_loss=1.022068, test_loss=1.149595, best_loss=1.149595
# iteration=478, train_loss=1.012744, test_loss=1.138390, best_loss=1.138390
# iteration=479, train_loss=1.009919, test_loss=1.132362, best_loss=1.132362
# iteration=480, train_loss=0.997961, test_loss=1.117867, best_loss=1.117867
# iteration=481, train_loss=0.990404, test_loss=1.110727, best_loss=1.110727
# iteration=482, train_loss=0.988888, test_loss=1.108196, best_loss=1.108196
# iteration=483, train_loss=0.977026, test_loss=1.091771, best_loss=1.091771
# iteration=484, train_loss=0.967741, test_loss=1.080780, best_loss=1.080780
# iteration=485, train_loss=0.971484, test_loss=1.090645, best_loss=1.080780
# iteration=486, train_loss=0.984184, test_loss=1.089453, best_loss=1.080780
# iteration=487, train_loss=0.948398, test_loss=1.057051, best_loss=1.057051
# iteration=488, train_loss=0.940593, test_loss=1.051665, best_loss=1.051665
# iteration=489, train_loss=0.930728, test_loss=1.036946, best_loss=1.036946
# iteration=490, train_loss=0.930199, test_loss=1.035219, best_loss=1.035219
# iteration=491, train_loss=0.920032, test_loss=1.025156, best_loss=1.025156
# iteration=492, train_loss=0.913450, test_loss=1.016955, best_loss=1.016955
# iteration=493, train_loss=0.903581, test_loss=1.000857, best_loss=1.000857
# iteration=494, train_loss=0.905103, test_loss=1.005636, best_loss=1.000857
# iteration=495, train_loss=0.892378, test_loss=0.990269, best_loss=0.990269
# iteration=496, train_loss=0.883564, test_loss=0.978111, best_loss=0.978111
# iteration=497, train_loss=0.880218, test_loss=0.976627, best_loss=0.976627
# iteration=498, train_loss=0.874752, test_loss=0.968034, best_loss=0.968034
# iteration=499, train_loss=0.865982, test_loss=0.954866, best_loss=0.954866
# iteration=500, train_loss=0.855277, test_loss=0.946924, best_loss=0.946924
# iteration=501, train_loss=0.848257, test_loss=0.937179, best_loss=0.937179
# iteration=502, train_loss=0.843956, test_loss=0.934071, best_loss=0.934071
# iteration=503, train_loss=0.843188, test_loss=0.927633, best_loss=0.927633
# iteration=504, train_loss=0.828255, test_loss=0.914696, best_loss=0.914696
# iteration=505, train_loss=0.834858, test_loss=0.914562, best_loss=0.914562
# iteration=506, train_loss=0.817600, test_loss=0.900710, best_loss=0.900710
# iteration=507, train_loss=0.813250, test_loss=0.896671, best_loss=0.896671
# iteration=508, train_loss=0.807584, test_loss=0.888349, best_loss=0.888349
# iteration=509, train_loss=0.808787, test_loss=0.883168, best_loss=0.883168
# iteration=510, train_loss=0.791227, test_loss=0.871109, best_loss=0.871109
# iteration=511, train_loss=0.786258, test_loss=0.860763, best_loss=0.860763
# iteration=512, train_loss=0.779951, test_loss=0.856732, best_loss=0.856732
# iteration=513, train_loss=0.773286, test_loss=0.847665, best_loss=0.847665
# iteration=514, train_loss=0.787384, test_loss=0.865850, best_loss=0.847665
# iteration=515, train_loss=0.767385, test_loss=0.836411, best_loss=0.836411
# iteration=516, train_loss=0.757230, test_loss=0.834426, best_loss=0.834426
# iteration=517, train_loss=0.751536, test_loss=0.820574, best_loss=0.820574
# iteration=518, train_loss=0.751363, test_loss=0.821665, best_loss=0.820574
# iteration=519, train_loss=0.744391, test_loss=0.815325, best_loss=0.815325
# iteration=520, train_loss=0.729849, test_loss=0.800614, best_loss=0.800614
# iteration=521, train_loss=0.729946, test_loss=0.799825, best_loss=0.799825
# iteration=522, train_loss=0.721654, test_loss=0.788519, best_loss=0.788519
# iteration=523, train_loss=0.730160, test_loss=0.796315, best_loss=0.788519
# iteration=524, train_loss=0.761552, test_loss=0.832632, best_loss=0.788519
# iteration=525, train_loss=0.710817, test_loss=0.775462, best_loss=0.775462
# iteration=526, train_loss=0.696194, test_loss=0.762169, best_loss=0.762169
# iteration=527, train_loss=0.696839, test_loss=0.761507, best_loss=0.761507
# iteration=528, train_loss=0.687694, test_loss=0.752591, best_loss=0.752591
# iteration=529, train_loss=0.677363, test_loss=0.739560, best_loss=0.739560
# iteration=530, train_loss=0.677771, test_loss=0.736475, best_loss=0.736475
# iteration=531, train_loss=0.679163, test_loss=0.745677, best_loss=0.736475
# iteration=532, train_loss=0.661790, test_loss=0.719979, best_loss=0.719979
# iteration=533, train_loss=0.653326, test_loss=0.714023, best_loss=0.714023
# iteration=534, train_loss=0.658547, test_loss=0.715589, best_loss=0.714023
# iteration=535, train_loss=0.641205, test_loss=0.699171, best_loss=0.699171
# iteration=536, train_loss=0.646218, test_loss=0.702747, best_loss=0.699171
# iteration=537, train_loss=0.632021, test_loss=0.689244, best_loss=0.689244
# iteration=538, train_loss=0.624329, test_loss=0.680350, best_loss=0.680350
# iteration=539, train_loss=0.624715, test_loss=0.682578, best_loss=0.680350
# iteration=540, train_loss=0.630204, test_loss=0.681716, best_loss=0.680350
# iteration=541, train_loss=0.634175, test_loss=0.684156, best_loss=0.680350
# iteration=542, train_loss=0.601928, test_loss=0.654859, best_loss=0.654859
# iteration=543, train_loss=0.596308, test_loss=0.651242, best_loss=0.651242
# iteration=544, train_loss=0.600527, test_loss=0.647945, best_loss=0.647945
# iteration=545, train_loss=0.589316, test_loss=0.645113, best_loss=0.645113
# iteration=546, train_loss=0.617980, test_loss=0.663787, best_loss=0.645113
# iteration=547, train_loss=0.589153, test_loss=0.636601, best_loss=0.636601
# iteration=548, train_loss=0.573743, test_loss=0.622348, best_loss=0.622348
# iteration=549, train_loss=0.559697, test_loss=0.607944, best_loss=0.607944
# iteration=550, train_loss=0.553169, test_loss=0.601455, best_loss=0.601455
# iteration=551, train_loss=0.570916, test_loss=0.615508, best_loss=0.601455
# iteration=552, train_loss=0.559390, test_loss=0.612412, best_loss=0.601455
# iteration=553, train_loss=0.537105, test_loss=0.582588, best_loss=0.582588
# iteration=554, train_loss=0.529163, test_loss=0.574195, best_loss=0.574195
# iteration=555, train_loss=0.529475, test_loss=0.573808, best_loss=0.573808
# iteration=556, train_loss=0.543072, test_loss=0.587178, best_loss=0.573808
# iteration=557, train_loss=0.510474, test_loss=0.554001, best_loss=0.554001
# iteration=558, train_loss=0.509595, test_loss=0.555437, best_loss=0.554001
# iteration=559, train_loss=0.508840, test_loss=0.550163, best_loss=0.550163
# iteration=560, train_loss=0.522535, test_loss=0.558738, best_loss=0.550163
# iteration=561, train_loss=0.485930, test_loss=0.526537, best_loss=0.526537
# iteration=562, train_loss=0.479775, test_loss=0.519271, best_loss=0.519271
# iteration=563, train_loss=0.478869, test_loss=0.519312, best_loss=0.519271
# iteration=564, train_loss=0.479943, test_loss=0.520224, best_loss=0.519271
# iteration=565, train_loss=0.472133, test_loss=0.510096, best_loss=0.510096
# iteration=566, train_loss=0.458268, test_loss=0.497334, best_loss=0.497334
# iteration=567, train_loss=0.468437, test_loss=0.501163, best_loss=0.497334
# iteration=568, train_loss=0.440999, test_loss=0.477004, best_loss=0.477004
# iteration=569, train_loss=0.448294, test_loss=0.484789, best_loss=0.477004
# iteration=570, train_loss=0.440218, test_loss=0.476133, best_loss=0.476133
# iteration=571, train_loss=0.433201, test_loss=0.465913, best_loss=0.465913
# iteration=572, train_loss=0.453937, test_loss=0.493213, best_loss=0.465913
# iteration=573, train_loss=0.419176, test_loss=0.452868, best_loss=0.452868
# iteration=574, train_loss=0.404809, test_loss=0.436422, best_loss=0.436422
# iteration=575, train_loss=0.412381, test_loss=0.441095, best_loss=0.436422
# iteration=576, train_loss=0.398513, test_loss=0.426984, best_loss=0.426984
# iteration=577, train_loss=0.435362, test_loss=0.462314, best_loss=0.426984
# iteration=578, train_loss=0.386516, test_loss=0.416708, best_loss=0.416708
# iteration=579, train_loss=0.377913, test_loss=0.406679, best_loss=0.406679
# iteration=580, train_loss=0.396853, test_loss=0.421506, best_loss=0.406679
# iteration=581, train_loss=0.371536, test_loss=0.398076, best_loss=0.398076
# iteration=582, train_loss=0.382301, test_loss=0.405720, best_loss=0.398076
# iteration=583, train_loss=0.381797, test_loss=0.412202, best_loss=0.398076
# iteration=584, train_loss=0.348155, test_loss=0.374066, best_loss=0.374066
# iteration=585, train_loss=0.343031, test_loss=0.368728, best_loss=0.368728
# iteration=586, train_loss=0.337853, test_loss=0.360750, best_loss=0.360750
# iteration=587, train_loss=0.336214, test_loss=0.358128, best_loss=0.358128
# iteration=588, train_loss=0.325046, test_loss=0.348738, best_loss=0.348738
# iteration=589, train_loss=0.317363, test_loss=0.339723, best_loss=0.339723
# iteration=590, train_loss=0.310126, test_loss=0.331016, best_loss=0.331016
# iteration=591, train_loss=0.303380, test_loss=0.324076, best_loss=0.324076
# iteration=592, train_loss=0.318301, test_loss=0.335065, best_loss=0.324076
# iteration=593, train_loss=0.300462, test_loss=0.319257, best_loss=0.319257
# iteration=594, train_loss=0.286952, test_loss=0.305626, best_loss=0.305626
# iteration=595, train_loss=0.288813, test_loss=0.307351, best_loss=0.305626
# iteration=596, train_loss=0.278088, test_loss=0.296232, best_loss=0.296232
# iteration=597, train_loss=0.276080, test_loss=0.294149, best_loss=0.294149
# iteration=598, train_loss=0.270146, test_loss=0.286484, best_loss=0.286484
# iteration=599, train_loss=0.260924, test_loss=0.277322, best_loss=0.277322
# iteration=600, train_loss=0.263036, test_loss=0.278053, best_loss=0.277322
# iteration=601, train_loss=0.267288, test_loss=0.282334, best_loss=0.277322
# iteration=602, train_loss=0.250521, test_loss=0.265453, best_loss=0.265453
# iteration=603, train_loss=0.250694, test_loss=0.265380, best_loss=0.265380
# iteration=604, train_loss=0.238086, test_loss=0.251218, best_loss=0.251218
# iteration=605, train_loss=0.235881, test_loss=0.251136, best_loss=0.251136
# iteration=606, train_loss=0.240374, test_loss=0.250355, best_loss=0.250355
# iteration=607, train_loss=0.222109, test_loss=0.235043, best_loss=0.235043
# iteration=608, train_loss=0.218272, test_loss=0.231120, best_loss=0.231120
# iteration=609, train_loss=0.213022, test_loss=0.224780, best_loss=0.224780
# iteration=610, train_loss=0.229966, test_loss=0.240080, best_loss=0.224780
# iteration=611, train_loss=0.246258, test_loss=0.256997, best_loss=0.224780
# iteration=612, train_loss=0.211283, test_loss=0.221791, best_loss=0.221791
# iteration=613, train_loss=0.203345, test_loss=0.213513, best_loss=0.213513
# iteration=614, train_loss=0.222283, test_loss=0.231039, best_loss=0.213513
# iteration=615, train_loss=0.220012, test_loss=0.228114, best_loss=0.213513
# iteration=616, train_loss=0.183230, test_loss=0.192509, best_loss=0.192509
# iteration=617, train_loss=0.179437, test_loss=0.188672, best_loss=0.188672
# iteration=618, train_loss=0.186314, test_loss=0.192229, best_loss=0.188672
# iteration=619, train_loss=0.178729, test_loss=0.188347, best_loss=0.188347
# iteration=620, train_loss=0.170750, test_loss=0.178607, best_loss=0.178607
# iteration=621, train_loss=0.165943, test_loss=0.173347, best_loss=0.173347
# iteration=622, train_loss=0.160752, test_loss=0.167282, best_loss=0.167282
# iteration=623, train_loss=0.159786, test_loss=0.166156, best_loss=0.166156
# iteration=624, train_loss=0.153480, test_loss=0.161277, best_loss=0.161277
# iteration=625, train_loss=0.154967, test_loss=0.161130, best_loss=0.161130
# iteration=626, train_loss=0.145757, test_loss=0.152766, best_loss=0.152766
# iteration=627, train_loss=0.154861, test_loss=0.160772, best_loss=0.152766
# ...
# iteration=1352, train_loss=0.052960, test_loss=0.052852, best_loss=0.011799
# iteration=1353, train_loss=0.067449, test_loss=0.065779, best_loss=0.011799
# iteration=1354, train_loss=0.051630, test_loss=0.053315, best_loss=0.011799
# iteration=1355, train_loss=0.033611, test_loss=0.033485, best_loss=0.011799
# iteration=1356, train_loss=0.013563, test_loss=0.013882, best_loss=0.011799
# iteration=1357, train_loss=0.018913, test_loss=0.020644, best_loss=0.011799
# iteration=1358, train_loss=0.028630, test_loss=0.029687, best_loss=0.011799
# iteration=1359, train_loss=0.100628, test_loss=0.096817, best_loss=0.011799
# iteration=1360, train_loss=0.029427, test_loss=0.030551, best_loss=0.011799
# iteration=1361, train_loss=0.038092, test_loss=0.039699, best_loss=0.011799
# iteration=1362, train_loss=0.022470, test_loss=0.023440, best_loss=0.011799
# iteration=1363, train_loss=0.040316, test_loss=0.039227, best_loss=0.011799
# iteration=1364, train_loss=0.025104, test_loss=0.023421, best_loss=0.011799
# iteration=1365, train_loss=0.014664, test_loss=0.015340, best_loss=0.011799
# iteration=1366, train_loss=0.018970, test_loss=0.018195, best_loss=0.011799
# iteration=1367, train_loss=0.033062, test_loss=0.034408, best_loss=0.011799
# iteration=1368, train_loss=0.032599, test_loss=0.031702, best_loss=0.011799
# iteration=1369, train_loss=0.049179, test_loss=0.050297, best_loss=0.011799
# iteration=1370, train_loss=0.021451, test_loss=0.020898, best_loss=0.011799
# iteration=1371, train_loss=0.043316, test_loss=0.044019, best_loss=0.011799
# iteration=1372, train_loss=0.014731, test_loss=0.014750, best_loss=0.011799
# iteration=1373, train_loss=0.029768, test_loss=0.030891, best_loss=0.011799
# iteration=1374, train_loss=0.065822, test_loss=0.067592, best_loss=0.011799
# iteration=1375, train_loss=0.016381, test_loss=0.015952, best_loss=0.011799
# iteration=1376, train_loss=0.047601, test_loss=0.049351, best_loss=0.011799
# iteration=1377, train_loss=0.030666, test_loss=0.029333, best_loss=0.011799
# iteration=1378, train_loss=0.014542, test_loss=0.015314, best_loss=0.011799
# iteration=1379, train_loss=0.018163, test_loss=0.018147, best_loss=0.011799
# iteration=1380, train_loss=0.035480, test_loss=0.035412, best_loss=0.011799
# iteration=1381, train_loss=0.032956, test_loss=0.033458, best_loss=0.011799
# iteration=1382, train_loss=0.029634, test_loss=0.027867, best_loss=0.011799
# iteration=1383, train_loss=0.021005, test_loss=0.021115, best_loss=0.011799
# iteration=1384, train_loss=0.019555, test_loss=0.019117, best_loss=0.011799
# iteration=1385, train_loss=0.051503, test_loss=0.047758, best_loss=0.011799
# iteration=1386, train_loss=0.057815, test_loss=0.058325, best_loss=0.011799
# iteration=1387, train_loss=0.034342, test_loss=0.034696, best_loss=0.011799
# iteration=1388, train_loss=0.014020, test_loss=0.014121, best_loss=0.011799
# iteration=1389, train_loss=0.014070, test_loss=0.014161, best_loss=0.011799
# iteration=1390, train_loss=0.030628, test_loss=0.031545, best_loss=0.011799
# iteration=1391, train_loss=0.070225, test_loss=0.070373, best_loss=0.011799
# iteration=1392, train_loss=0.052162, test_loss=0.053347, best_loss=0.011799
# iteration=1393, train_loss=0.037580, test_loss=0.037661, best_loss=0.011799
# iteration=1394, train_loss=0.062456, test_loss=0.065281, best_loss=0.011799
# iteration=1395, train_loss=0.083898, test_loss=0.080268, best_loss=0.011799
# iteration=1396, train_loss=0.027736, test_loss=0.026371, best_loss=0.011799
# iteration=1397, train_loss=0.062939, test_loss=0.065071, best_loss=0.011799
# iteration=1398, train_loss=0.053764, test_loss=0.051614, best_loss=0.011799
# iteration=1399, train_loss=0.069294, test_loss=0.066856, best_loss=0.011799
# iteration=1400, train_loss=0.021708, test_loss=0.022874, best_loss=0.011799
# iteration=1401, train_loss=0.020746, test_loss=0.021052, best_loss=0.011799
# iteration=1402, train_loss=0.030780, test_loss=0.028927, best_loss=0.011799
# iteration=1403, train_loss=0.040339, test_loss=0.037682, best_loss=0.011799
# iteration=1404, train_loss=0.018083, test_loss=0.018636, best_loss=0.011799
# iteration=1405, train_loss=0.016703, test_loss=0.017519, best_loss=0.011799
# iteration=1406, train_loss=0.016685, test_loss=0.017199, best_loss=0.011799
# iteration=1407, train_loss=0.017616, test_loss=0.018953, best_loss=0.011799
# iteration=1408, train_loss=0.017949, test_loss=0.018526, best_loss=0.011799
# iteration=1409, train_loss=0.015206, test_loss=0.015114, best_loss=0.011799
# iteration=1410, train_loss=0.015247, test_loss=0.015622, best_loss=0.011799
# iteration=1411, train_loss=0.030124, test_loss=0.030050, best_loss=0.011799
# iteration=1412, train_loss=0.054131, test_loss=0.049760, best_loss=0.011799
# iteration=1413, train_loss=0.021690, test_loss=0.020442, best_loss=0.011799
# iteration=1414, train_loss=0.130310, test_loss=0.124258, best_loss=0.011799
# iteration=1415, train_loss=0.038684, test_loss=0.038963, best_loss=0.011799
# iteration=1416, train_loss=0.047722, test_loss=0.051543, best_loss=0.011799
# iteration=1417, train_loss=0.022635, test_loss=0.022784, best_loss=0.011799
# iteration=1418, train_loss=0.022047, test_loss=0.021792, best_loss=0.011799
# iteration=1419, train_loss=0.031637, test_loss=0.032700, best_loss=0.011799
# iteration=1420, train_loss=0.061280, test_loss=0.060303, best_loss=0.011799
# iteration=1421, train_loss=0.060771, test_loss=0.061862, best_loss=0.011799
# iteration=1422, train_loss=0.022481, test_loss=0.023464, best_loss=0.011799
# iteration=1423, train_loss=0.023835, test_loss=0.023702, best_loss=0.011799
# iteration=1424, train_loss=0.020887, test_loss=0.021036, best_loss=0.011799
# iteration=1425, train_loss=0.017599, test_loss=0.018308, best_loss=0.011799
# iteration=1426, train_loss=0.044826, test_loss=0.044744, best_loss=0.011799
# iteration=1427, train_loss=0.103516, test_loss=0.102823, best_loss=0.011799
# iteration=1428, train_loss=0.091067, test_loss=0.089194, best_loss=0.011799
# iteration=1429, train_loss=0.030601, test_loss=0.031958, best_loss=0.011799
# iteration=1430, train_loss=0.038580, test_loss=0.039897, best_loss=0.011799
# iteration=1431, train_loss=0.054233, test_loss=0.055915, best_loss=0.011799
# iteration=1432, train_loss=0.030662, test_loss=0.031580, best_loss=0.011799
# iteration=1433, train_loss=0.023267, test_loss=0.024238, best_loss=0.011799
# iteration=1434, train_loss=0.013030, test_loss=0.013553, best_loss=0.011799
# iteration=1435, train_loss=0.014807, test_loss=0.015016, best_loss=0.011799
# iteration=1436, train_loss=0.018384, test_loss=0.017999, best_loss=0.011799
# iteration=1437, train_loss=0.043378, test_loss=0.043276, best_loss=0.011799
# iteration=1438, train_loss=0.057122, test_loss=0.057934, best_loss=0.011799
# iteration=1439, train_loss=0.023487, test_loss=0.025280, best_loss=0.011799
# iteration=1440, train_loss=0.016528, test_loss=0.016494, best_loss=0.011799
# iteration=1441, train_loss=0.015198, test_loss=0.015392, best_loss=0.011799
# iteration=1442, train_loss=0.012510, test_loss=0.013739, best_loss=0.011799
# iteration=1443, train_loss=0.068679, test_loss=0.068666, best_loss=0.011799
# iteration=1444, train_loss=0.030397, test_loss=0.030872, best_loss=0.011799
# iteration=1445, train_loss=0.057829, test_loss=0.058752, best_loss=0.011799
# iteration=1446, train_loss=0.050202, test_loss=0.049471, best_loss=0.011799
# iteration=1447, train_loss=0.015136, test_loss=0.016042, best_loss=0.011799
# iteration=1448, train_loss=0.015288, test_loss=0.015546, best_loss=0.011799
# iteration=1449, train_loss=0.020620, test_loss=0.020960, best_loss=0.011799
# iteration=1450, train_loss=0.017563, test_loss=0.017132, best_loss=0.011799
# iteration=1451, train_loss=0.018063, test_loss=0.017694, best_loss=0.011799
# iteration=1452, train_loss=0.012482, test_loss=0.013153, best_loss=0.011799
# iteration=1453, train_loss=0.024073, test_loss=0.025644, best_loss=0.011799
# iteration=1454, train_loss=0.059810, test_loss=0.061518, best_loss=0.011799
# iteration=1455, train_loss=0.027824, test_loss=0.029311, best_loss=0.011799
# iteration=1456, train_loss=0.021931, test_loss=0.022563, best_loss=0.011799
# iteration=1457, train_loss=0.076607, test_loss=0.079274, best_loss=0.011799
# iteration=1458, train_loss=0.109965, test_loss=0.110339, best_loss=0.011799
# iteration=1459, train_loss=0.042872, test_loss=0.042809, best_loss=0.011799
# iteration=1460, train_loss=0.015933, test_loss=0.016601, best_loss=0.011799
# iteration=1461, train_loss=0.035582, test_loss=0.034442, best_loss=0.011799
# iteration=1462, train_loss=0.014529, test_loss=0.015538, best_loss=0.011799
# iteration=1463, train_loss=0.022665, test_loss=0.022445, best_loss=0.011799
# iteration=1464, train_loss=0.028161, test_loss=0.027521, best_loss=0.011799
# iteration=1465, train_loss=0.018660, test_loss=0.018879, best_loss=0.011799
# iteration=1466, train_loss=0.039746, test_loss=0.040333, best_loss=0.011799
# iteration=1467, train_loss=0.031603, test_loss=0.032249, best_loss=0.011799
# iteration=1468, train_loss=0.023150, test_loss=0.024222, best_loss=0.011799
# iteration=1469, train_loss=0.017360, test_loss=0.017369, best_loss=0.011799
# iteration=1470, train_loss=0.092677, test_loss=0.097962, best_loss=0.011799
# iteration=1471, train_loss=0.087682, test_loss=0.091436, best_loss=0.011799
# iteration=1472, train_loss=0.047153, test_loss=0.049065, best_loss=0.011799
# iteration=1473, train_loss=0.020096, test_loss=0.021080, best_loss=0.011799
# iteration=1474, train_loss=0.014403, test_loss=0.015167, best_loss=0.011799
# iteration=1475, train_loss=0.012609, test_loss=0.013226, best_loss=0.011799
# iteration=1476, train_loss=0.041803, test_loss=0.039458, best_loss=0.011799
# iteration=1477, train_loss=0.015752, test_loss=0.016296, best_loss=0.011799
# iteration=1478, train_loss=0.022523, test_loss=0.022979, best_loss=0.011799
# iteration=1479, train_loss=0.012901, test_loss=0.012806, best_loss=0.011799
# iteration=1480, train_loss=0.018358, test_loss=0.018978, best_loss=0.011799
# iteration=1481, train_loss=0.015051, test_loss=0.014913, best_loss=0.011799
# iteration=1482, train_loss=0.011066, test_loss=0.011755, best_loss=0.011755
# iteration=1483, train_loss=0.013713, test_loss=0.013674, best_loss=0.011755
# iteration=1484, train_loss=0.034161, test_loss=0.033268, best_loss=0.011755
# iteration=1485, train_loss=0.033010, test_loss=0.035668, best_loss=0.011755
# iteration=1486, train_loss=0.011994, test_loss=0.012322, best_loss=0.011755
# iteration=1487, train_loss=0.021040, test_loss=0.021754, best_loss=0.011755
# iteration=1488, train_loss=0.114764, test_loss=0.108346, best_loss=0.011755
# iteration=1489, train_loss=0.051103, test_loss=0.047873, best_loss=0.011755
# iteration=1490, train_loss=0.059891, test_loss=0.059042, best_loss=0.011755
# iteration=1491, train_loss=0.022105, test_loss=0.021441, best_loss=0.011755
# iteration=1492, train_loss=0.017886, test_loss=0.018533, best_loss=0.011755
# iteration=1493, train_loss=0.019225, test_loss=0.020304, best_loss=0.011755
# iteration=1494, train_loss=0.025887, test_loss=0.027243, best_loss=0.011755
# iteration=1495, train_loss=0.030751, test_loss=0.032828, best_loss=0.011755
# iteration=1496, train_loss=0.016530, test_loss=0.016870, best_loss=0.011755
# iteration=1497, train_loss=0.038730, test_loss=0.040585, best_loss=0.011755
# iteration=1498, train_loss=0.044717, test_loss=0.045874, best_loss=0.011755
# iteration=1499, train_loss=0.012161, test_loss=0.012713, best_loss=0.011755
# iteration=1500, train_loss=0.018518, test_loss=0.019714, best_loss=0.011755
# iteration=1501, train_loss=0.056016, test_loss=0.056555, best_loss=0.011755
# iteration=1502, train_loss=0.021199, test_loss=0.020127, best_loss=0.011755
# iteration=1503, train_loss=0.023094, test_loss=0.023189, best_loss=0.011755
# iteration=1504, train_loss=0.046248, test_loss=0.048353, best_loss=0.011755
# iteration=1505, train_loss=0.043536, test_loss=0.041504, best_loss=0.011755
# iteration=1506, train_loss=0.033963, test_loss=0.035845, best_loss=0.011755
# iteration=1507, train_loss=0.023350, test_loss=0.024633, best_loss=0.011755
# iteration=1508, train_loss=0.026454, test_loss=0.027079, best_loss=0.011755
# iteration=1509, train_loss=0.018739, test_loss=0.019444, best_loss=0.011755
# iteration=1510, train_loss=0.028066, test_loss=0.028991, best_loss=0.011755
# iteration=1511, train_loss=0.022122, test_loss=0.023401, best_loss=0.011755
# iteration=1512, train_loss=0.015631, test_loss=0.016611, best_loss=0.011755
# iteration=1513, train_loss=0.014528, test_loss=0.015446, best_loss=0.011755
# iteration=1514, train_loss=0.040063, test_loss=0.038307, best_loss=0.011755
# iteration=1515, train_loss=0.033331, test_loss=0.035024, best_loss=0.011755
# iteration=1516, train_loss=0.050300, test_loss=0.047804, best_loss=0.011755
# iteration=1517, train_loss=0.028224, test_loss=0.029168, best_loss=0.011755
# iteration=1518, train_loss=0.034948, test_loss=0.035098, best_loss=0.011755
# iteration=1519, train_loss=0.029171, test_loss=0.032658, best_loss=0.011755
# iteration=1520, train_loss=0.031176, test_loss=0.030983, best_loss=0.011755
# iteration=1521, train_loss=0.050353, test_loss=0.047118, best_loss=0.011755
# iteration=1522, train_loss=0.078077, test_loss=0.071679, best_loss=0.011755
# iteration=1523, train_loss=0.129109, test_loss=0.130299, best_loss=0.011755
# iteration=1524, train_loss=0.096614, test_loss=0.092734, best_loss=0.011755
# iteration=1525, train_loss=0.044256, test_loss=0.047308, best_loss=0.011755
# iteration=1526, train_loss=0.039584, test_loss=0.040113, best_loss=0.011755
# iteration=1527, train_loss=0.022930, test_loss=0.022805, best_loss=0.011755
# iteration=1528, train_loss=0.016896, test_loss=0.018369, best_loss=0.011755
# iteration=1529, train_loss=0.024307, test_loss=0.024325, best_loss=0.011755
# iteration=1530, train_loss=0.017503, test_loss=0.017492, best_loss=0.011755
# iteration=1531, train_loss=0.019539, test_loss=0.020071, best_loss=0.011755
# iteration=1532, train_loss=0.019522, test_loss=0.019426, best_loss=0.011755
# iteration=1533, train_loss=0.018428, test_loss=0.017782, best_loss=0.011755
# iteration=1534, train_loss=0.025301, test_loss=0.026119, best_loss=0.011755
# iteration=1535, train_loss=0.023929, test_loss=0.025444, best_loss=0.011755
# iteration=1536, train_loss=0.025035, test_loss=0.026393, best_loss=0.011755
# iteration=1537, train_loss=0.033055, test_loss=0.031067, best_loss=0.011755
# iteration=1538, train_loss=0.013105, test_loss=0.013921, best_loss=0.011755
# iteration=1539, train_loss=0.017847, test_loss=0.017472, best_loss=0.011755
# iteration=1540, train_loss=0.016080, test_loss=0.016354, best_loss=0.011755
# iteration=1541, train_loss=0.025675, test_loss=0.026728, best_loss=0.011755
# iteration=1542, train_loss=0.013374, test_loss=0.013927, best_loss=0.011755
# iteration=1543, train_loss=0.038856, test_loss=0.039734, best_loss=0.011755
# iteration=1544, train_loss=0.015667, test_loss=0.016082, best_loss=0.011755
# iteration=1545, train_loss=0.032897, test_loss=0.033392, best_loss=0.011755
# iteration=1546, train_loss=0.026608, test_loss=0.026366, best_loss=0.011755
# iteration=1547, train_loss=0.029926, test_loss=0.030380, best_loss=0.011755
# iteration=1548, train_loss=0.029444, test_loss=0.031518, best_loss=0.011755
# iteration=1549, train_loss=0.017475, test_loss=0.017438, best_loss=0.011755
# iteration=1550, train_loss=0.016398, test_loss=0.017568, best_loss=0.011755
# iteration=1551, train_loss=0.017505, test_loss=0.018547, best_loss=0.011755
# iteration=1552, train_loss=0.037409, test_loss=0.040026, best_loss=0.011755
# iteration=1553, train_loss=0.042606, test_loss=0.044588, best_loss=0.011755
# iteration=1554, train_loss=0.054073, test_loss=0.054721, best_loss=0.011755
# iteration=1555, train_loss=0.023646, test_loss=0.023573, best_loss=0.011755
# iteration=1556, train_loss=0.044375, test_loss=0.047730, best_loss=0.011755
# iteration=1557, train_loss=0.035705, test_loss=0.036830, best_loss=0.011755
# iteration=1558, train_loss=0.027865, test_loss=0.027794, best_loss=0.011755
# iteration=1559, train_loss=0.012141, test_loss=0.012345, best_loss=0.011755
# iteration=1560, train_loss=0.009322, test_loss=0.009746, best_loss=0.009746
# CPU times: user 7min 14s, sys: 5.11 s, total: 7min 19s
# Wall time: 7min 15s

# %%
#WIZUALIZACJA BŁĘDU MSE PODCZAS UCZENIA SIECI

plt.figure(figsize=(8, 3.5), dpi=120)
plt.plot(train_error[:], 'r', label='Train loss')
plt.plot(test_error[:], 'g', label='Test loss')
plt.yscale('log')
plt.title('Błąd średniokwadratowy podczas uczenia sieci')
plt.xlabel("Epoka") 
plt.ylabel("Błąd MSE")
plt.grid()
plt.legend() 
plt.show()

# %%
#WIZUALIZACJA ZMIAN WYBRANYCH WAG PODCZAS UCZENIA SIECI

plt.figure(figsize=(8, 3.5), dpi=120)
plt.plot(w1[:])
plt.plot(w2[:])
plt.plot(w3[:])
plt.plot(w4[:])
plt.title('Wartości pewnych wag podczas uczenia sieci')
plt.xlabel("Epoka") 
plt.ylabel("Wartość wagi")
plt.grid()
plt.show()

# %%
#TEST PREDYKCJI SIECI

#Obliczenie predykcji sieci (wartość wyjściowa) na podstawie zbioru testowego
y_pred = jax.vmap(partial(equation_of_motion, learned_lagrangian(params)))(x_test)

#Wizualizacji wyników
fig, axes = plt.subplots(1, 2, figsize=(6, 3), dpi=120)
fig.suptitle("Porównanie oczekiwanych wyników z wynikami predykcji")
axes[0].scatter(y_test[:, 0], y_pred[:, 0], s=6, alpha=0.2)
axes[0].set_xlabel('oczkiwane $\dot q$')
axes[0].set_ylabel('predykcja $\dot q$')
axes[0].grid()
axes[1].scatter(y_test[:, 1], y_pred[:, 1], s=6, alpha=0.2)
axes[1].set_xlabel('oczkiwane $\ddot q$')
axes[1].set_ylabel('predykcja $\ddot q$')
axes[1].grid()
plt.tight_layout()

# %%
#OBLICZENIE BŁĘDU WZGLĘDNEGO PREDYKCJI

#Zakresy prędkości i położenia
q=jnp.arange(-1*np.pi, np.pi, 0.2, dtype=jnp.float32)
q = np.concatenate([q, jnp.array([np.pi])])
q_t=jnp.arange(-1*v_max, v_max, 0.5, dtype=jnp.float32)
q_t = np.concatenate([q_t, jnp.array([v_max])])



True_value = np.zeros([len(q), len(q_t)],dtype=jnp.float32)
Pred_value = np.zeros([len(q), len(q_t)],dtype=jnp.float32)
Error = np.zeros([len(q), len(q_t)],dtype=jnp.float32)



for i in range (len(q)):
    for j in range(len(q_t)):
        True_value[i,j] = analitical(jnp.array([q[i], q_t[j]]))[1]                #Wartość rzczywista
        Pred_value[i,j] = acceleration_learned(params, jnp.array([q[i], q_t[j]]))           #Predykcja
        Error[i,j] = np.abs(True_value[i,j]-Pred_value[i,j])/np.abs(True_value[i,j])*100    #Błąd (wartość bezwlędna z różnicy)

# %%
#WIZUALIZACJA WZGLĘDNEGO BŁĘDU PROCENTOWEGO PREDYKCJI

q, q_t = np.meshgrid(q, q_t)
Error = np.transpose(Error)

Error = np.where(Error>20, 20, Error)

#Wizualizacja
#%matplotlib qt5
fig = plt.figure()
axes = fig.add_subplot(projection='3d')

axes.set_title("Porównanie predykcji przyśpieszenia z wartością oczekiwaną")
axes.set_xlabel('q')
axes.set_ylabel('$\dot q$')
axes.set_zlabel("Błąd względny [%]")
axes.grid()

axes.plot_surface(q, q_t, Error, cmap='viridis')
plt.show()
plt.tight_layout()
# %matplotlib inline

# %%
q=jnp.arange(-1*np.pi, np.pi, 0.05, dtype=jnp.float32)
q_t=jnp.array([0,1,-2,3,-4,5], dtype=jnp.float32)


Lagrangian_true = np.zeros([len(q), len(q_t)],dtype=jnp.float32)
Lagrangian_pred = np.zeros([len(q), len(q_t)],dtype=jnp.float32)

for i in range (len(q)):
    for j in range(len(q_t)):
        Lagrangian_true[i,j] = jax.device_get(lagrangian_analitical(q[i], q_t[j], 1, 1, 9.8)).item()                #Wartość rzeczywista
        Lagrangian_pred[i,j] = jax.device_get(learned_lagrangian(params)(jnp.array([q[i]]), jnp.array([q_t[j]])))   #Predykcja




#WIZUALIZACJA
fig, axes = plt.subplots(3, 2, figsize=(20, 10), dpi=120)
for i, ax in enumerate(axes.flat):
    ax.plot(q, Lagrangian_true[:, i], 'g--', label='oczekiwane')
    ax.plot(q, Lagrangian_pred[:, i], 'r', label='LNN')
    ax.set_xlim(-1*np.pi, np.pi)
    ax.set_xlabel('q', fontsize=14)
    ax.set_ylabel('Lagrangian', fontsize=14)
    ax.set_title('$\dot q$='+str(q_t[i]), fontsize=18)
    ax.legend()
    ax.grid()
    
fig.suptitle('Porównanie oczekiwanych wartości lagrangianu z wynikami predykcji LNN', fontsize=28)


plt.tight_layout()


#Wizualizacji wyników
fig1, axes1 = plt.subplots(6, 2, figsize=(20, 15), dpi=120)

for i in range(len(q_t)):
    axes1[i,0].plot(q, Lagrangian_true[:, i],'g--')
    axes1[i,0].set_ylabel('Lagrangian', fontsize=14)
    axes1[i,0].set_xlabel('q', fontsize=14)
    axes1[i,0].set_title('Wartości oczekiwane przy $\dot q$='+str(q_t[i]), fontsize=14)
    axes1[i,0].grid()
    axes1[i,0].set_xlim(-1*np.pi, np.pi)
    axes1[i,1].plot(q, Lagrangian_pred[:, i],'r')
    axes1[i,1].set_ylabel('Lagrangian', fontsize=14)
    axes1[i,1].set_xlabel('q', fontsize=14)
    axes1[i,1].set_title('Wartości predykcji przy $\dot q$='+str(q_t[i]), fontsize=14)
    axes1[i,1].grid()
    axes1[i,1].set_xlim(-1*np.pi, np.pi)

fig1.suptitle('Porównanie oczekiwanych wartości lagrangianu z wynikami predykcji LNN', fontsize=28)
plt.tight_layout()


fig2, axes2 = plt.subplots(6, 1, figsize=(20, 15), dpi=120)


for i in range(len(q_t)):
    axes2[i].plot(q, Lagrangian_pred[:, i],'r')
    axes2[i].plot(q+2*np.pi, Lagrangian_pred[:, i],'r')
    axes2[i].set_ylabel('Lagrangian', fontsize=14)
    axes2[i].set_xlabel('q', fontsize=14)
    axes2[i].set_title('Wartości predykcji przy $\dot q$='+str(q_t[i]), fontsize=14)
    axes2[i].grid()
    axes2[i].set_xlim(-1*np.pi, 3*np.pi)

fig2.suptitle('Wykres modelowanego Lagrangianu dla zakresu $q\in(-\Pi, 3\Pi)$', fontsize=28)
plt.tight_layout()

# %%
#TEST WYZNACZENIA TRAJEKTORI RUCHU PRZY UŻYCIU SIECI NEURONOWEJ

#Punkt startowy
x0 = jnp.array([-3/2*np.pi/2,0], dtype=np.float32)
#Wektor czasu
t = np.linspace(0, 40, num=401, dtype=np.float32)

#Wyznaczenie trajektori przy użyciu sieci
# %time lagrangian_trajectory = jax.device_get(solve_lagrangian(params, x0, t))
lagrangian_trajectory = jax.device_get(jax.vmap(normalize)(lagrangian_trajectory))

#Wyznaczenie trajektori metodą analityczną
# %time analitical_trajectory = jax.device_get(solve_analitical(x0, t))


#WIZUALIZACJA
fig, axes = plt.subplots(1, 2, figsize=(10, 5), dpi=120)
fig.suptitle('Porównanie trajektorii ruchu otrzymanych przy użyciu metody analitycznej i LNN')


axes[0].plot(t, analitical_trajectory[:, 0], 'r', label='analityczne')
axes[0].plot(t, lagrangian_trajectory[:, 0], 'g--', label='LNN')
axes[0].set_xlabel('t')
axes[0].set_ylabel('$q$')
axes[0].legend()
axes[0].grid()
axes[0].axis([0,t[-1],-1*np.pi,np.pi])


axes[1].plot(t, analitical_trajectory[:, 1], 'r', label='analityczne')
axes[1].plot(t, lagrangian_trajectory[:, 1], 'g--', label='LNN')
axes[1].set_xlabel('t')
axes[1].set_ylabel('$\dot q$')
axes[1].grid()

plt.tight_layout()
# Out:
# CPU times: user 2.04 s, sys: 9.98 ms, total: 2.05 s
# Wall time: 2.04 s
# CPU times: user 1.02 ms, sys: 19 µs, total: 1.04 ms
# Wall time: 1.04 ms

# %%
#Wyznaczenie Energi potencjalnej i kinetycznej trajektorii

q, q_t = jnp.hsplit(lagrangian_trajectory, 2)
energy = partial(compute_energy, m=1, l=1, g=9.81)
Ep, Ek = jax.vmap(energy)(q, q_t)
Ec=Ep+Ek
mean = jnp.mean(Ec)
mean_Ec = jnp.ones(Ec.shape, dtype=jnp.float32) * jnp.mean(Ec)

plt.figure(figsize=(8, 3.5), dpi=120)
plt.plot(mean_Ec, 'r--', label="Średnia energia całkowita układu")
plt.plot(Ec, label="Energia całkowita układu")
plt.plot(Ep, label="Energia potencjalna układu")
plt.plot(Ek, label="Energia kinetyczna układu")
plt.title('Zmiany energii układu w czasie')
plt.xlabel("t [s]") 
plt.ylabel("Energia [J]")
plt.legend()
plt.grid()
plt.show()
