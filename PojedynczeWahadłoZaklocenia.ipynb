# %%
#imports
import math
import jax
import jax.numpy as jnp
from jax.experimental.ode import odeint
import numpy as np
from functools import partial
import matplotlib.pyplot as plt
from jax.example_libraries import stax
from jax.example_libraries import optimizers
import random as rd
import pickle
import os

# %%
#METODA AUTOGRAD

#Definicja Lagrangianu dla pojedynńczego wachadła liczonego w sposób analityczny
#Argumenty funkcji:
#  -q   - położenie ciała
#  -q_t - prędkość ciała
#  -m   - masa ciała
#  -l   - długość liny
#  -g   - wartość przyśpieszenia ziemskiego
#Zwracane: wartość Lagrangianu w danym momencie.
def lagrangian_analitical(q, q_t, m, l, g):
    #Eneriga kinetyczna
    Ek=0.5*m*l*jnp.square(q_t)
    
    #Energia potencjalna
    Ep=m*g*(l-l*jnp.cos(q))
    
    #Lagrangian
    return jnp.sum(Ek - Ep)

#Obliczenie energi potencjalnej i kinetycznej układu na podstawie aktualnego stanu
#Argumenty funkcji:
#  -q   - położenie ciała
#  -q_t - prędkość ciała
#  -m   - masa ciała
#  -l   - długość liny
#  -g   - wartość przyśpieszenia ziemskiego
#Zwracane: 
#  -Ek  - Energia kinetyczna
#  -Ep  - Energia potencjalna
def compute_energy(q, q_t, m, l, g):
    #Eneriga kinetyczna
    Ek=0.5*m*l*jnp.square(q_t)
    
    #Energia potencjalna
    Ep=m*g*(l-l*jnp.cos(q))
    
    #Lagrangian
    return Ek, Ep

#Funkcja ma za zadanie reprezenotwanie równania różniczkowego, wynikającego z rozwiązania
#równanie Eulera-Lagrange'a
#Argumenty funkcji:
#   -lagrangian - Funkcja opisująca Lagrangian. Funkcja musi być typu ,,callable'' żeby,
#                 pochodne Lagrangianu zostały policzone.
#   -state      - Wektor zawierający wartości początkowe położenia i prędkości
#   -empty      - Aby ta funkcja mogła zostać poprawnie wywoływana w dalszej części programu
#                 koniecznym było dodanie ,,pustego'' argumentu, które nie będzie pełnił żadnej
#                 funkcji, ale pozwoli na poprawną kompilację
#Zwracane: Wektor zawiercający przyśpieszenia oraz prędkości w danym momencie.
def equation_of_motion(lagrangian, state, empty=None):
    #Rozdzilenie danych startowych na położenia i prędkości
    q, q_t = jnp.split(state, 2)
    #Obliczanie przyśpieszenia na podstawie lagrangianu
    q_tt = jax.numpy.linalg.pinv(jax.hessian(lagrangian, 1)(q, q_t)) @ (
		jax.grad(lagrangian, 0)(q, q_t)
		- jax.jacfwd(jax.grad(lagrangian, 1), 0)(q, q_t) @ q_t)
    return jnp.concatenate([q_t, q_tt])

#Funkcja wyznaczająca trajektorię ruchu przy użyciu Lagrangianu wyznaczonego
#w sposób analityczny
#Argumenty funkcji:
#   -initial_state - Początkowego położenie oraz prędkości
#   -times         - Czas wyznaczanej trajektori
#   -m             - masa wachadła
#   -l             - długość liny wachadła
#   -g             - przyśpieszenie ziemskie
#Zwraca:
#   Wektor trajektori ruchu w zależności od czasu
@partial(jax.jit, backend='cpu')
def solve_autograd(initial_state, times, m=1, l=1, g=9.8):
  lagrangian = partial(lagrangian_analitical, m=m, l=l, g=g)
  equation = partial(equation_of_motion, lagrangian)
  return odeint(equation, initial_state, times, rtol=1e-10, atol=1e-10)

# %%
#METODA ANALICTYCZNA

#Funkcja obliczająca przyśpieszenie wahadła na podstawie aktualnego położenia i prędkości.
#Argumenty funkcji:
#   -initial_state - Początkowego położenie oraz prędkości
#   -empty         - Aby ta funkcja mogła zostać poprawnie wywoływana w dalszej części programu
#                   koniecznym było dodanie ,,pustego'' argumentu, które nie będzie pełnił żadnej
#                   funkcji, ale pozwoli na poprawną kompilację
#   -l             - długość liny wachadła
#   -g             - przyśpieszenie ziemskie
#Zwraca:
#   Wektor trajektori ruchu w zależności od czasu
def analitical(initial_state, empty=None, l=1, g=9.8):
    q = initial_state[0]
    q_t = initial_state[1]
    q_tt = -g / l * jnp.sin(q)
    return jnp.concatenate((jnp.expand_dims(q_t, axis=0), jnp.expand_dims(q_tt, axis=0)), axis=0)

#Funkcja wyznaczająca trajektorię ruchu obliczoną przy użyciu analitycznie wyznaczonego 
# równiania różniczkowego (funkcja analitical)
#Argumenty funkcji:
#   -initial_state - Początkowego położenie oraz prędkości
#   -times         - Czas wyznaczanej trajektori
#   -l             - długość liny wachadła
#   -g             - przyśpieszenie ziemskie
#Zwraca:
#   Wektor trajektori ruchu w zależności od czasu
@partial(jax.jit, backend='cpu')
def solve_analitical(initial_state, times, l=1, g=9.8):
    function = partial(analitical, l=l, g=g)
    return odeint(function, initial_state, t=times, rtol=1e-10, atol=1e-10)

# %%
#WYZNACZENIE PUNKTU STARTOWEGO, SZUMU, ORAZ CZASU DLA TESTU POWYŻSZYCH METOD WYZNACZANIA TRAJEKTORI

#Punkt startowy
x0 = jnp.array([0.5,0.2], dtype=np.float32)
#Szum
noise = np.random.RandomState(0).randn(x0.size)
#Wektor czasów
t = np.linspace(0, 40, num=401, dtype=np.float32)

# %%
#WYZNACZENIE TRAJEKTORI METODĄ AUTOGRAD ORAZ ANALITYCZNĄ

#Autograd
# %time autograd_clean = jax.device_get(solve_autograd(x0, t))
#Autograd z małym szumem
# %time autograd_noise1 = jax.device_get(solve_autograd(x0 + 1e-10*noise, t))
#Autograd z dużym szumem
# %time autograd_noise2 = jax.device_get(solve_autograd(x0 + 1e-2*noise, t))

#Analitycznie
# %time analitical_clean = jax.device_get(solve_analitical(x0, t))
#Analitycznie z małym szumem
# %time analitical_noise1 = jax.device_get(solve_analitical(x0 + 1e-10*noise, t))
#Analitycznie z dużym szumem
# %time analitical_noise2 = jax.device_get(solve_analitical(x0 + 1e-2*noise, t))
# Out:
# CPU times: user 762 ms, sys: 9.87 ms, total: 771 ms
# Wall time: 761 ms
# CPU times: user 5.02 ms, sys: 0 ns, total: 5.02 ms
# Wall time: 3.46 ms
# CPU times: user 1.22 ms, sys: 0 ns, total: 1.22 ms
# Wall time: 1.24 ms
# CPU times: user 435 ms, sys: 0 ns, total: 435 ms
# Wall time: 430 ms
# CPU times: user 1.27 ms, sys: 0 ns, total: 1.27 ms
# Wall time: 1.26 ms
# CPU times: user 941 µs, sys: 0 ns, total: 941 µs
# Wall time: 947 µs

# %%
#WYŚWIETLENIE TRAJEKTORI (AUTOGRAD)

fig, axes = plt.subplots(1, 2, figsize=(10, 5), dpi=120)

fig.suptitle("Wpływ zakłóceń na trajektorie ruchu wyznaczoną przy użyciu funkcji autograd")

#Położenie (kąt)
axes[0].plot(t, autograd_clean[:, 0], 'r', label='noise=0')
axes[0].plot(t, autograd_noise1[:, 0], 'g--', label='noise=1e-10')
axes[0].plot(t, autograd_noise2[:, 0], 'b.', label='noise=1e-2')
axes[0].set_xlabel('t')
axes[0].set_ylabel('$q$')
axes[0].legend()
axes[0].grid()

#Prędkość (kątowa)
axes[1].plot(t, autograd_clean[:, 1], 'r', label='noise=0')
axes[1].plot(t, autograd_noise1[:, 1], 'g--', label='noise=1e-10')
axes[1].plot(t, autograd_noise2[:, 1], 'b.', label='noise=1e-2')
axes[1].set_xlabel('t')
axes[1].set_ylabel('$\dot q$')
axes[1].legend()
axes[1].grid()

plt.tight_layout()

# %%
#WYŚWIETLENIE TRAJEKTORI (METODA ANALITYCZNA)

fig, axes = plt.subplots(1, 2, figsize=(10, 5), dpi=120)
fig.suptitle('Wpływ zakłóceń na trajektorie ruchu wyznaczoną przy użyciu rozwiązania analitycznego')

#Położenie (kąt)
axes[0].plot(t, analitical_clean[:, 0], 'r', label='noise=0')
axes[0].plot(t, analitical_noise1[:, 0], 'g--', label='noise=1e-10')
axes[0].plot(t, analitical_noise2[:, 0], 'b.', label='noise=1e-2')
axes[0].set_xlabel('t')
axes[0].set_ylabel('$q$')
axes[0].legend()
axes[0].grid()

#Prędkość (kątowa)
axes[1].plot(t, analitical_clean[:, 1], 'r', label='noise=0')
axes[1].plot(t, analitical_noise1[:, 1], 'g--', label='noise=1e-10')
axes[1].plot(t, analitical_noise2[:, 1], 'b.', label='noise=1e-2')
axes[1].set_xlabel('t')
axes[1].set_ylabel('$\dot q$')
axes[1].grid()

plt.tight_layout()

# %%
#PORÓWNANIE TRAJEKTORI OTRZYMANYCH PRZY UŻYCIU OBU METOD

fig, axes = plt.subplots(1, 2, figsize=(10, 5), dpi=120)
fig.suptitle('Porównanie trajektori ruchu otrzymanych metodą analityczną i metodą autograd')


#Położenie (kąt)
axes[0].plot(t, analitical_clean[:, 0], 'r', label='analityczne')
axes[0].plot(t, autograd_clean[:, 0], 'g--', label='autograd')
axes[0].set_xlabel('t')
axes[0].set_ylabel('$q$')
axes[0].legend()
axes[0].grid()

#Prędkość (kątowa)
axes[1].plot(t, analitical_clean[:, 1], 'r', label='analityczne')
axes[1].plot(t, autograd_clean[:, 1], 'g--', label='autograd')
axes[1].set_xlabel('t')
axes[1].set_ylabel('$\dot q$')
axes[1].grid()


plt.tight_layout()

# %%
#Funkcja normalizująca wektor stanu (położenie i prędkość). W przypadku położenia wartości 
#normalizowane są do zakresów <-Pi;Pi>. W przypadku prędkości wartości pozostają bez zmian.
#Argumenty:
#   state - wektor stanu [położenie, prędkość].
#Zwraca:
#   Unormowany wektor stanu.
def normalize(state):
    dim = int(len(state)/2)
    return jnp.concatenate([(state[:dim] + np.pi) % (2 * np.pi) - np.pi, state[dim:]])

# %%
#BUDOWA ZBIORU UCZĄCEGO NA PODSTAWIE TRAJEKTORI WACHADŁA
N=1000

#Wektor punktów początkowych (3 warianty do testu)
x0 = jnp.array([[0.1,0.1], [0.5,0.2], [0.3, 0.3]], dtype=np.float32)

#Wektor czasów dla zbioru uczącego
t_train = np.arange(0,N, dtype=np.float32)
#Wektor czasów dla zbioru testowego
t_test = np.arange(N,2*N, dtype=np.float32)


fig, axes = plt.subplots(1, 2, figsize=(6, 3), dpi=120)

#Wyznaczenie 3 różnych zbiorów uczących na podstawie trajektori
#o różnych punktach startowych.
for i in range(x0.shape[0]):

    #Zbiór uczący
    x_train = jax.device_get(solve_analitical(x0[i], t_train))  #Dane wejściowe zbudowane na podstawie trajektori
    x_train = jax.device_get(jax.vmap(normalize)(x_train))      #Normalizacja danych wejściowych
    y_train = jax.device_get(jax.vmap(analitical)(x_train))     #Wyznaczenie danych wyjściowych (przyśpieszenie dla danych wektorów stanu [położenie, prędkość])

    #Zbiór testowy
    x_test = jax.device_get(solve_analitical(x_train[-1], t_train)) #Dane wejściowe zbudowane na podstawie trajektori
    x_test = jax.device_get(jax.vmap(normalize)(x_test))            #Normalizacja danych wejściowych
    y_test = jax.device_get(jax.vmap(analitical)(x_test))           #Wyznaczenie danych wyjściowych (przyśpieszenie dla danych wektorów stanu [położenie, prędkość])

    #Wyświetlenie wartość wejściowych na wykresie
    axes[0].scatter(x_train[:, 0], x_train[:, 1], s=6, alpha=1)
    axes[1].scatter(x_test[:, 0], x_test[:, 1], s=6, alpha=1)


#Wykres
fig.suptitle("Analiza punktów w zbiorach uczących i testowych")
axes[0].set_xlabel('q')
axes[0].set_ylabel('$\dot q$')
axes[0].set_title('Zbiór uczący')
axes[0].grid()
axes[1].set_xlabel('q')
axes[1].set_ylabel('$\dot q$')
axes[1].set_title('Zbiór testowy')
axes[1].grid()
fig.legend(['$q_0$=0.1, $\dot q_0$=0.1','$q_0$=0.5, $\dot q_0$=0.2', '$q_0$=0.3, $\dot q_0$=0.3'],fontsize="8", loc='lower center')
plt.tight_layout()

# %%
#BUDOWA ZBIORU UCZĄCEGO I TESTOWEGO NA PODSTAWIE WARTOŚCI LOSOWYCH

N=1000  #Liczność zbioru testowego i uczącego

#Maksymalne wartości prędkości w zbiorze
v_max=2*np.sqrt(9.81)

x_test_train = np.zeros([2*N, 2])
#Wyznaczenie losowych wartości położenia i prędkości 
x_test_train[:,0] = np.random.rand(N*2)*2*np.pi - np.pi  #Zakres wartości położenia <-Pi;Pi>
x_test_train[:,1] = np.random.rand(N*2)*2*v_max - v_max  #Zakres wartości <-Vmax;Vmax>
#Obliczenie wartości wyjściowych (przyśpieszenia) dla otrzymanych losowych punktów położenia i prędkości
#przy użyciu równania różniczkowego otrzymanego w sposób analityczny 
y_test_train = jax.device_get(jax.vmap(analitical)(x_test_train))

#Rozbicie zbioru na uczący i testowy
x_train = x_test_train[0:N]
y_train_np = y_test_train[0:N]

x_test = x_test_train[N:2*N]
y_test = y_test_train[N:2*N]


#Zakłocenia
E=0
Var=0.1

noise = np.sqrt(Var)*np.random.RandomState(0).randn(int(y_train_np.size/2))+E
y_train=np.array(y_train_np)
y_train[:,1]+=noise

# %%
#WIZUALIZACJA ZBIORU DANYCH

fig, axes = plt.subplots(1, 2, figsize=(6, 3), dpi=120)
fig.suptitle("Analiza punktów w zbiorach uczących i testowych")
axes[0].scatter(x_train[:, 0], x_train[:, 1], s=6)
axes[0].set_xlabel('q')
axes[0].set_ylabel('$\dot q$')
axes[0].set_title('Zbiór uczący')
axes[0].grid()
axes[1].scatter(x_test[:, 0], x_test[:, 1], s=6)
axes[1].set_xlabel('q')
axes[1].set_ylabel('$\dot q$')
axes[1].set_title('Zbiór testowy')
axes[1].grid()
plt.tight_layout()

# %%
#ARCHITEKUTRA SIECI NEURONOWEJ
init_random_params, nn_forward_fn = stax.serial(
    stax.Dense(64),
    stax.Softplus,
    stax.Dense(64),
    stax.Softplus,
    stax.Dense(1),
)

#Funkcja modelująca lagrangian (wyjście sieci neuronowej)
#Argumenty:
#   params - parametry sieci neuronowej
#   q, q_t - wektor wartości wejściowych dla sieci (położenie, przyśpieszenie)
#Zwraca:
#   lagrangian - wartość lagrangianu dla danego wektora stanu
def learned_lagrangian(params):
  def lagrangian(q, q_t):
    assert q.shape == (1,)
    state = normalize(jnp.concatenate([q, q_t]))
    return jnp.squeeze(nn_forward_fn(params, state), axis=-1)
  return lagrangian

#Funkcja wyznaczająca trajektorię ruchu przy użyciu Lagrangianu zamodlowanego za pomocą sieci neuronowej
#Argumenty funkcji:
#   -params        - Parametry sieci neuronowej
#   -initial_state - Początkowego położenie oraz prędkości
#   -times         - Czas wyznaczanej trajektori
#Zwraca:
#   Wektor trajektori ruchu w zależności od czasu
@partial(jax.jit, backend='cpu')
def solve_lagrangian(params, initial_state, times):
  return odeint(partial(equation_of_motion, learned_lagrangian(params)),
                  initial_state, times, rtol=1e-10, atol=1e-10)
  
  
#Funkcja ma za zadanie obliczenie przyśpieszenia na podstawie aktualnego stanu
#(położenie i przyśpieszenie) przy użyciu lagrangianu zamodelowanego przez sieć LNN.
#Argumenty funkcji:
#   -params     - Parametry sieci.
#   -state      - Wektor zawierający wartości początkowe położenia i prędkości [q, q_t].
#Zwracane:  Przyśpieszenie wynikającego z aktulanego wektora stanu.  
def acceleration_learned(params, initial_state):
  acc = partial(equation_of_motion, learned_lagrangian(params))
  return acc(initial_state)[1]


#DEFINICJA BŁĘDU DLA SIECI
#Argumenty:
#   params  - parametry sieci neuronowej
#   state   - wektor stanu [położenie, prędkość]
#   target  - oczekiwany wektor wyjściowy sieci [prędkość, przyśpieszenie]
@partial(jax.jit, backend='cpu')
def MSE_loss(params, state, targets):
  preds = jax.vmap(partial(equation_of_motion, learned_lagrangian(params)))(state)
  return jnp.mean((preds[:,1] - targets[:,1]) ** 2)


#Funkcja zamieniająca losowe elementy 2 wektorów w ten sam sposób.
#Argumenty:
#   a, b - Wektory, które mają zostać przemieszane.
#Zawracane:
#   a, b - Przetasowane wektory.
def shuffle(a, b):
    assert len(a) == len(b)
    p = np.random.permutation(a.shape[0])
    return a[p], b[p]

# %%
# %%time
#UCZENIE SIECI NEURONOWEJ



Training=True      #Uczenie sieci
Epochs=2000       #Maksymalna liczba epok
StopError=0.01      #Wartość błędu MSE dla zbioru testowego, przy której uczenie zostanie szybciej zakończone
#!!!!WAZNE - STOP ERROR MAX 0.005, PONIZEJ PRZEUCZENIE
Learning_rate=1e-2  #Współczynnik uczenia
Batch_size= 64


train_error=[]      #Wektor błędów MSE dla zbioru uczącego
test_error=[]       ##Wektor błędów MSE dla zbioru testowego

#Wektory wag
w1=[]
w2=[]
w3=[]
w4=[]

#Ścieżka dla pliku przechowującego parametry sieci
config = {"ckpt_path": "Checkpoints"}

#Inicjalizacja parametrów sieci
rng = jax.random.PRNGKey(0)
output_shape, params_initial = init_random_params(rng, (-1, 2))

#Wybór optymalizotra sieci ADAM
init, update, get_params = optimizers.adam(step_size=Learning_rate)
update = jax.jit(update)
get_params = jax.jit(get_params)


#Wykonanie uczenia sieci
if(Training):

    best_error = float('inf')

    opt_state = init(params_initial)
    for i in range(Epochs):
        #Realizacja minibatcha
        x_train, y_train = shuffle(x_train, y_train)
        start=0
        while start < x_train.shape[0]:
            #Podział danych na batche
            end = start+Batch_size
            if end > x_train.shape[0]:
                end = x_train.shape[0]
            x_batch = x_train[start:end, :]
            y_batch = y_train[start:end, :]

            #Obliczenie błędu MSE i optymalizacja wag
            params = get_params(opt_state)
            grad = jax.grad(MSE_loss)(params, x_batch, y_batch)
            opt_state = update(i, grad, opt_state)

            start += Batch_size


        #Zapisanie błędu na podstawie zbioru uczącego i testowego w każdej epoce
        train_error.append(MSE_loss(params, x_train, y_train))
        test_error.append(MSE_loss(params, x_test, y_test))

        #Zapamiętywanie najlepszych parametrów sieci
        if test_error[-1]<best_error:
            best_error = test_error[-1]
            best_params = params

        #Zapisywanie pewnych wag
        w1.append(params[2][0][1][2])
        w2.append(params[0][1][2])
        w3.append(params[2][0][1][3])
        w4.append(params[0][1][1])

        #Wcześciejsze kończenie uczenia
        if test_error[-1]<=StopError:
            print(f"iteration={i}, train_loss={train_error[-1]:.6f}, test_loss={test_error[-1]:.6f}, best_loss={best_error:.6f}")
            break

        #Wyświetlanie informacji o postępie uczenia
        if i%1==0:
            print(f"iteration={i}, train_loss={train_error[-1]:.6f}, test_loss={test_error[-1]:.6f}, best_loss={best_error:.6f}")
    
    #Wybór najlepszych parametrów
    params = best_params

    #Zapisanie parametrów do pliku
    pickle.dump(params, open(os.path.join(config["ckpt_path"], "PojedynczeWahadloZaklocenia.pkl"), "wb"))

#Brak uczenia - odczyt parametrów z pliku
else:
    params = pickle.load(open(os.path.join(config["ckpt_path"], "PojedynczeWahadloZaklocenia.pkl"), "rb"))
    #opt_state = optimizers.pack_optimizer_state(params)
# Out:
# iteration=0, train_loss=79.876381, test_loss=83.137352, best_loss=83.137352
# iteration=1, train_loss=75.948441, test_loss=78.831924, best_loss=78.831924
# iteration=2, train_loss=72.883362, test_loss=75.501282, best_loss=75.501282
# iteration=3, train_loss=70.793533, test_loss=73.237144, best_loss=73.237144
# iteration=4, train_loss=69.284172, test_loss=71.602875, best_loss=71.602875
# iteration=5, train_loss=68.076454, test_loss=70.304100, best_loss=70.304100
# iteration=6, train_loss=67.006050, test_loss=69.152237, best_loss=69.152237
# iteration=7, train_loss=66.083000, test_loss=68.162376, best_loss=68.162376
# iteration=8, train_loss=65.262840, test_loss=67.287781, best_loss=67.287781
# iteration=9, train_loss=64.457298, test_loss=66.425735, best_loss=66.425735
# iteration=10, train_loss=63.658230, test_loss=65.574066, best_loss=65.574066
# iteration=11, train_loss=62.814449, test_loss=64.674088, best_loss=64.674088
# iteration=12, train_loss=61.841187, test_loss=63.635830, best_loss=63.635830
# iteration=13, train_loss=60.725082, test_loss=62.454010, best_loss=62.454010
# iteration=14, train_loss=59.401863, test_loss=61.051357, best_loss=61.051357
# iteration=15, train_loss=57.813564, test_loss=59.373196, best_loss=59.373196
# iteration=16, train_loss=55.929573, test_loss=57.380253, best_loss=57.380253
# iteration=17, train_loss=53.740040, test_loss=55.064220, best_loss=55.064220
# iteration=18, train_loss=51.301689, test_loss=52.489922, best_loss=52.489922
# iteration=19, train_loss=48.638165, test_loss=49.689060, best_loss=49.689060
# iteration=20, train_loss=45.841831, test_loss=46.744217, best_loss=46.744217
# iteration=21, train_loss=42.876507, test_loss=43.623516, best_loss=43.623516
# iteration=22, train_loss=39.905415, test_loss=40.507805, best_loss=40.507805
# iteration=23, train_loss=36.914761, test_loss=37.371555, best_loss=37.371555
# iteration=24, train_loss=34.057228, test_loss=34.390972, best_loss=34.390972
# iteration=25, train_loss=31.303381, test_loss=31.525459, best_loss=31.525459
# iteration=26, train_loss=28.687510, test_loss=28.822306, best_loss=28.822306
# iteration=27, train_loss=26.256126, test_loss=26.330154, best_loss=26.330154
# iteration=28, train_loss=23.997702, test_loss=24.033907, best_loss=24.033907
# iteration=29, train_loss=21.888824, test_loss=21.905813, best_loss=21.905813
# iteration=30, train_loss=19.949238, test_loss=19.961855, best_loss=19.961855
# iteration=31, train_loss=18.054045, test_loss=18.075619, best_loss=18.075619
# iteration=32, train_loss=16.304255, test_loss=16.343460, best_loss=16.343460
# iteration=33, train_loss=14.680449, test_loss=14.740316, best_loss=14.740316
# iteration=34, train_loss=13.124846, test_loss=13.210217, best_loss=13.210217
# iteration=35, train_loss=11.733647, test_loss=11.837688, best_loss=11.837688
# iteration=36, train_loss=10.483167, test_loss=10.599802, best_loss=10.599802
# iteration=37, train_loss=9.411797, test_loss=9.528268, best_loss=9.528268
# iteration=38, train_loss=8.530141, test_loss=8.622493, best_loss=8.622493
# iteration=39, train_loss=7.822784, test_loss=7.898181, best_loss=7.898181
# iteration=40, train_loss=7.294038, test_loss=7.334356, best_loss=7.334356
# iteration=41, train_loss=6.831079, test_loss=6.844876, best_loss=6.844876
# iteration=42, train_loss=6.428450, test_loss=6.417551, best_loss=6.417551
# iteration=43, train_loss=6.074349, test_loss=6.054725, best_loss=6.054725
# iteration=44, train_loss=5.764016, test_loss=5.729357, best_loss=5.729357
# iteration=45, train_loss=5.468344, test_loss=5.423522, best_loss=5.423522
# iteration=46, train_loss=5.202639, test_loss=5.155943, best_loss=5.155943
# iteration=47, train_loss=4.946754, test_loss=4.890063, best_loss=4.890063
# iteration=48, train_loss=4.725325, test_loss=4.660559, best_loss=4.660559
# iteration=49, train_loss=4.507334, test_loss=4.439272, best_loss=4.439272
# iteration=50, train_loss=4.293709, test_loss=4.223616, best_loss=4.223616
# iteration=51, train_loss=4.100019, test_loss=4.025003, best_loss=4.025003
# iteration=52, train_loss=3.901249, test_loss=3.827996, best_loss=3.827996
# iteration=53, train_loss=3.722721, test_loss=3.647297, best_loss=3.647297
# iteration=54, train_loss=3.559992, test_loss=3.480643, best_loss=3.480643
# iteration=55, train_loss=3.411182, test_loss=3.337219, best_loss=3.337219
# iteration=56, train_loss=3.276990, test_loss=3.200583, best_loss=3.200583
# iteration=57, train_loss=3.163855, test_loss=3.084739, best_loss=3.084739
# iteration=58, train_loss=3.051170, test_loss=2.969532, best_loss=2.969532
# iteration=59, train_loss=2.952289, test_loss=2.875457, best_loss=2.875457
# iteration=60, train_loss=2.856296, test_loss=2.774426, best_loss=2.774426
# iteration=61, train_loss=2.771921, test_loss=2.683097, best_loss=2.683097
# iteration=62, train_loss=2.687310, test_loss=2.601956, best_loss=2.601956
# iteration=63, train_loss=2.613702, test_loss=2.518162, best_loss=2.518162
# iteration=64, train_loss=2.515860, test_loss=2.427359, best_loss=2.427359
# iteration=65, train_loss=2.431972, test_loss=2.336309, best_loss=2.336309
# iteration=66, train_loss=2.341716, test_loss=2.241310, best_loss=2.241310
# iteration=67, train_loss=2.249711, test_loss=2.159509, best_loss=2.159509
# iteration=68, train_loss=2.153676, test_loss=2.057159, best_loss=2.057159
# iteration=69, train_loss=2.065693, test_loss=1.970488, best_loss=1.970488
# iteration=70, train_loss=1.980437, test_loss=1.888387, best_loss=1.888387
# iteration=71, train_loss=1.894966, test_loss=1.804925, best_loss=1.804925
# iteration=72, train_loss=1.825804, test_loss=1.736553, best_loss=1.736553
# iteration=73, train_loss=1.757816, test_loss=1.671590, best_loss=1.671590
# iteration=74, train_loss=1.685559, test_loss=1.599242, best_loss=1.599242
# iteration=75, train_loss=1.622386, test_loss=1.545031, best_loss=1.545031
# iteration=76, train_loss=1.578257, test_loss=1.490815, best_loss=1.490815
# iteration=77, train_loss=1.526034, test_loss=1.451040, best_loss=1.451040
# iteration=78, train_loss=1.460986, test_loss=1.388261, best_loss=1.388261
# iteration=79, train_loss=1.420112, test_loss=1.346060, best_loss=1.346060
# iteration=80, train_loss=1.376260, test_loss=1.305123, best_loss=1.305123
# iteration=81, train_loss=1.327998, test_loss=1.259518, best_loss=1.259518
# iteration=82, train_loss=1.288090, test_loss=1.221085, best_loss=1.221085
# iteration=83, train_loss=1.252072, test_loss=1.184944, best_loss=1.184944
# iteration=84, train_loss=1.220195, test_loss=1.156771, best_loss=1.156771
# iteration=85, train_loss=1.182846, test_loss=1.120395, best_loss=1.120395
# iteration=86, train_loss=1.151375, test_loss=1.088083, best_loss=1.088083
# iteration=87, train_loss=1.125337, test_loss=1.064312, best_loss=1.064312
# iteration=88, train_loss=1.091415, test_loss=1.034602, best_loss=1.034602
# iteration=89, train_loss=1.063888, test_loss=1.008588, best_loss=1.008588
# iteration=90, train_loss=1.037593, test_loss=0.983102, best_loss=0.983102
# iteration=91, train_loss=1.013003, test_loss=0.958489, best_loss=0.958489
# iteration=92, train_loss=0.994580, test_loss=0.949970, best_loss=0.949970
# iteration=93, train_loss=0.969841, test_loss=0.916182, best_loss=0.916182
# iteration=94, train_loss=0.946417, test_loss=0.891281, best_loss=0.891281
# iteration=95, train_loss=0.934203, test_loss=0.896174, best_loss=0.891281
# iteration=96, train_loss=0.905156, test_loss=0.858153, best_loss=0.858153
# iteration=97, train_loss=0.890408, test_loss=0.842822, best_loss=0.842822
# iteration=98, train_loss=0.863851, test_loss=0.817997, best_loss=0.817997
# iteration=99, train_loss=0.857994, test_loss=0.821242, best_loss=0.817997
# iteration=100, train_loss=0.844850, test_loss=0.812949, best_loss=0.812949
# iteration=101, train_loss=0.813355, test_loss=0.770597, best_loss=0.770597
# iteration=102, train_loss=0.797540, test_loss=0.756279, best_loss=0.756279
# iteration=103, train_loss=0.786711, test_loss=0.755179, best_loss=0.755179
# iteration=104, train_loss=0.787758, test_loss=0.760088, best_loss=0.755179
# iteration=105, train_loss=0.754301, test_loss=0.722518, best_loss=0.722518
# iteration=106, train_loss=0.741452, test_loss=0.704324, best_loss=0.704324
# iteration=107, train_loss=0.729201, test_loss=0.690138, best_loss=0.690138
# iteration=108, train_loss=0.727678, test_loss=0.682838, best_loss=0.682838
# iteration=109, train_loss=0.713154, test_loss=0.673291, best_loss=0.673291
# iteration=110, train_loss=0.691469, test_loss=0.654388, best_loss=0.654388
# iteration=111, train_loss=0.679144, test_loss=0.651005, best_loss=0.651005
# iteration=112, train_loss=0.668424, test_loss=0.643872, best_loss=0.643872
# iteration=113, train_loss=0.667213, test_loss=0.639570, best_loss=0.639570
# iteration=114, train_loss=0.647570, test_loss=0.622744, best_loss=0.622744
# iteration=115, train_loss=0.648778, test_loss=0.615342, best_loss=0.615342
# iteration=116, train_loss=0.646331, test_loss=0.603498, best_loss=0.603498
# iteration=117, train_loss=0.625393, test_loss=0.600924, best_loss=0.600924
# iteration=118, train_loss=0.616488, test_loss=0.594653, best_loss=0.594653
# iteration=119, train_loss=0.603425, test_loss=0.582842, best_loss=0.582842
# iteration=120, train_loss=0.595222, test_loss=0.577211, best_loss=0.577211
# iteration=121, train_loss=0.588246, test_loss=0.570316, best_loss=0.570316
# iteration=122, train_loss=0.581402, test_loss=0.558846, best_loss=0.558846
# iteration=123, train_loss=0.572118, test_loss=0.552765, best_loss=0.552765
# iteration=124, train_loss=0.564236, test_loss=0.544499, best_loss=0.544499
# iteration=125, train_loss=0.557957, test_loss=0.538454, best_loss=0.538454
# iteration=126, train_loss=0.562419, test_loss=0.555370, best_loss=0.538454
# iteration=127, train_loss=0.548325, test_loss=0.515475, best_loss=0.515475
# iteration=128, train_loss=0.548340, test_loss=0.521965, best_loss=0.515475
# iteration=129, train_loss=0.533404, test_loss=0.512894, best_loss=0.512894
# iteration=130, train_loss=0.528950, test_loss=0.511537, best_loss=0.511537
# iteration=131, train_loss=0.545192, test_loss=0.545388, best_loss=0.511537
# iteration=132, train_loss=0.520906, test_loss=0.500751, best_loss=0.500751
# iteration=133, train_loss=0.510703, test_loss=0.493379, best_loss=0.493379
# iteration=134, train_loss=0.509112, test_loss=0.498111, best_loss=0.493379
# iteration=135, train_loss=0.502517, test_loss=0.488790, best_loss=0.488790
# iteration=136, train_loss=0.495329, test_loss=0.476580, best_loss=0.476580
# iteration=137, train_loss=0.492833, test_loss=0.467076, best_loss=0.467076
# iteration=138, train_loss=0.499627, test_loss=0.501277, best_loss=0.467076
# iteration=139, train_loss=0.482307, test_loss=0.464481, best_loss=0.464481
# iteration=140, train_loss=0.477500, test_loss=0.460373, best_loss=0.460373
# iteration=141, train_loss=0.477103, test_loss=0.449877, best_loss=0.449877
# iteration=142, train_loss=0.474055, test_loss=0.453061, best_loss=0.449877
# iteration=143, train_loss=0.466838, test_loss=0.458346, best_loss=0.449877
# iteration=144, train_loss=0.473506, test_loss=0.457627, best_loss=0.449877
# iteration=145, train_loss=0.459411, test_loss=0.448841, best_loss=0.448841
# iteration=146, train_loss=0.459206, test_loss=0.433173, best_loss=0.433173
# iteration=147, train_loss=0.452243, test_loss=0.426954, best_loss=0.426954
# iteration=148, train_loss=0.448960, test_loss=0.443234, best_loss=0.426954
# iteration=149, train_loss=0.444396, test_loss=0.423877, best_loss=0.423877
# iteration=150, train_loss=0.441475, test_loss=0.417640, best_loss=0.417640
# iteration=151, train_loss=0.441804, test_loss=0.420105, best_loss=0.417640
# iteration=152, train_loss=0.435358, test_loss=0.424939, best_loss=0.417640
# iteration=153, train_loss=0.430108, test_loss=0.416247, best_loss=0.416247
# iteration=154, train_loss=0.429202, test_loss=0.405976, best_loss=0.405976
# iteration=155, train_loss=0.431917, test_loss=0.401441, best_loss=0.401441
# iteration=156, train_loss=0.435696, test_loss=0.406138, best_loss=0.401441
# iteration=157, train_loss=0.420144, test_loss=0.400652, best_loss=0.400652
# iteration=158, train_loss=0.420463, test_loss=0.392244, best_loss=0.392244
# iteration=159, train_loss=0.414979, test_loss=0.401243, best_loss=0.392244
# iteration=160, train_loss=0.409080, test_loss=0.394281, best_loss=0.392244
# iteration=161, train_loss=0.410500, test_loss=0.403781, best_loss=0.392244
# iteration=162, train_loss=0.403692, test_loss=0.391771, best_loss=0.391771
# iteration=163, train_loss=0.405251, test_loss=0.384062, best_loss=0.384062
# iteration=164, train_loss=0.409537, test_loss=0.404743, best_loss=0.384062
# iteration=165, train_loss=0.416493, test_loss=0.416235, best_loss=0.384062
# iteration=166, train_loss=0.393276, test_loss=0.383005, best_loss=0.383005
# iteration=167, train_loss=0.391173, test_loss=0.379313, best_loss=0.379313
# iteration=168, train_loss=0.386662, test_loss=0.366826, best_loss=0.366826
# iteration=169, train_loss=0.384538, test_loss=0.363629, best_loss=0.363629
# iteration=170, train_loss=0.381348, test_loss=0.361893, best_loss=0.361893
# iteration=171, train_loss=0.381131, test_loss=0.370374, best_loss=0.361893
# iteration=172, train_loss=0.378158, test_loss=0.367050, best_loss=0.361893
# iteration=173, train_loss=0.389491, test_loss=0.351064, best_loss=0.351064
# iteration=174, train_loss=0.380146, test_loss=0.347300, best_loss=0.347300
# iteration=175, train_loss=0.377843, test_loss=0.347201, best_loss=0.347201
# iteration=176, train_loss=0.366889, test_loss=0.356849, best_loss=0.347201
# iteration=177, train_loss=0.367474, test_loss=0.358591, best_loss=0.347201
# iteration=178, train_loss=0.366769, test_loss=0.358570, best_loss=0.347201
# iteration=179, train_loss=0.358242, test_loss=0.336497, best_loss=0.336497
# iteration=180, train_loss=0.360560, test_loss=0.350831, best_loss=0.336497
# iteration=181, train_loss=0.352913, test_loss=0.332005, best_loss=0.332005
# iteration=182, train_loss=0.358374, test_loss=0.327133, best_loss=0.327133
# iteration=183, train_loss=0.354090, test_loss=0.320337, best_loss=0.320337
# iteration=184, train_loss=0.353010, test_loss=0.324024, best_loss=0.320337
# iteration=185, train_loss=0.346460, test_loss=0.336888, best_loss=0.320337
# iteration=186, train_loss=0.348635, test_loss=0.317516, best_loss=0.317516
# iteration=187, train_loss=0.339814, test_loss=0.310988, best_loss=0.310988
# iteration=188, train_loss=0.340817, test_loss=0.318514, best_loss=0.310988
# iteration=189, train_loss=0.338010, test_loss=0.323326, best_loss=0.310988
# iteration=190, train_loss=0.333090, test_loss=0.303436, best_loss=0.303436
# iteration=191, train_loss=0.330168, test_loss=0.311886, best_loss=0.303436
# iteration=192, train_loss=0.327956, test_loss=0.301343, best_loss=0.301343
# iteration=193, train_loss=0.330900, test_loss=0.306862, best_loss=0.301343
# iteration=194, train_loss=0.328622, test_loss=0.315112, best_loss=0.301343
# iteration=195, train_loss=0.322728, test_loss=0.297871, best_loss=0.297871
# iteration=196, train_loss=0.320423, test_loss=0.306795, best_loss=0.297871
# iteration=197, train_loss=0.334295, test_loss=0.327955, best_loss=0.297871
# iteration=198, train_loss=0.316202, test_loss=0.290621, best_loss=0.290621
# iteration=199, train_loss=0.354814, test_loss=0.300164, best_loss=0.290621
# iteration=200, train_loss=0.315046, test_loss=0.301812, best_loss=0.290621
# iteration=201, train_loss=0.318216, test_loss=0.302928, best_loss=0.290621
# iteration=202, train_loss=0.305469, test_loss=0.283772, best_loss=0.283772
# iteration=203, train_loss=0.303713, test_loss=0.272416, best_loss=0.272416
# iteration=204, train_loss=0.301190, test_loss=0.274488, best_loss=0.272416
# iteration=205, train_loss=0.305645, test_loss=0.291838, best_loss=0.272416
# iteration=206, train_loss=0.310520, test_loss=0.286496, best_loss=0.272416
# iteration=207, train_loss=0.297472, test_loss=0.276400, best_loss=0.272416
# iteration=208, train_loss=0.294607, test_loss=0.261042, best_loss=0.261042
# iteration=209, train_loss=0.294547, test_loss=0.266693, best_loss=0.261042
# iteration=210, train_loss=0.291295, test_loss=0.259448, best_loss=0.259448
# iteration=211, train_loss=0.299402, test_loss=0.253805, best_loss=0.253805
# iteration=212, train_loss=0.289560, test_loss=0.260949, best_loss=0.253805
# iteration=213, train_loss=0.331128, test_loss=0.323799, best_loss=0.253805
# iteration=214, train_loss=0.333466, test_loss=0.329110, best_loss=0.253805
# iteration=215, train_loss=0.289936, test_loss=0.254878, best_loss=0.253805
# iteration=216, train_loss=0.286600, test_loss=0.241056, best_loss=0.241056
# iteration=217, train_loss=0.277879, test_loss=0.248729, best_loss=0.241056
# iteration=218, train_loss=0.279930, test_loss=0.253109, best_loss=0.241056
# iteration=219, train_loss=0.301332, test_loss=0.290961, best_loss=0.241056
# iteration=220, train_loss=0.276667, test_loss=0.235092, best_loss=0.235092
# iteration=221, train_loss=0.293102, test_loss=0.237482, best_loss=0.235092
# iteration=222, train_loss=0.302557, test_loss=0.300495, best_loss=0.235092
# iteration=223, train_loss=0.277977, test_loss=0.253047, best_loss=0.235092
# iteration=224, train_loss=0.265212, test_loss=0.230885, best_loss=0.230885
# iteration=225, train_loss=0.266561, test_loss=0.225362, best_loss=0.225362
# iteration=226, train_loss=0.261640, test_loss=0.220790, best_loss=0.220790
# iteration=227, train_loss=0.315214, test_loss=0.255505, best_loss=0.220790
# iteration=228, train_loss=0.260842, test_loss=0.217169, best_loss=0.217169
# iteration=229, train_loss=0.261402, test_loss=0.235468, best_loss=0.217169
# iteration=230, train_loss=0.257698, test_loss=0.212664, best_loss=0.212664
# iteration=231, train_loss=0.257089, test_loss=0.215935, best_loss=0.212664
# iteration=232, train_loss=0.266052, test_loss=0.246285, best_loss=0.212664
# iteration=233, train_loss=0.252081, test_loss=0.206887, best_loss=0.206887
# iteration=234, train_loss=0.258631, test_loss=0.210034, best_loss=0.206887
# iteration=235, train_loss=0.252350, test_loss=0.201881, best_loss=0.201881
# iteration=236, train_loss=0.260640, test_loss=0.235265, best_loss=0.201881
# iteration=237, train_loss=0.274296, test_loss=0.249214, best_loss=0.201881
# iteration=238, train_loss=0.258653, test_loss=0.204890, best_loss=0.201881
# iteration=239, train_loss=0.241855, test_loss=0.195022, best_loss=0.195022
# iteration=240, train_loss=0.240887, test_loss=0.200391, best_loss=0.195022
# iteration=241, train_loss=0.243209, test_loss=0.202426, best_loss=0.195022
# iteration=242, train_loss=0.249918, test_loss=0.220502, best_loss=0.195022
# iteration=243, train_loss=0.237158, test_loss=0.186071, best_loss=0.186071
# iteration=244, train_loss=0.239498, test_loss=0.208125, best_loss=0.186071
# iteration=245, train_loss=0.244213, test_loss=0.208136, best_loss=0.186071
# iteration=246, train_loss=0.240427, test_loss=0.190419, best_loss=0.186071
# iteration=247, train_loss=0.239397, test_loss=0.195633, best_loss=0.186071
# iteration=248, train_loss=0.233316, test_loss=0.197830, best_loss=0.186071
# iteration=249, train_loss=0.246168, test_loss=0.188449, best_loss=0.186071
# iteration=250, train_loss=0.229768, test_loss=0.177656, best_loss=0.177656
# iteration=251, train_loss=0.253288, test_loss=0.191993, best_loss=0.177656
# iteration=252, train_loss=0.224834, test_loss=0.181073, best_loss=0.177656
# iteration=253, train_loss=0.235739, test_loss=0.198603, best_loss=0.177656
# iteration=254, train_loss=0.224080, test_loss=0.184072, best_loss=0.177656
# iteration=255, train_loss=0.224334, test_loss=0.180400, best_loss=0.177656
# iteration=256, train_loss=0.222581, test_loss=0.179414, best_loss=0.177656
# iteration=257, train_loss=0.227235, test_loss=0.186996, best_loss=0.177656
# iteration=258, train_loss=0.218810, test_loss=0.174583, best_loss=0.174583
# iteration=259, train_loss=0.216602, test_loss=0.162542, best_loss=0.162542
# iteration=260, train_loss=0.218495, test_loss=0.165461, best_loss=0.162542
# iteration=261, train_loss=0.219331, test_loss=0.182714, best_loss=0.162542
# iteration=262, train_loss=0.223332, test_loss=0.162767, best_loss=0.162542
# iteration=263, train_loss=0.211765, test_loss=0.157900, best_loss=0.157900
# iteration=264, train_loss=0.211610, test_loss=0.163220, best_loss=0.157900
# iteration=265, train_loss=0.226623, test_loss=0.170547, best_loss=0.157900
# iteration=266, train_loss=0.213601, test_loss=0.164470, best_loss=0.157900
# iteration=267, train_loss=0.213953, test_loss=0.158146, best_loss=0.157900
# iteration=268, train_loss=0.209259, test_loss=0.148224, best_loss=0.148224
# iteration=269, train_loss=0.205402, test_loss=0.151039, best_loss=0.148224
# iteration=270, train_loss=0.208756, test_loss=0.155632, best_loss=0.148224
# iteration=271, train_loss=0.202546, test_loss=0.148087, best_loss=0.148087
# iteration=272, train_loss=0.214848, test_loss=0.153201, best_loss=0.148087
# iteration=273, train_loss=0.204342, test_loss=0.147904, best_loss=0.147904
# iteration=274, train_loss=0.224081, test_loss=0.175688, best_loss=0.147904
# iteration=275, train_loss=0.218459, test_loss=0.151354, best_loss=0.147904
# iteration=276, train_loss=0.206751, test_loss=0.142061, best_loss=0.142061
# iteration=277, train_loss=0.196874, test_loss=0.141721, best_loss=0.141721
# iteration=278, train_loss=0.207029, test_loss=0.150873, best_loss=0.141721
# iteration=279, train_loss=0.207959, test_loss=0.144790, best_loss=0.141721
# iteration=280, train_loss=0.240039, test_loss=0.200623, best_loss=0.141721
# iteration=281, train_loss=0.196603, test_loss=0.137730, best_loss=0.137730
# iteration=282, train_loss=0.209121, test_loss=0.159568, best_loss=0.137730
# iteration=283, train_loss=0.194647, test_loss=0.132273, best_loss=0.132273
# iteration=284, train_loss=0.193173, test_loss=0.141060, best_loss=0.132273
# iteration=285, train_loss=0.196959, test_loss=0.125218, best_loss=0.125218
# iteration=286, train_loss=0.195197, test_loss=0.135046, best_loss=0.125218
# iteration=287, train_loss=0.194061, test_loss=0.141649, best_loss=0.125218
# iteration=288, train_loss=0.190161, test_loss=0.134798, best_loss=0.125218
# iteration=289, train_loss=0.194179, test_loss=0.130014, best_loss=0.125218
# iteration=290, train_loss=0.201028, test_loss=0.138216, best_loss=0.125218
# iteration=291, train_loss=0.195896, test_loss=0.134433, best_loss=0.125218
# iteration=292, train_loss=0.189696, test_loss=0.130006, best_loss=0.125218
# iteration=293, train_loss=0.202992, test_loss=0.151611, best_loss=0.125218
# iteration=294, train_loss=0.213289, test_loss=0.137915, best_loss=0.125218
# iteration=295, train_loss=0.203346, test_loss=0.147530, best_loss=0.125218
# iteration=296, train_loss=0.215899, test_loss=0.140189, best_loss=0.125218
# iteration=297, train_loss=0.186917, test_loss=0.121065, best_loss=0.121065
# iteration=298, train_loss=0.179338, test_loss=0.113357, best_loss=0.113357
# iteration=299, train_loss=0.178832, test_loss=0.110151, best_loss=0.110151
# iteration=300, train_loss=0.185385, test_loss=0.126739, best_loss=0.110151
# iteration=301, train_loss=0.198279, test_loss=0.120787, best_loss=0.110151
# iteration=302, train_loss=0.177285, test_loss=0.114731, best_loss=0.110151
# iteration=303, train_loss=0.181022, test_loss=0.108500, best_loss=0.108500
# iteration=304, train_loss=0.180177, test_loss=0.115680, best_loss=0.108500
# iteration=305, train_loss=0.186521, test_loss=0.111885, best_loss=0.108500
# iteration=306, train_loss=0.179197, test_loss=0.112858, best_loss=0.108500
# iteration=307, train_loss=0.195682, test_loss=0.123784, best_loss=0.108500
# iteration=308, train_loss=0.183454, test_loss=0.113938, best_loss=0.108500
# iteration=309, train_loss=0.180602, test_loss=0.116283, best_loss=0.108500
# iteration=310, train_loss=0.181290, test_loss=0.105809, best_loss=0.105809
# iteration=311, train_loss=0.174187, test_loss=0.100020, best_loss=0.100020
# iteration=312, train_loss=0.170493, test_loss=0.100646, best_loss=0.100020
# iteration=313, train_loss=0.172084, test_loss=0.107247, best_loss=0.100020
# iteration=314, train_loss=0.169590, test_loss=0.096418, best_loss=0.096418
# iteration=315, train_loss=0.173442, test_loss=0.096350, best_loss=0.096350
# iteration=316, train_loss=0.174546, test_loss=0.097650, best_loss=0.096350
# iteration=317, train_loss=0.174418, test_loss=0.103222, best_loss=0.096350
# iteration=318, train_loss=0.179116, test_loss=0.117862, best_loss=0.096350
# iteration=319, train_loss=0.173331, test_loss=0.110579, best_loss=0.096350
# iteration=320, train_loss=0.192329, test_loss=0.118851, best_loss=0.096350
# iteration=321, train_loss=0.168092, test_loss=0.101832, best_loss=0.096350
# iteration=322, train_loss=0.164262, test_loss=0.094824, best_loss=0.094824
# iteration=323, train_loss=0.172003, test_loss=0.100375, best_loss=0.094824
# iteration=324, train_loss=0.169526, test_loss=0.102054, best_loss=0.094824
# iteration=325, train_loss=0.170885, test_loss=0.091794, best_loss=0.091794
# iteration=326, train_loss=0.170041, test_loss=0.106818, best_loss=0.091794
# iteration=327, train_loss=0.191725, test_loss=0.127717, best_loss=0.091794
# iteration=328, train_loss=0.174014, test_loss=0.094097, best_loss=0.091794
# iteration=329, train_loss=0.180316, test_loss=0.111779, best_loss=0.091794
# iteration=330, train_loss=0.160954, test_loss=0.090611, best_loss=0.090611
# iteration=331, train_loss=0.164172, test_loss=0.089664, best_loss=0.089664
# iteration=332, train_loss=0.178714, test_loss=0.099731, best_loss=0.089664
# iteration=333, train_loss=0.162230, test_loss=0.095140, best_loss=0.089664
# iteration=334, train_loss=0.159817, test_loss=0.080804, best_loss=0.080804
# iteration=335, train_loss=0.166394, test_loss=0.090737, best_loss=0.080804
# iteration=336, train_loss=0.158748, test_loss=0.083988, best_loss=0.080804
# iteration=337, train_loss=0.180041, test_loss=0.109723, best_loss=0.080804
# iteration=338, train_loss=0.158453, test_loss=0.082065, best_loss=0.080804
# iteration=339, train_loss=0.184696, test_loss=0.100313, best_loss=0.080804
# iteration=340, train_loss=0.172989, test_loss=0.097460, best_loss=0.080804
# iteration=341, train_loss=0.157856, test_loss=0.079460, best_loss=0.079460
# iteration=342, train_loss=0.173684, test_loss=0.089592, best_loss=0.079460
# iteration=343, train_loss=0.155485, test_loss=0.077766, best_loss=0.077766
# iteration=344, train_loss=0.156437, test_loss=0.078693, best_loss=0.077766
# iteration=345, train_loss=0.201639, test_loss=0.133198, best_loss=0.077766
# iteration=346, train_loss=0.183410, test_loss=0.098842, best_loss=0.077766
# iteration=347, train_loss=0.162768, test_loss=0.081088, best_loss=0.077766
# iteration=348, train_loss=0.179312, test_loss=0.108554, best_loss=0.077766
# iteration=349, train_loss=0.156913, test_loss=0.074434, best_loss=0.074434
# iteration=350, train_loss=0.156061, test_loss=0.079083, best_loss=0.074434
# iteration=351, train_loss=0.156782, test_loss=0.081195, best_loss=0.074434
# iteration=352, train_loss=0.154808, test_loss=0.076592, best_loss=0.074434
# iteration=353, train_loss=0.182629, test_loss=0.094776, best_loss=0.074434
# iteration=354, train_loss=0.155180, test_loss=0.079363, best_loss=0.074434
# iteration=355, train_loss=0.149024, test_loss=0.067073, best_loss=0.067073
# iteration=356, train_loss=0.153751, test_loss=0.075471, best_loss=0.067073
# iteration=357, train_loss=0.159232, test_loss=0.088157, best_loss=0.067073
# iteration=358, train_loss=0.147908, test_loss=0.067903, best_loss=0.067073
# iteration=359, train_loss=0.153271, test_loss=0.070213, best_loss=0.067073
# iteration=360, train_loss=0.149872, test_loss=0.077949, best_loss=0.067073
# iteration=361, train_loss=0.168983, test_loss=0.085084, best_loss=0.067073
# iteration=362, train_loss=0.148704, test_loss=0.070526, best_loss=0.067073
# iteration=363, train_loss=0.146729, test_loss=0.071653, best_loss=0.067073
# iteration=364, train_loss=0.147131, test_loss=0.070687, best_loss=0.067073
# iteration=365, train_loss=0.154218, test_loss=0.081131, best_loss=0.067073
# iteration=366, train_loss=0.171103, test_loss=0.095830, best_loss=0.067073
# iteration=367, train_loss=0.147075, test_loss=0.065339, best_loss=0.065339
# iteration=368, train_loss=0.145584, test_loss=0.065652, best_loss=0.065339
# iteration=369, train_loss=0.165950, test_loss=0.081388, best_loss=0.065339
# iteration=370, train_loss=0.148193, test_loss=0.065618, best_loss=0.065339
# iteration=371, train_loss=0.177828, test_loss=0.101589, best_loss=0.065339
# iteration=372, train_loss=0.149065, test_loss=0.067236, best_loss=0.065339
# iteration=373, train_loss=0.145636, test_loss=0.068114, best_loss=0.065339
# iteration=374, train_loss=0.145803, test_loss=0.065267, best_loss=0.065267
# iteration=375, train_loss=0.152633, test_loss=0.076297, best_loss=0.065267
# iteration=376, train_loss=0.161451, test_loss=0.087113, best_loss=0.065267
# iteration=377, train_loss=0.159841, test_loss=0.090936, best_loss=0.065267
# iteration=378, train_loss=0.152006, test_loss=0.072489, best_loss=0.065267
# iteration=379, train_loss=0.163265, test_loss=0.075749, best_loss=0.065267
# iteration=380, train_loss=0.148085, test_loss=0.069808, best_loss=0.065267
# iteration=381, train_loss=0.140690, test_loss=0.058672, best_loss=0.058672
# iteration=382, train_loss=0.146144, test_loss=0.067344, best_loss=0.058672
# iteration=383, train_loss=0.141727, test_loss=0.058765, best_loss=0.058672
# iteration=384, train_loss=0.153279, test_loss=0.067690, best_loss=0.058672
# iteration=385, train_loss=0.145467, test_loss=0.067553, best_loss=0.058672
# iteration=386, train_loss=0.151567, test_loss=0.063638, best_loss=0.058672
# iteration=387, train_loss=0.139745, test_loss=0.060513, best_loss=0.058672
# iteration=388, train_loss=0.147319, test_loss=0.071450, best_loss=0.058672
# iteration=389, train_loss=0.143042, test_loss=0.062374, best_loss=0.058672
# iteration=390, train_loss=0.138954, test_loss=0.055633, best_loss=0.055633
# iteration=391, train_loss=0.165965, test_loss=0.075424, best_loss=0.055633
# iteration=392, train_loss=0.139035, test_loss=0.059974, best_loss=0.055633
# iteration=393, train_loss=0.133880, test_loss=0.051391, best_loss=0.051391
# iteration=394, train_loss=0.160612, test_loss=0.088743, best_loss=0.051391
# iteration=395, train_loss=0.140986, test_loss=0.058103, best_loss=0.051391
# iteration=396, train_loss=0.137777, test_loss=0.059999, best_loss=0.051391
# iteration=397, train_loss=0.145372, test_loss=0.059813, best_loss=0.051391
# iteration=398, train_loss=0.143920, test_loss=0.058557, best_loss=0.051391
# iteration=399, train_loss=0.138456, test_loss=0.051550, best_loss=0.051391
# iteration=400, train_loss=0.155752, test_loss=0.074637, best_loss=0.051391
# iteration=401, train_loss=0.139744, test_loss=0.057982, best_loss=0.051391
# iteration=402, train_loss=0.141131, test_loss=0.060213, best_loss=0.051391
# iteration=403, train_loss=0.140434, test_loss=0.056395, best_loss=0.051391
# iteration=404, train_loss=0.130939, test_loss=0.048396, best_loss=0.048396
# iteration=405, train_loss=0.135216, test_loss=0.055789, best_loss=0.048396
# iteration=406, train_loss=0.138087, test_loss=0.055720, best_loss=0.048396
# iteration=407, train_loss=0.137427, test_loss=0.057503, best_loss=0.048396
# iteration=408, train_loss=0.158419, test_loss=0.083949, best_loss=0.048396
# iteration=409, train_loss=0.136514, test_loss=0.059100, best_loss=0.048396
# iteration=410, train_loss=0.153534, test_loss=0.067285, best_loss=0.048396
# iteration=411, train_loss=0.155541, test_loss=0.067619, best_loss=0.048396
# iteration=412, train_loss=0.130811, test_loss=0.045079, best_loss=0.045079
# iteration=413, train_loss=0.134312, test_loss=0.047812, best_loss=0.045079
# iteration=414, train_loss=0.145744, test_loss=0.059627, best_loss=0.045079
# iteration=415, train_loss=0.130778, test_loss=0.046086, best_loss=0.045079
# iteration=416, train_loss=0.138926, test_loss=0.063385, best_loss=0.045079
# iteration=417, train_loss=0.130206, test_loss=0.050496, best_loss=0.045079
# iteration=418, train_loss=0.130742, test_loss=0.051592, best_loss=0.045079
# iteration=419, train_loss=0.130988, test_loss=0.048092, best_loss=0.045079
# iteration=420, train_loss=0.129524, test_loss=0.042223, best_loss=0.042223
# iteration=421, train_loss=0.135034, test_loss=0.045672, best_loss=0.042223
# iteration=422, train_loss=0.143132, test_loss=0.055635, best_loss=0.042223
# iteration=423, train_loss=0.133433, test_loss=0.049333, best_loss=0.042223
# iteration=424, train_loss=0.183969, test_loss=0.111461, best_loss=0.042223
# iteration=425, train_loss=0.152324, test_loss=0.071797, best_loss=0.042223
# iteration=426, train_loss=0.149817, test_loss=0.066436, best_loss=0.042223
# iteration=427, train_loss=0.135005, test_loss=0.051113, best_loss=0.042223
# iteration=428, train_loss=0.136605, test_loss=0.053670, best_loss=0.042223
# iteration=429, train_loss=0.135400, test_loss=0.048167, best_loss=0.042223
# iteration=430, train_loss=0.132509, test_loss=0.044005, best_loss=0.042223
# iteration=431, train_loss=0.130903, test_loss=0.043983, best_loss=0.042223
# iteration=432, train_loss=0.164104, test_loss=0.078997, best_loss=0.042223
# iteration=433, train_loss=0.149842, test_loss=0.069849, best_loss=0.042223
# iteration=434, train_loss=0.127513, test_loss=0.045708, best_loss=0.042223
# iteration=435, train_loss=0.127792, test_loss=0.047827, best_loss=0.042223
# iteration=436, train_loss=0.134510, test_loss=0.052158, best_loss=0.042223
# iteration=437, train_loss=0.146089, test_loss=0.066688, best_loss=0.042223
# iteration=438, train_loss=0.130755, test_loss=0.045538, best_loss=0.042223
# iteration=439, train_loss=0.136309, test_loss=0.049578, best_loss=0.042223
# iteration=440, train_loss=0.125682, test_loss=0.042031, best_loss=0.042031
# iteration=441, train_loss=0.154087, test_loss=0.069910, best_loss=0.042031
# iteration=442, train_loss=0.149377, test_loss=0.064302, best_loss=0.042031
# iteration=443, train_loss=0.138142, test_loss=0.055109, best_loss=0.042031
# iteration=444, train_loss=0.132023, test_loss=0.046738, best_loss=0.042031
# iteration=445, train_loss=0.146343, test_loss=0.065128, best_loss=0.042031
# iteration=446, train_loss=0.146140, test_loss=0.067312, best_loss=0.042031
# iteration=447, train_loss=0.141033, test_loss=0.057152, best_loss=0.042031
# iteration=448, train_loss=0.129906, test_loss=0.044888, best_loss=0.042031
# iteration=449, train_loss=0.128945, test_loss=0.042393, best_loss=0.042031
# iteration=450, train_loss=0.141508, test_loss=0.052152, best_loss=0.042031
# iteration=451, train_loss=0.128171, test_loss=0.042069, best_loss=0.042031
# iteration=452, train_loss=0.136994, test_loss=0.047569, best_loss=0.042031
# iteration=453, train_loss=0.150396, test_loss=0.058182, best_loss=0.042031
# iteration=454, train_loss=0.127137, test_loss=0.037914, best_loss=0.037914
# iteration=455, train_loss=0.145054, test_loss=0.060286, best_loss=0.037914
# iteration=456, train_loss=0.208164, test_loss=0.128725, best_loss=0.037914
# iteration=457, train_loss=0.132840, test_loss=0.047549, best_loss=0.037914
# iteration=458, train_loss=0.127588, test_loss=0.043148, best_loss=0.037914
# iteration=459, train_loss=0.132361, test_loss=0.050270, best_loss=0.037914
# iteration=460, train_loss=0.137191, test_loss=0.057486, best_loss=0.037914
# iteration=461, train_loss=0.131596, test_loss=0.051935, best_loss=0.037914
# iteration=462, train_loss=0.119071, test_loss=0.033175, best_loss=0.033175
# iteration=463, train_loss=0.122391, test_loss=0.039123, best_loss=0.033175
# iteration=464, train_loss=0.126982, test_loss=0.043487, best_loss=0.033175
# iteration=465, train_loss=0.139752, test_loss=0.055613, best_loss=0.033175
# iteration=466, train_loss=0.121716, test_loss=0.036021, best_loss=0.033175
# iteration=467, train_loss=0.127601, test_loss=0.040151, best_loss=0.033175
# iteration=468, train_loss=0.126164, test_loss=0.041920, best_loss=0.033175
# iteration=469, train_loss=0.131655, test_loss=0.044145, best_loss=0.033175
# iteration=470, train_loss=0.132299, test_loss=0.049334, best_loss=0.033175
# iteration=471, train_loss=0.126251, test_loss=0.039287, best_loss=0.033175
# iteration=472, train_loss=0.149974, test_loss=0.076463, best_loss=0.033175
# iteration=473, train_loss=0.125415, test_loss=0.044003, best_loss=0.033175
# iteration=474, train_loss=0.136676, test_loss=0.048861, best_loss=0.033175
# iteration=475, train_loss=0.129648, test_loss=0.048774, best_loss=0.033175
# iteration=476, train_loss=0.149131, test_loss=0.071004, best_loss=0.033175
# iteration=477, train_loss=0.123518, test_loss=0.041296, best_loss=0.033175
# iteration=478, train_loss=0.130016, test_loss=0.049458, best_loss=0.033175
# iteration=479, train_loss=0.121992, test_loss=0.040683, best_loss=0.033175
# iteration=480, train_loss=0.119878, test_loss=0.034331, best_loss=0.033175
# iteration=481, train_loss=0.134232, test_loss=0.053888, best_loss=0.033175
# iteration=482, train_loss=0.126918, test_loss=0.044916, best_loss=0.033175
# iteration=483, train_loss=0.139542, test_loss=0.058249, best_loss=0.033175
# iteration=484, train_loss=0.121997, test_loss=0.033628, best_loss=0.033175
# iteration=485, train_loss=0.131268, test_loss=0.047403, best_loss=0.033175
# iteration=486, train_loss=0.116656, test_loss=0.028821, best_loss=0.028821
# iteration=487, train_loss=0.125734, test_loss=0.041370, best_loss=0.028821
# iteration=488, train_loss=0.143389, test_loss=0.065327, best_loss=0.028821
# iteration=489, train_loss=0.115202, test_loss=0.030235, best_loss=0.028821
# iteration=490, train_loss=0.130851, test_loss=0.039905, best_loss=0.028821
# iteration=491, train_loss=0.157438, test_loss=0.064252, best_loss=0.028821
# iteration=492, train_loss=0.187151, test_loss=0.108360, best_loss=0.028821
# iteration=493, train_loss=0.146012, test_loss=0.063979, best_loss=0.028821
# iteration=494, train_loss=0.121632, test_loss=0.034418, best_loss=0.028821
# iteration=495, train_loss=0.121720, test_loss=0.035171, best_loss=0.028821
# iteration=496, train_loss=0.129119, test_loss=0.041638, best_loss=0.028821
# iteration=497, train_loss=0.127422, test_loss=0.042413, best_loss=0.028821
# iteration=498, train_loss=0.127471, test_loss=0.042622, best_loss=0.028821
# iteration=499, train_loss=0.122336, test_loss=0.038155, best_loss=0.028821
# iteration=500, train_loss=0.114246, test_loss=0.027624, best_loss=0.027624
# iteration=501, train_loss=0.123884, test_loss=0.038722, best_loss=0.027624
# iteration=502, train_loss=0.126421, test_loss=0.043714, best_loss=0.027624
# iteration=503, train_loss=0.171897, test_loss=0.080227, best_loss=0.027624
# iteration=504, train_loss=0.125556, test_loss=0.037858, best_loss=0.027624
# iteration=505, train_loss=0.137681, test_loss=0.048247, best_loss=0.027624
# iteration=506, train_loss=0.134937, test_loss=0.044694, best_loss=0.027624
# iteration=507, train_loss=0.183997, test_loss=0.109146, best_loss=0.027624
# iteration=508, train_loss=0.126644, test_loss=0.039756, best_loss=0.027624
# iteration=509, train_loss=0.114533, test_loss=0.027295, best_loss=0.027295
# iteration=510, train_loss=0.138310, test_loss=0.060023, best_loss=0.027295
# iteration=511, train_loss=0.147628, test_loss=0.056228, best_loss=0.027295
# iteration=512, train_loss=0.120178, test_loss=0.034290, best_loss=0.027295
# iteration=513, train_loss=0.158950, test_loss=0.078591, best_loss=0.027295
# iteration=514, train_loss=0.119396, test_loss=0.031817, best_loss=0.027295
# iteration=515, train_loss=0.147443, test_loss=0.065863, best_loss=0.027295
# iteration=516, train_loss=0.153073, test_loss=0.070819, best_loss=0.027295
# iteration=517, train_loss=0.152843, test_loss=0.075878, best_loss=0.027295
# iteration=518, train_loss=0.118913, test_loss=0.033841, best_loss=0.027295
# iteration=519, train_loss=0.133110, test_loss=0.046778, best_loss=0.027295
# iteration=520, train_loss=0.129127, test_loss=0.042881, best_loss=0.027295
# iteration=521, train_loss=0.128139, test_loss=0.041930, best_loss=0.027295
# iteration=522, train_loss=0.133286, test_loss=0.044743, best_loss=0.027295
# iteration=523, train_loss=0.119043, test_loss=0.034231, best_loss=0.027295
# iteration=524, train_loss=0.114556, test_loss=0.028065, best_loss=0.027295
# iteration=525, train_loss=0.128464, test_loss=0.043284, best_loss=0.027295
# iteration=526, train_loss=0.120603, test_loss=0.034647, best_loss=0.027295
# iteration=527, train_loss=0.116161, test_loss=0.026951, best_loss=0.026951
# iteration=528, train_loss=0.147462, test_loss=0.061783, best_loss=0.026951
# iteration=529, train_loss=0.129268, test_loss=0.041477, best_loss=0.026951
# iteration=530, train_loss=0.162669, test_loss=0.084742, best_loss=0.026951
# iteration=531, train_loss=0.142541, test_loss=0.064585, best_loss=0.026951
# iteration=532, train_loss=0.127395, test_loss=0.041009, best_loss=0.026951
# iteration=533, train_loss=0.129944, test_loss=0.040481, best_loss=0.026951
# iteration=534, train_loss=0.132722, test_loss=0.051462, best_loss=0.026951
# iteration=535, train_loss=0.131484, test_loss=0.048316, best_loss=0.026951
# iteration=536, train_loss=0.136716, test_loss=0.055639, best_loss=0.026951
# iteration=537, train_loss=0.131649, test_loss=0.050022, best_loss=0.026951
# iteration=538, train_loss=0.122469, test_loss=0.034953, best_loss=0.026951
# iteration=539, train_loss=0.140055, test_loss=0.058417, best_loss=0.026951
# iteration=540, train_loss=0.116771, test_loss=0.029377, best_loss=0.026951
# iteration=541, train_loss=0.122688, test_loss=0.035356, best_loss=0.026951
# iteration=542, train_loss=0.192293, test_loss=0.090948, best_loss=0.026951
# iteration=543, train_loss=0.156952, test_loss=0.076922, best_loss=0.026951
# iteration=544, train_loss=0.144983, test_loss=0.051826, best_loss=0.026951
# iteration=545, train_loss=0.152552, test_loss=0.064977, best_loss=0.026951
# iteration=546, train_loss=0.163023, test_loss=0.073558, best_loss=0.026951
# iteration=547, train_loss=0.113804, test_loss=0.026519, best_loss=0.026519
# iteration=548, train_loss=0.117227, test_loss=0.032611, best_loss=0.026519
# iteration=549, train_loss=0.114957, test_loss=0.025946, best_loss=0.025946
# iteration=550, train_loss=0.128777, test_loss=0.036277, best_loss=0.025946
# iteration=551, train_loss=0.132858, test_loss=0.053568, best_loss=0.025946
# iteration=552, train_loss=0.116240, test_loss=0.027563, best_loss=0.025946
# iteration=553, train_loss=0.151068, test_loss=0.069019, best_loss=0.025946
# iteration=554, train_loss=0.135740, test_loss=0.055132, best_loss=0.025946
# iteration=555, train_loss=0.146054, test_loss=0.062087, best_loss=0.025946
# iteration=556, train_loss=0.117991, test_loss=0.032424, best_loss=0.025946
# iteration=557, train_loss=0.124156, test_loss=0.040758, best_loss=0.025946
# iteration=558, train_loss=0.262142, test_loss=0.174587, best_loss=0.025946
# iteration=559, train_loss=0.227452, test_loss=0.144937, best_loss=0.025946
# iteration=560, train_loss=0.116781, test_loss=0.033714, best_loss=0.025946
# iteration=561, train_loss=0.138069, test_loss=0.043634, best_loss=0.025946
# iteration=562, train_loss=0.129626, test_loss=0.044305, best_loss=0.025946
# iteration=563, train_loss=0.133653, test_loss=0.041204, best_loss=0.025946
# iteration=564, train_loss=0.121508, test_loss=0.030531, best_loss=0.025946
# iteration=565, train_loss=0.115611, test_loss=0.026996, best_loss=0.025946
# iteration=566, train_loss=0.126774, test_loss=0.035226, best_loss=0.025946
# iteration=567, train_loss=0.111207, test_loss=0.024919, best_loss=0.024919
# iteration=568, train_loss=0.143286, test_loss=0.052995, best_loss=0.024919
# iteration=569, train_loss=0.112994, test_loss=0.028849, best_loss=0.024919
# iteration=570, train_loss=0.139447, test_loss=0.050680, best_loss=0.024919
# iteration=571, train_loss=0.119921, test_loss=0.031955, best_loss=0.024919
# iteration=572, train_loss=0.149105, test_loss=0.060932, best_loss=0.024919
# iteration=573, train_loss=0.116534, test_loss=0.031235, best_loss=0.024919
# iteration=574, train_loss=0.126295, test_loss=0.036464, best_loss=0.024919
# iteration=575, train_loss=0.137571, test_loss=0.052225, best_loss=0.024919
# iteration=576, train_loss=0.165395, test_loss=0.077391, best_loss=0.024919
# iteration=577, train_loss=0.124191, test_loss=0.034545, best_loss=0.024919
# iteration=578, train_loss=0.152801, test_loss=0.058363, best_loss=0.024919
# iteration=579, train_loss=0.121951, test_loss=0.032881, best_loss=0.024919
# iteration=580, train_loss=0.121825, test_loss=0.037734, best_loss=0.024919
# iteration=581, train_loss=0.122987, test_loss=0.034577, best_loss=0.024919
# iteration=582, train_loss=0.139852, test_loss=0.048784, best_loss=0.024919
# iteration=583, train_loss=0.111516, test_loss=0.022700, best_loss=0.022700
# iteration=584, train_loss=0.132014, test_loss=0.043212, best_loss=0.022700
# iteration=585, train_loss=0.122358, test_loss=0.034207, best_loss=0.022700
# iteration=586, train_loss=0.121503, test_loss=0.038076, best_loss=0.022700
# iteration=587, train_loss=0.116931, test_loss=0.029789, best_loss=0.022700
# iteration=588, train_loss=0.126921, test_loss=0.045844, best_loss=0.022700
# iteration=589, train_loss=0.113926, test_loss=0.026915, best_loss=0.022700
# iteration=590, train_loss=0.129322, test_loss=0.043367, best_loss=0.022700
# iteration=591, train_loss=0.114118, test_loss=0.025258, best_loss=0.022700
# iteration=592, train_loss=0.139396, test_loss=0.056109, best_loss=0.022700
# iteration=593, train_loss=0.127223, test_loss=0.039455, best_loss=0.022700
# iteration=594, train_loss=0.151102, test_loss=0.065978, best_loss=0.022700
# iteration=595, train_loss=0.113798, test_loss=0.028205, best_loss=0.022700
# iteration=596, train_loss=0.123029, test_loss=0.039800, best_loss=0.022700
# iteration=597, train_loss=0.116246, test_loss=0.031002, best_loss=0.022700
# iteration=598, train_loss=0.146718, test_loss=0.067360, best_loss=0.022700
# iteration=599, train_loss=0.114728, test_loss=0.030896, best_loss=0.022700
# iteration=600, train_loss=0.132882, test_loss=0.044076, best_loss=0.022700
# iteration=601, train_loss=0.137085, test_loss=0.044435, best_loss=0.022700
# iteration=602, train_loss=0.128127, test_loss=0.043770, best_loss=0.022700
# iteration=603, train_loss=0.139111, test_loss=0.057126, best_loss=0.022700
# iteration=604, train_loss=0.122453, test_loss=0.035378, best_loss=0.022700
# iteration=605, train_loss=0.129134, test_loss=0.047329, best_loss=0.022700
# iteration=606, train_loss=0.114932, test_loss=0.026846, best_loss=0.022700
# iteration=607, train_loss=0.160050, test_loss=0.075881, best_loss=0.022700
# iteration=608, train_loss=0.135680, test_loss=0.044967, best_loss=0.022700
# iteration=609, train_loss=0.137712, test_loss=0.052102, best_loss=0.022700
# iteration=610, train_loss=0.118324, test_loss=0.035927, best_loss=0.022700
# iteration=611, train_loss=0.124898, test_loss=0.042371, best_loss=0.022700
# iteration=612, train_loss=0.112850, test_loss=0.023337, best_loss=0.022700
# iteration=613, train_loss=0.120571, test_loss=0.031979, best_loss=0.022700
# iteration=614, train_loss=0.194049, test_loss=0.114902, best_loss=0.022700
# iteration=615, train_loss=0.148903, test_loss=0.058078, best_loss=0.022700
# iteration=616, train_loss=0.148458, test_loss=0.066650, best_loss=0.022700
# iteration=617, train_loss=0.136445, test_loss=0.047517, best_loss=0.022700
# iteration=618, train_loss=0.143088, test_loss=0.059087, best_loss=0.022700
# iteration=619, train_loss=0.160259, test_loss=0.076657, best_loss=0.022700
# iteration=620, train_loss=0.144149, test_loss=0.058616, best_loss=0.022700
# iteration=621, train_loss=0.125443, test_loss=0.036810, best_loss=0.022700
# iteration=622, train_loss=0.178416, test_loss=0.094524, best_loss=0.022700
# iteration=623, train_loss=0.136610, test_loss=0.051571, best_loss=0.022700
# iteration=624, train_loss=0.192761, test_loss=0.106020, best_loss=0.022700
# iteration=625, train_loss=0.122412, test_loss=0.030768, best_loss=0.022700
# iteration=626, train_loss=0.149416, test_loss=0.060396, best_loss=0.022700
# iteration=627, train_loss=0.121987, test_loss=0.031963, best_loss=0.022700
# iteration=628, train_loss=0.130610, test_loss=0.050561, best_loss=0.022700
# iteration=629, train_loss=0.111145, test_loss=0.024775, best_loss=0.022700
# iteration=630, train_loss=0.121908, test_loss=0.031679, best_loss=0.022700
# iteration=631, train_loss=0.119760, test_loss=0.032878, best_loss=0.022700
# iteration=632, train_loss=0.130372, test_loss=0.048902, best_loss=0.022700
# iteration=633, train_loss=0.133594, test_loss=0.051469, best_loss=0.022700
# iteration=634, train_loss=0.141180, test_loss=0.051808, best_loss=0.022700
# iteration=635, train_loss=0.148996, test_loss=0.056348, best_loss=0.022700
# iteration=636, train_loss=0.152555, test_loss=0.059477, best_loss=0.022700
# iteration=637, train_loss=0.119731, test_loss=0.036956, best_loss=0.022700
# iteration=638, train_loss=0.110492, test_loss=0.022066, best_loss=0.022066
# ...
# iteration=1791, train_loss=0.101157, test_loss=0.018678, best_loss=0.010885
# iteration=1792, train_loss=0.120842, test_loss=0.042652, best_loss=0.010885
# iteration=1793, train_loss=0.115667, test_loss=0.032837, best_loss=0.010885
# iteration=1794, train_loss=0.126979, test_loss=0.048302, best_loss=0.010885
# iteration=1795, train_loss=0.133979, test_loss=0.060231, best_loss=0.010885
# iteration=1796, train_loss=0.102824, test_loss=0.019999, best_loss=0.010885
# iteration=1797, train_loss=0.106671, test_loss=0.025457, best_loss=0.010885
# iteration=1798, train_loss=0.106932, test_loss=0.026787, best_loss=0.010885
# iteration=1799, train_loss=0.103661, test_loss=0.016843, best_loss=0.010885
# iteration=1800, train_loss=0.109015, test_loss=0.026764, best_loss=0.010885
# iteration=1801, train_loss=0.100476, test_loss=0.020310, best_loss=0.010885
# iteration=1802, train_loss=0.124792, test_loss=0.038519, best_loss=0.010885
# iteration=1803, train_loss=0.117824, test_loss=0.034039, best_loss=0.010885
# iteration=1804, train_loss=0.096854, test_loss=0.012163, best_loss=0.010885
# iteration=1805, train_loss=0.123790, test_loss=0.041779, best_loss=0.010885
# iteration=1806, train_loss=0.126831, test_loss=0.044934, best_loss=0.010885
# iteration=1807, train_loss=0.106140, test_loss=0.029410, best_loss=0.010885
# iteration=1808, train_loss=0.102073, test_loss=0.017422, best_loss=0.010885
# iteration=1809, train_loss=0.117807, test_loss=0.031282, best_loss=0.010885
# iteration=1810, train_loss=0.100453, test_loss=0.019817, best_loss=0.010885
# iteration=1811, train_loss=0.116938, test_loss=0.036116, best_loss=0.010885
# iteration=1812, train_loss=0.151501, test_loss=0.065257, best_loss=0.010885
# iteration=1813, train_loss=0.100147, test_loss=0.017944, best_loss=0.010885
# iteration=1814, train_loss=0.111940, test_loss=0.027707, best_loss=0.010885
# iteration=1815, train_loss=0.113415, test_loss=0.029099, best_loss=0.010885
# iteration=1816, train_loss=0.104599, test_loss=0.021790, best_loss=0.010885
# iteration=1817, train_loss=0.107957, test_loss=0.026114, best_loss=0.010885
# iteration=1818, train_loss=0.133119, test_loss=0.056930, best_loss=0.010885
# iteration=1819, train_loss=0.103674, test_loss=0.019177, best_loss=0.010885
# iteration=1820, train_loss=0.141055, test_loss=0.060371, best_loss=0.010885
# iteration=1821, train_loss=0.111257, test_loss=0.028228, best_loss=0.010885
# iteration=1822, train_loss=0.145536, test_loss=0.064858, best_loss=0.010885
# iteration=1823, train_loss=0.180672, test_loss=0.100601, best_loss=0.010885
# iteration=1824, train_loss=0.109882, test_loss=0.028143, best_loss=0.010885
# iteration=1825, train_loss=0.112887, test_loss=0.031265, best_loss=0.010885
# iteration=1826, train_loss=0.116273, test_loss=0.035940, best_loss=0.010885
# iteration=1827, train_loss=0.103174, test_loss=0.020037, best_loss=0.010885
# iteration=1828, train_loss=0.104051, test_loss=0.020712, best_loss=0.010885
# iteration=1829, train_loss=0.110406, test_loss=0.027255, best_loss=0.010885
# iteration=1830, train_loss=0.108092, test_loss=0.026653, best_loss=0.010885
# iteration=1831, train_loss=0.106191, test_loss=0.026088, best_loss=0.010885
# iteration=1832, train_loss=0.113467, test_loss=0.027891, best_loss=0.010885
# iteration=1833, train_loss=0.103370, test_loss=0.017799, best_loss=0.010885
# iteration=1834, train_loss=0.108821, test_loss=0.026947, best_loss=0.010885
# iteration=1835, train_loss=0.143196, test_loss=0.066396, best_loss=0.010885
# iteration=1836, train_loss=0.194448, test_loss=0.110453, best_loss=0.010885
# iteration=1837, train_loss=0.097253, test_loss=0.015661, best_loss=0.010885
# iteration=1838, train_loss=0.118403, test_loss=0.038974, best_loss=0.010885
# iteration=1839, train_loss=0.110988, test_loss=0.028986, best_loss=0.010885
# iteration=1840, train_loss=0.142892, test_loss=0.059788, best_loss=0.010885
# iteration=1841, train_loss=0.116449, test_loss=0.033352, best_loss=0.010885
# iteration=1842, train_loss=0.121065, test_loss=0.038188, best_loss=0.010885
# iteration=1843, train_loss=0.106393, test_loss=0.019228, best_loss=0.010885
# iteration=1844, train_loss=0.121746, test_loss=0.031617, best_loss=0.010885
# iteration=1845, train_loss=0.145243, test_loss=0.057556, best_loss=0.010885
# iteration=1846, train_loss=0.164290, test_loss=0.085645, best_loss=0.010885
# iteration=1847, train_loss=0.139313, test_loss=0.055064, best_loss=0.010885
# iteration=1848, train_loss=0.159945, test_loss=0.074982, best_loss=0.010885
# iteration=1849, train_loss=0.124547, test_loss=0.042365, best_loss=0.010885
# iteration=1850, train_loss=0.108100, test_loss=0.027310, best_loss=0.010885
# iteration=1851, train_loss=0.136683, test_loss=0.061800, best_loss=0.010885
# iteration=1852, train_loss=0.143604, test_loss=0.062532, best_loss=0.010885
# iteration=1853, train_loss=0.128629, test_loss=0.051415, best_loss=0.010885
# iteration=1854, train_loss=0.131329, test_loss=0.047626, best_loss=0.010885
# iteration=1855, train_loss=0.114649, test_loss=0.033482, best_loss=0.010885
# iteration=1856, train_loss=0.113780, test_loss=0.027614, best_loss=0.010885
# iteration=1857, train_loss=0.129157, test_loss=0.046683, best_loss=0.010885
# iteration=1858, train_loss=0.110592, test_loss=0.029429, best_loss=0.010885
# iteration=1859, train_loss=0.116679, test_loss=0.030153, best_loss=0.010885
# iteration=1860, train_loss=0.103099, test_loss=0.022723, best_loss=0.010885
# iteration=1861, train_loss=0.122583, test_loss=0.040167, best_loss=0.010885
# iteration=1862, train_loss=0.109603, test_loss=0.028559, best_loss=0.010885
# iteration=1863, train_loss=0.114979, test_loss=0.027917, best_loss=0.010885
# iteration=1864, train_loss=0.116385, test_loss=0.033255, best_loss=0.010885
# iteration=1865, train_loss=0.103567, test_loss=0.022387, best_loss=0.010885
# iteration=1866, train_loss=0.121176, test_loss=0.030633, best_loss=0.010885
# iteration=1867, train_loss=0.099727, test_loss=0.021006, best_loss=0.010885
# iteration=1868, train_loss=0.101710, test_loss=0.019350, best_loss=0.010885
# iteration=1869, train_loss=0.104815, test_loss=0.026373, best_loss=0.010885
# iteration=1870, train_loss=0.115094, test_loss=0.030806, best_loss=0.010885
# iteration=1871, train_loss=0.107153, test_loss=0.022694, best_loss=0.010885
# iteration=1872, train_loss=0.114910, test_loss=0.034999, best_loss=0.010885
# iteration=1873, train_loss=0.123863, test_loss=0.044151, best_loss=0.010885
# iteration=1874, train_loss=0.111689, test_loss=0.029866, best_loss=0.010885
# iteration=1875, train_loss=0.124841, test_loss=0.046120, best_loss=0.010885
# iteration=1876, train_loss=0.104005, test_loss=0.019776, best_loss=0.010885
# iteration=1877, train_loss=0.101391, test_loss=0.014852, best_loss=0.010885
# iteration=1878, train_loss=0.108866, test_loss=0.030404, best_loss=0.010885
# iteration=1879, train_loss=0.108469, test_loss=0.028955, best_loss=0.010885
# iteration=1880, train_loss=0.098405, test_loss=0.017227, best_loss=0.010885
# iteration=1881, train_loss=0.107923, test_loss=0.025590, best_loss=0.010885
# iteration=1882, train_loss=0.107016, test_loss=0.026741, best_loss=0.010885
# iteration=1883, train_loss=0.111322, test_loss=0.031417, best_loss=0.010885
# iteration=1884, train_loss=0.116287, test_loss=0.031843, best_loss=0.010885
# iteration=1885, train_loss=0.121460, test_loss=0.042190, best_loss=0.010885
# iteration=1886, train_loss=0.126587, test_loss=0.049887, best_loss=0.010885
# iteration=1887, train_loss=0.160737, test_loss=0.073524, best_loss=0.010885
# iteration=1888, train_loss=0.133668, test_loss=0.049198, best_loss=0.010885
# iteration=1889, train_loss=0.145986, test_loss=0.063583, best_loss=0.010885
# iteration=1890, train_loss=0.105296, test_loss=0.023689, best_loss=0.010885
# iteration=1891, train_loss=0.127187, test_loss=0.040501, best_loss=0.010885
# iteration=1892, train_loss=0.133597, test_loss=0.054471, best_loss=0.010885
# iteration=1893, train_loss=0.212991, test_loss=0.132212, best_loss=0.010885
# iteration=1894, train_loss=0.126586, test_loss=0.043076, best_loss=0.010885
# iteration=1895, train_loss=0.105264, test_loss=0.022552, best_loss=0.010885
# iteration=1896, train_loss=0.118792, test_loss=0.034826, best_loss=0.010885
# iteration=1897, train_loss=0.154860, test_loss=0.078766, best_loss=0.010885
# iteration=1898, train_loss=0.114934, test_loss=0.034300, best_loss=0.010885
# iteration=1899, train_loss=0.106252, test_loss=0.022462, best_loss=0.010885
# iteration=1900, train_loss=0.109445, test_loss=0.023724, best_loss=0.010885
# iteration=1901, train_loss=0.113452, test_loss=0.034515, best_loss=0.010885
# iteration=1902, train_loss=0.105119, test_loss=0.021913, best_loss=0.010885
# iteration=1903, train_loss=0.114249, test_loss=0.036670, best_loss=0.010885
# iteration=1904, train_loss=0.121126, test_loss=0.041142, best_loss=0.010885
# iteration=1905, train_loss=0.112041, test_loss=0.034167, best_loss=0.010885
# iteration=1906, train_loss=0.114205, test_loss=0.026585, best_loss=0.010885
# iteration=1907, train_loss=0.122974, test_loss=0.040661, best_loss=0.010885
# iteration=1908, train_loss=0.118131, test_loss=0.038389, best_loss=0.010885
# iteration=1909, train_loss=0.118044, test_loss=0.036502, best_loss=0.010885
# iteration=1910, train_loss=0.113257, test_loss=0.030424, best_loss=0.010885
# iteration=1911, train_loss=0.111216, test_loss=0.032799, best_loss=0.010885
# iteration=1912, train_loss=0.170663, test_loss=0.092506, best_loss=0.010885
# iteration=1913, train_loss=0.142613, test_loss=0.052838, best_loss=0.010885
# iteration=1914, train_loss=0.098881, test_loss=0.017862, best_loss=0.010885
# iteration=1915, train_loss=0.105798, test_loss=0.022444, best_loss=0.010885
# iteration=1916, train_loss=0.113833, test_loss=0.033587, best_loss=0.010885
# iteration=1917, train_loss=0.137619, test_loss=0.051981, best_loss=0.010885
# iteration=1918, train_loss=0.156210, test_loss=0.074202, best_loss=0.010885
# iteration=1919, train_loss=0.106280, test_loss=0.025920, best_loss=0.010885
# iteration=1920, train_loss=0.122938, test_loss=0.044306, best_loss=0.010885
# iteration=1921, train_loss=0.117746, test_loss=0.037878, best_loss=0.010885
# iteration=1922, train_loss=0.121848, test_loss=0.046537, best_loss=0.010885
# iteration=1923, train_loss=0.128359, test_loss=0.046232, best_loss=0.010885
# iteration=1924, train_loss=0.139577, test_loss=0.053608, best_loss=0.010885
# iteration=1925, train_loss=0.138320, test_loss=0.053154, best_loss=0.010885
# iteration=1926, train_loss=0.132013, test_loss=0.046849, best_loss=0.010885
# iteration=1927, train_loss=0.144342, test_loss=0.059335, best_loss=0.010885
# iteration=1928, train_loss=0.113418, test_loss=0.031604, best_loss=0.010885
# iteration=1929, train_loss=0.144093, test_loss=0.064075, best_loss=0.010885
# iteration=1930, train_loss=0.104919, test_loss=0.025731, best_loss=0.010885
# iteration=1931, train_loss=0.134547, test_loss=0.052289, best_loss=0.010885
# iteration=1932, train_loss=0.112891, test_loss=0.031990, best_loss=0.010885
# iteration=1933, train_loss=0.103428, test_loss=0.021575, best_loss=0.010885
# iteration=1934, train_loss=0.105740, test_loss=0.022432, best_loss=0.010885
# iteration=1935, train_loss=0.116496, test_loss=0.032611, best_loss=0.010885
# iteration=1936, train_loss=0.112086, test_loss=0.028208, best_loss=0.010885
# iteration=1937, train_loss=0.107213, test_loss=0.025919, best_loss=0.010885
# iteration=1938, train_loss=0.095674, test_loss=0.015613, best_loss=0.010885
# iteration=1939, train_loss=0.115220, test_loss=0.033024, best_loss=0.010885
# iteration=1940, train_loss=0.107958, test_loss=0.025093, best_loss=0.010885
# iteration=1941, train_loss=0.176658, test_loss=0.102136, best_loss=0.010885
# iteration=1942, train_loss=0.124352, test_loss=0.039118, best_loss=0.010885
# iteration=1943, train_loss=0.115486, test_loss=0.031022, best_loss=0.010885
# iteration=1944, train_loss=0.109973, test_loss=0.033211, best_loss=0.010885
# iteration=1945, train_loss=0.123332, test_loss=0.043851, best_loss=0.010885
# iteration=1946, train_loss=0.144236, test_loss=0.061877, best_loss=0.010885
# iteration=1947, train_loss=0.108365, test_loss=0.026573, best_loss=0.010885
# iteration=1948, train_loss=0.116486, test_loss=0.035430, best_loss=0.010885
# iteration=1949, train_loss=0.121512, test_loss=0.042988, best_loss=0.010885
# iteration=1950, train_loss=0.159164, test_loss=0.085685, best_loss=0.010885
# iteration=1951, train_loss=0.118788, test_loss=0.037715, best_loss=0.010885
# iteration=1952, train_loss=0.108996, test_loss=0.030135, best_loss=0.010885
# iteration=1953, train_loss=0.105617, test_loss=0.026437, best_loss=0.010885
# iteration=1954, train_loss=0.137113, test_loss=0.057711, best_loss=0.010885
# iteration=1955, train_loss=0.109860, test_loss=0.027672, best_loss=0.010885
# iteration=1956, train_loss=0.108809, test_loss=0.026140, best_loss=0.010885
# iteration=1957, train_loss=0.106948, test_loss=0.023221, best_loss=0.010885
# iteration=1958, train_loss=0.113100, test_loss=0.035444, best_loss=0.010885
# iteration=1959, train_loss=0.111865, test_loss=0.037106, best_loss=0.010885
# iteration=1960, train_loss=0.110089, test_loss=0.028516, best_loss=0.010885
# iteration=1961, train_loss=0.129519, test_loss=0.050918, best_loss=0.010885
# iteration=1962, train_loss=0.140040, test_loss=0.062278, best_loss=0.010885
# iteration=1963, train_loss=0.117256, test_loss=0.035143, best_loss=0.010885
# iteration=1964, train_loss=0.134263, test_loss=0.062992, best_loss=0.010885
# iteration=1965, train_loss=0.114770, test_loss=0.033761, best_loss=0.010885
# iteration=1966, train_loss=0.099313, test_loss=0.017966, best_loss=0.010885
# iteration=1967, train_loss=0.124939, test_loss=0.052217, best_loss=0.010885
# iteration=1968, train_loss=0.118891, test_loss=0.038707, best_loss=0.010885
# iteration=1969, train_loss=0.121697, test_loss=0.047975, best_loss=0.010885
# iteration=1970, train_loss=0.106763, test_loss=0.021823, best_loss=0.010885
# iteration=1971, train_loss=0.136167, test_loss=0.054313, best_loss=0.010885
# iteration=1972, train_loss=0.119470, test_loss=0.037194, best_loss=0.010885
# iteration=1973, train_loss=0.150300, test_loss=0.066673, best_loss=0.010885
# iteration=1974, train_loss=0.136278, test_loss=0.056730, best_loss=0.010885
# iteration=1975, train_loss=0.101195, test_loss=0.026088, best_loss=0.010885
# iteration=1976, train_loss=0.098193, test_loss=0.016048, best_loss=0.010885
# iteration=1977, train_loss=0.118368, test_loss=0.038985, best_loss=0.010885
# iteration=1978, train_loss=0.102763, test_loss=0.019579, best_loss=0.010885
# iteration=1979, train_loss=0.099170, test_loss=0.017438, best_loss=0.010885
# iteration=1980, train_loss=0.109264, test_loss=0.031965, best_loss=0.010885
# iteration=1981, train_loss=0.131840, test_loss=0.051438, best_loss=0.010885
# iteration=1982, train_loss=0.117220, test_loss=0.031627, best_loss=0.010885
# iteration=1983, train_loss=0.113578, test_loss=0.030960, best_loss=0.010885
# iteration=1984, train_loss=0.108102, test_loss=0.028840, best_loss=0.010885
# iteration=1985, train_loss=0.101184, test_loss=0.019178, best_loss=0.010885
# iteration=1986, train_loss=0.106769, test_loss=0.029699, best_loss=0.010885
# iteration=1987, train_loss=0.102713, test_loss=0.023285, best_loss=0.010885
# iteration=1988, train_loss=0.105773, test_loss=0.023662, best_loss=0.010885
# iteration=1989, train_loss=0.146252, test_loss=0.067771, best_loss=0.010885
# iteration=1990, train_loss=0.103778, test_loss=0.020407, best_loss=0.010885
# iteration=1991, train_loss=0.125324, test_loss=0.046961, best_loss=0.010885
# iteration=1992, train_loss=0.118789, test_loss=0.038202, best_loss=0.010885
# iteration=1993, train_loss=0.112726, test_loss=0.028456, best_loss=0.010885
# iteration=1994, train_loss=0.125407, test_loss=0.038272, best_loss=0.010885
# iteration=1995, train_loss=0.123409, test_loss=0.039069, best_loss=0.010885
# iteration=1996, train_loss=0.113985, test_loss=0.027489, best_loss=0.010885
# iteration=1997, train_loss=0.118266, test_loss=0.038436, best_loss=0.010885
# iteration=1998, train_loss=0.122071, test_loss=0.038834, best_loss=0.010885
# iteration=1999, train_loss=0.103077, test_loss=0.018441, best_loss=0.010885
# CPU times: user 9min 9s, sys: 6.51 s, total: 9min 16s
# Wall time: 9min 9s

# %%
#WIZUALIZACJA BŁĘDU MSE PODCZAS UCZENIA SIECI

plt.figure(figsize=(8, 3.5), dpi=120)
plt.plot(train_error[:], 'r', label='Train loss')
plt.plot(test_error[:], 'g', label='Test loss')
plt.yscale('log')
plt.title('Błąd średniokwadratowy podczas uczenia sieci')
plt.xlabel("Epoka") 
plt.ylabel("Błąd MSE")
plt.grid()
plt.legend() 
plt.show()

# %%
#WIZUALIZACJA ZMIAN WYBRANYCH WAG PODCZAS UCZENIA SIECI

plt.figure(figsize=(8, 3.5), dpi=120)
plt.plot(w1[:])
plt.plot(w2[:])
plt.plot(w3[:])
plt.plot(w4[:])
plt.title('Wartości pewnych wag podczas uczenia sieci')
plt.xlabel("Epoka") 
plt.ylabel("Wartość wagi")
plt.grid()
plt.show()

# %%
#TEST PREDYKCJI SIECI

#Obliczenie predykcji sieci (wartość wyjściowa) na podstawie zbioru testowego
y_pred = jax.vmap(partial(equation_of_motion, learned_lagrangian(params)))(x_test)

#Wizualizacji wyników
fig, axes = plt.subplots(1, 2, figsize=(6, 3), dpi=120)
fig.suptitle("Porównanie oczekiwanych wyników z wynikami predykcji")
axes[0].scatter(y_test[:, 0], y_pred[:, 0], s=6, alpha=0.2)
axes[0].set_xlabel('oczkiwane $\dot q$')
axes[0].set_ylabel('predykcja $\dot q$')
axes[0].grid()
axes[1].scatter(y_test[:, 1], y_pred[:, 1], s=6, alpha=0.2)
axes[1].set_xlabel('oczkiwane $\ddot q$')
axes[1].set_ylabel('predykcja $\ddot q$')
axes[1].grid()
plt.tight_layout()

# %%
#OBLICZENIE BŁĘDU WZGLĘDNEGO PREDYKCJI

#Zakresy prędkości i położenia
q=jnp.arange(-1*np.pi, np.pi, 0.2, dtype=jnp.float32)
q = np.concatenate([q, jnp.array([np.pi])])
q_t=jnp.arange(-1*v_max, v_max, 0.5, dtype=jnp.float32)
q_t = np.concatenate([q_t, jnp.array([v_max])])



True_value = np.zeros([len(q), len(q_t)],dtype=jnp.float32)
Pred_value = np.zeros([len(q), len(q_t)],dtype=jnp.float32)
Error = np.zeros([len(q), len(q_t)],dtype=jnp.float32)



for i in range (len(q)):
    for j in range(len(q_t)):
        True_value[i,j] = analitical(jnp.array([q[i], q_t[j]]))[1]                          #Wartość rzczywista
        Pred_value[i,j] = acceleration_learned(params, jnp.array([q[i], q_t[j]]))           #Predykcja
        Error[i,j] = np.abs(True_value[i,j]-Pred_value[i,j])/np.abs(True_value[i,j])*100    #Błąd (wartość bezwlędna z różnicy)

# %%
#WIZUALIZACJA WZGLĘDNEGO BŁĘDU PROCENTOWEGO PREDYKCJI

q, q_t = np.meshgrid(q, q_t)
Error = np.transpose(Error)

Error = np.where(Error>20, 20, Error)

#Wizualizacja
#%matplotlib qt5
fig = plt.figure()
axes = fig.add_subplot(projection='3d')

axes.set_title("Porównanie predykcji przyśpieszenia z wartością oczekiwaną")
axes.set_xlabel('q')
axes.set_ylabel('$\dot q$')
axes.set_zlabel("Błąd względny [%]")
axes.grid()

axes.plot_surface(q, q_t, Error, cmap='viridis')
plt.show()
plt.tight_layout()
# %matplotlib inline

# %%
q=jnp.arange(-1*np.pi, np.pi, 0.05, dtype=jnp.float32)
q_t=jnp.array([0,1,-2,3,-4,5], dtype=jnp.float32)


Lagrangian_true = np.zeros([len(q), len(q_t)],dtype=jnp.float32)
Lagrangian_pred = np.zeros([len(q), len(q_t)],dtype=jnp.float32)

for i in range (len(q)):
    for j in range(len(q_t)):
        Lagrangian_true[i,j] = jax.device_get(lagrangian_analitical(q[i], q_t[j], 1, 1, 9.8)).item()                #Wartość rzeczywista
        Lagrangian_pred[i,j] = jax.device_get(learned_lagrangian(params)(jnp.array([q[i]]), jnp.array([q_t[j]])))   #Predykcja




#WIZUALIZACJA
fig, axes = plt.subplots(3, 2, figsize=(20, 10), dpi=120)
for i, ax in enumerate(axes.flat):
    ax.plot(q, Lagrangian_true[:, i], 'g--', label='oczekiwane')
    ax.plot(q, Lagrangian_pred[:, i], 'r', label='LNN')
    ax.set_xlim(-1*np.pi, np.pi)
    ax.set_xlabel('q', fontsize=14)
    ax.set_ylabel('Lagrangian', fontsize=14)
    ax.set_title('$\dot q$='+str(q_t[i]), fontsize=18)
    ax.legend()
    ax.grid()
    
fig.suptitle('Porównanie oczekiwanych wartości lagrangianu z wynikami predykcji LNN', fontsize=28)


plt.tight_layout()


#Wizualizacji wyników
fig1, axes1 = plt.subplots(6, 2, figsize=(20, 15), dpi=120)

for i in range(len(q_t)):
    axes1[i,0].plot(q, Lagrangian_true[:, i],'g--')
    axes1[i,0].set_ylabel('Lagrangian', fontsize=14)
    axes1[i,0].set_xlabel('q', fontsize=14)
    axes1[i,0].set_title('Wartości oczekiwane przy $\dot q$='+str(q_t[i]), fontsize=14)
    axes1[i,0].grid()
    axes1[i,0].set_xlim(-1*np.pi, np.pi)
    axes1[i,1].plot(q, Lagrangian_pred[:, i],'r')
    axes1[i,1].set_ylabel('Lagrangian', fontsize=14)
    axes1[i,1].set_xlabel('q', fontsize=14)
    axes1[i,1].set_title('Wartości predykcji przy $\dot q$='+str(q_t[i]), fontsize=14)
    axes1[i,1].grid()
    axes1[i,1].set_xlim(-1*np.pi, np.pi)

fig1.suptitle('Porównanie oczekiwanych wartości lagrangianu z wynikami predykcji LNN', fontsize=28)
plt.tight_layout()


fig2, axes2 = plt.subplots(6, 1, figsize=(20, 15), dpi=120)


for i in range(len(q_t)):
    axes2[i].plot(q, Lagrangian_pred[:, i],'r')
    axes2[i].plot(q+2*np.pi, Lagrangian_pred[:, i],'r')
    axes2[i].set_ylabel('Lagrangian', fontsize=14)
    axes2[i].set_xlabel('q', fontsize=14)
    axes2[i].set_title('Wartości predykcji przy $\dot q$='+str(q_t[i]), fontsize=14)
    axes2[i].grid()
    axes2[i].set_xlim(-1*np.pi, 3*np.pi)

fig2.suptitle('Wykres modelowanego Lagrangianu dla zakresu $q\in(-\Pi, 3\Pi)$', fontsize=28)
plt.tight_layout()

# %%
#TEST WYZNACZENIA TRAJEKTORI RUCHU PRZY UŻYCIU SIECI NEURONOWEJ

#Punkt startowy
x0 = jnp.array([-3/2*np.pi/2,0], dtype=np.float32)
#Wektor czasu
t = np.linspace(0, 40, num=401, dtype=np.float32)

#Wyznaczenie trajektori przy użyciu sieci
# %time lagrangian_trajectory = jax.device_get(solve_lagrangian(params, x0, t))
lagrangian_trajectory = jax.device_get(jax.vmap(normalize)(lagrangian_trajectory))

#Wyznaczenie trajektori metodą analityczną
# %time analitical_trajectory = jax.device_get(solve_analitical(x0, t))


#WIZUALIZACJA
fig, axes = plt.subplots(1, 2, figsize=(10, 5), dpi=120)
fig.suptitle('Porównanie trajektorii ruchu otrzymanych przy użyciu metody analitycznej i LNN')


axes[0].plot(t, analitical_trajectory[:, 0], 'r', label='analityczne')
axes[0].plot(t, lagrangian_trajectory[:, 0], 'g--', label='LNN')
axes[0].set_xlabel('t')
axes[0].set_ylabel('$q$')
axes[0].legend()
axes[0].grid()
axes[0].axis([0,t[-1],-1*np.pi,np.pi])


axes[1].plot(t, analitical_trajectory[:, 1], 'r', label='analityczne')
axes[1].plot(t, lagrangian_trajectory[:, 1], 'g--', label='LNN')
axes[1].set_xlabel('t')
axes[1].set_ylabel('$\dot q$')
axes[1].grid()

plt.tight_layout()
# Out:
# CPU times: user 1.85 s, sys: 30.2 ms, total: 1.88 s
# Wall time: 1.87 s
# CPU times: user 1.05 ms, sys: 15 µs, total: 1.07 ms
# Wall time: 1.07 ms

# %%
#Wyznaczenie Energi potencjalnej i kinetycznej trajektorii

q, q_t = jnp.hsplit(lagrangian_trajectory, 2)
energy = partial(compute_energy, m=1, l=1, g=9.81)
Ep, Ek = jax.vmap(energy)(q, q_t)
Ec=Ep+Ek
mean = jnp.mean(Ec)
mean_Ec = jnp.ones(Ec.shape, dtype=jnp.float32) * jnp.mean(Ec)

plt.figure(figsize=(8, 3.5), dpi=120)
plt.plot(mean_Ec, 'r--', label="Średnia energia całkowita układu")
plt.plot(Ec, label="Energia całkowita układu")
plt.plot(Ep, label="Energia potencjalna układu")
plt.plot(Ek, label="Energia kinetyczna układu")
plt.title('Zmiany energii układu w czasie')
plt.xlabel("t [s]") 
plt.ylabel("Energia [J]")
plt.legend()
plt.grid()
plt.show()
