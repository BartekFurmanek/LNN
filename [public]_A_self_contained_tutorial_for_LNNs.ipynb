# %%
import jax
import jax.numpy as jnp
import numpy as np
from jax.experimental.ode import odeint
import matplotlib.pyplot as plt
from functools import partial # reduces arguments to function by making some subset implicit

from jax.example_libraries import stax
from jax.example_libraries import optimizers

# visualization
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
from moviepy.editor import ImageSequenceClip
from functools import partial
import proglog
from PIL import Image

# %%
def lagrangian(q, q_dot, m1, m2, l1, l2, g):
  t1, t2 = q     # theta 1 and theta 2
  w1, w2 = q_dot # omega 1 and omega 2

  # kinetic energy (T)
  T1 = 0.5 * m1 * (l1 * w1)**2
  T2 = 0.5 * m2 * ((l1 * w1)**2 + (l2 * w2)**2 +
                    2 * l1 * l2 * w1 * w2 * jnp.cos(t1 - t2))
  T = T1 + T2

  # potential energy (V)
  y1 = -l1 * jnp.cos(t1)
  y2 = y1 - l2 * jnp.cos(t2)
  V = m1 * g * y1 + m2 * g * y2

  return T - V

# %%
def f_analytical(state, t=0, m1=1, m2=1, l1=1, l2=1, g=9.8):
  t1, t2, w1, w2 = state
  a1 = (l2 / l1) * (m2 / (m1 + m2)) * jnp.cos(t1 - t2)
  a2 = (l1 / l2) * jnp.cos(t1 - t2)
  f1 = -(l2 / l1) * (m2 / (m1 + m2)) * (w2**2) * jnp.sin(t1 - t2) - \
      (g / l1) * jnp.sin(t1)
  f2 = (l1 / l2) * (w1**2) * jnp.sin(t1 - t2) - (g / l2) * jnp.sin(t2)
  g1 = (f1 - a1 * f2) / (1 - a1 * a2)
  g2 = (f2 - a2 * f1) / (1 - a1 * a2)
  return jnp.stack([w1, w2, g1, g2])

# %%
def equation_of_motion(lagrangian, state, t=None):
  q, q_t = jnp.split(state, 2)
  q_tt = (jnp.linalg.pinv(jax.hessian(lagrangian, 1)(q, q_t))
          @ (jax.grad(lagrangian, 0)(q, q_t)
             - jax.jacobian(jax.jacobian(lagrangian, 1), 0)(q, q_t) @ q_t))
  return jnp.concatenate([q_t, q_tt])

def solve_lagrangian(lagrangian, initial_state, **kwargs):
  # We currently run odeint on CPUs only, because its cost is dominated by
  # control flow, which is slow on GPUs.
  @partial(jax.jit, backend='cpu')
  def f(initial_state):
    return odeint(partial(equation_of_motion, lagrangian),
                  initial_state, **kwargs)
  return f(initial_state)

# %%
# Double pendulum dynamics via the rewritten Euler-Lagrange
@partial(jax.jit, backend='cpu')
def solve_autograd(initial_state, times, m1=1, m2=1, l1=1, l2=1, g=9.8):
  L = partial(lagrangian, m1=m1, m2=m2, l1=l1, l2=l2, g=g)
  return solve_lagrangian(L, initial_state, t=times, rtol=1e-10, atol=1e-10)

# Double pendulum dynamics via analytical forces taken from Diego's blog
@partial(jax.jit, backend='cpu')
def solve_analytical(initial_state, times):
  return odeint(f_analytical, initial_state, t=times, rtol=1e-10, atol=1e-10)

def normalize_dp(state):
  # wrap generalized coordinates to [-pi, pi]
  return jnp.concatenate([(state[:2] + np.pi) % (2 * np.pi) - np.pi, state[2:]])

def rk4_step(f, x, t, h):
  # one step of runge-kutta integration
  k1 = h * f(x, t)
  k2 = h * f(x + k1/2, t + h/2)
  k3 = h * f(x + k2/2, t + h/2)
  k4 = h * f(x + k3, t + h)
  return x + 1/6 * (k1 + 2 * k2 + 2 * k3 + k4)

# %%
# choose an initial state
x0 = np.array([3*np.pi/7, 3*np.pi/4, 0, 0], dtype=np.float32)
noise = np.random.RandomState(0).randn(x0.size)
t = np.linspace(0, 40, num=401, dtype=np.float32)

# %%
# compute dynamics analytically
# %time x_analytical = jax.device_get(solve_analytical(x0, t))
noise_coeff_1, noise_coeff_2 = 1e-10, 1e-11
x_perturbed_1 = jax.device_get(solve_analytical(x0 + noise_coeff_1 * noise, t))
x_perturbed_2 = jax.device_get(solve_analytical(x0 + noise_coeff_2 * noise, t))
# Out:
# CUDA backend failed to initialize: Unable to load CUDA. Is it installed? (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# CPU times: user 1.6 s, sys: 58.1 ms, total: 1.66 s
# Wall time: 1.64 s

# %%
# compute dynamics via autograd / the rewritten E-L equation
# %time x_autograd = jax.device_get(solve_autograd(x0, t))
# Out:
# CPU times: user 3.72 s, sys: 0 ns, total: 3.72 s
# Wall time: 3.68 s

# %% [markdown]
# ### Plot a comparison

# %%
plt.figure(figsize=[10,3], dpi=120) ; plt.xlim(0, 100)
plt.subplot(1,3,1)
plt.title("Analytic vs Perturbed ($\epsilon$={})".format(noise_coeff_1))
plt.xlabel("Time") ; plt.ylabel("State")
plt.plot(t, x_analytical[:, 0], 'g-', label='$q$')
plt.plot(t, x_analytical[:, 1], 'c-', label='$\dot q$')
plt.plot(t, x_perturbed_1[:, 0], 'g--', label='pert. $q$')
plt.plot(t, x_perturbed_1[:, 1], 'c--', label='pert. $\dot q$')
plt.legend(fontsize=6)

plt.subplot(1,3,2)
plt.title("Analytic vs Perturbed ($\epsilon$={})".format(noise_coeff_2))
plt.xlabel("Time") ; plt.ylabel("State")
plt.plot(t, x_analytical[:, 0], 'g-', label='$q$')
plt.plot(t, x_analytical[:, 1], 'c-', label='$\dot q$')
plt.plot(t, x_perturbed_2[:, 0], 'g--', label='pert. $q$')
plt.plot(t, x_perturbed_2[:, 1], 'c--', label='pert. $\dot q$')
plt.legend(fontsize=6)

plt.subplot(1,3,3)
plt.title("Analytic vs Autograd")
plt.xlabel("Time") ; plt.ylabel("State")
plt.plot(t, x_analytical[:, 0], 'g-', label='$q$')
plt.plot(t, x_analytical[:, 1], 'c-', label='$\dot q$')
plt.plot(t, x_autograd[:, 0], 'g--', label='autograd $q$')
plt.plot(t, x_autograd[:, 1], 'c--', label='autograd $\dot q$')
plt.legend(fontsize=6)

plt.tight_layout() ; plt.show()

# %% [markdown]
# ## **Step 5: Generate training data**
# Let's generate some training data by using the analytical method to sample double pendulum dynamics.

# %%
time_step = 0.01
N = 1500
analytical_step = jax.jit(jax.vmap(partial(rk4_step, f_analytical, t=0.0, h=time_step)))

# x0 = np.array([-0.3*np.pi, 0.2*np.pi, 0.35*np.pi, 0.5*np.pi], dtype=np.float32)
x0 = np.array([3*np.pi/7, 3*np.pi/4, 0, 0], dtype=np.float32)
t = np.arange(N, dtype=np.float32) # time steps 0 to N
# %time x_train = jax.device_get(solve_analytical(x0, t)) # dynamics for first N time steps
# %time xt_train = jax.device_get(jax.vmap(f_analytical)(x_train)) # time derivatives of each state
# %time y_train = jax.device_get(analytical_step(x_train)) # analytical next step

noise = np.random.RandomState(0).randn(x0.size)
t_test = np.arange(N, 2*N, dtype=np.float32) # time steps N to 2N
# %time x_test = jax.device_get(solve_analytical(x0, t_test)) # dynamics for next N time steps
# %time xt_test = jax.device_get(jax.vmap(f_analytical)(x_test)) # time derivatives of each state
# %time y_test = jax.device_get(analytical_step(x_test)) # analytical next step
# Out:
# CPU times: user 18.5 s, sys: 39.3 ms, total: 18.6 s
# Wall time: 18.5 s
# CPU times: user 678 ms, sys: 29.4 ms, total: 708 ms
# Wall time: 705 ms
# CPU times: user 440 ms, sys: 66 µs, total: 440 ms
# Wall time: 439 ms
# CPU times: user 24.6 s, sys: 10.1 ms, total: 24.6 s
# Wall time: 24.6 s
# CPU times: user 56.4 ms, sys: 163 µs, total: 56.6 ms
# Wall time: 56.5 ms
# CPU times: user 863 µs, sys: 0 ns, total: 863 µs
# Wall time: 876 µs

# %% [markdown]
# ### Visualize train and test data

# %%
# preprocess
train_vis = jax.vmap(normalize_dp)(x_train)
test_vis = jax.vmap(normalize_dp)(x_test)

vel_angle = lambda data:  (np.arctan2(data[:,3], data[:,2]) / np.pi + 1)/2
vel_color = lambda vangle: np.stack( [np.zeros_like(vangle), vangle, 1-vangle]).T
train_colors = vel_color(vel_angle(train_vis))
test_colors = vel_color(vel_angle(test_vis))

# plot
SCALE = 80 ; WIDTH = 0.006
plt.figure(figsize=[8,4], dpi=120)
plt.subplot(1,2,1)
plt.title("Train data") ; plt.xlabel(r'$\theta_1$') ; plt.ylabel(r'$\theta_2$')
plt.quiver(*train_vis.T, color=train_colors, scale=SCALE, width=WIDTH)

plt.subplot(1,2,2)
plt.title("Test data") ; plt.xlabel(r'$\theta_1$') ; plt.ylabel(r'$\theta_2$')
plt.quiver(*test_vis.T, color=test_colors, scale=SCALE, width=WIDTH)

plt.tight_layout() ; plt.show()

# %% [markdown]
# ## **Step 6: Build a Lagrangian Neural Network**
# This section presents a bare-bones approach to approximating the Lagrangian with a neural network
#
# ### i) Build model and define the loss

# %%
# replace the lagrangian with a parameteric model
def learned_lagrangian(params):
  def lagrangian(q, q_t):
    assert q.shape == (2,)
    state = normalize_dp(jnp.concatenate([q, q_t]))
    return jnp.squeeze(nn_forward_fn(params, state), axis=-1)
  return lagrangian

# define the loss of the model (MSE between predicted q, \dot q and targets)
@jax.jit
def loss(params, batch, time_step=None):
  state, targets = batch
  if time_step is not None:
    f = partial(equation_of_motion, learned_lagrangian(params))
    preds = jax.vmap(partial(rk4_step, f, t=0.0, h=time_step))(state)
  else:
    preds = jax.vmap(partial(equation_of_motion, learned_lagrangian(params)))(state)
  return jnp.mean((preds - targets) ** 2)

# build a neural network model
init_random_params, nn_forward_fn = stax.serial(
    stax.Dense(128),
    stax.Softplus,
    stax.Dense(128),
    stax.Softplus,
    stax.Dense(1),
)

# %% [markdown]
# ### ii) Define optimization and data

# %%
@jax.jit
def update_timestep(i, opt_state, batch):
  params = get_params(opt_state)
  return opt_update(i, jax.grad(loss)(params, batch, time_step), opt_state)

@jax.jit
def update_derivative(i, opt_state, batch):
  params = get_params(opt_state)
  return opt_update(i, jax.grad(loss)(params, batch, None), opt_state)

x_train = jax.device_put(jax.vmap(normalize_dp)(x_train))
y_train = jax.device_put(y_train)

x_test = jax.device_put(jax.vmap(normalize_dp)(x_test))
y_test = jax.device_put(y_test)

# %% [markdown]
# ### iii) Train the model

# %%
# %%time

rng = jax.random.PRNGKey(0)
_, init_params = init_random_params(rng, (-1, 4))

# numbers in comments denote stephan's settings
batch_size = 100
test_every = 10
num_batches = 1500

train_losses = []
test_losses = []

# adam w learn rate decay
opt_init, opt_update, get_params = optimizers.adam(
    lambda t: jnp.select([t < batch_size*(num_batches//3),
                          t < batch_size*(2*num_batches//3),
                          t > batch_size*(2*num_batches//3)],
                         [1e-3, 3e-4, 1e-4]))
opt_state = opt_init(init_params)

for iteration in range(batch_size*num_batches + 1):
  if iteration % batch_size == 0:
    params = get_params(opt_state)
    train_loss = loss(params, (x_train, xt_train))
    train_losses.append(train_loss)
    test_loss = loss(params, (x_test, xt_test))
    test_losses.append(test_loss)
    if iteration % (batch_size*test_every) == 0:
      print(f"iteration={iteration}, train_loss={train_loss:.6f}, test_loss={test_loss:.6f}")
  opt_state = update_derivative(iteration, opt_state, (x_train, xt_train))

params = get_params(opt_state)
# Out:
# iteration=0, train_loss=1011.814331, test_loss=707.076233
# iteration=1000, train_loss=192.191330, test_loss=179.092743
# iteration=2000, train_loss=192.190704, test_loss=179.092041
# iteration=3000, train_loss=192.189331, test_loss=179.090378
# iteration=4000, train_loss=192.186035, test_loss=179.086533
# iteration=5000, train_loss=192.180084, test_loss=179.079498
# iteration=6000, train_loss=192.169159, test_loss=179.066742
# iteration=7000, train_loss=192.149857, test_loss=179.044159
# iteration=8000, train_loss=192.117157, test_loss=179.005951
# iteration=9000, train_loss=192.062332, test_loss=178.941879
# iteration=10000, train_loss=191.971085, test_loss=178.835449
# iteration=11000, train_loss=191.823074, test_loss=178.662994
# iteration=12000, train_loss=191.587143, test_loss=178.389084
# iteration=13000, train_loss=191.220871, test_loss=177.966629
# iteration=14000, train_loss=190.669647, test_loss=177.338455
# iteration=15000, train_loss=189.865463, test_loss=176.441116
# iteration=16000, train_loss=188.717880, test_loss=175.200623
# iteration=17000, train_loss=187.097580, test_loss=173.513641
# iteration=18000, train_loss=184.807144, test_loss=171.202591
# iteration=19000, train_loss=181.427460, test_loss=167.857513
# iteration=20000, train_loss=175.327682, test_loss=161.893265
# iteration=21000, train_loss=153.444977, test_loss=140.104858
# iteration=22000, train_loss=119.686417, test_loss=104.958633
# iteration=23000, train_loss=80.475357, test_loss=71.585548
# iteration=24000, train_loss=25.499365, test_loss=25.262234
# iteration=25000, train_loss=14.817080, test_loss=14.838008
# iteration=26000, train_loss=10.681768, test_loss=10.936252
# iteration=27000, train_loss=7.856449, test_loss=8.030112
# iteration=28000, train_loss=5.340951, test_loss=5.556948
# iteration=29000, train_loss=3.589240, test_loss=3.688261
# iteration=30000, train_loss=2.362746, test_loss=2.447283
# iteration=31000, train_loss=1.956831, test_loss=2.045826
# iteration=32000, train_loss=1.871213, test_loss=1.929342
# iteration=33000, train_loss=1.580346, test_loss=1.596794
# iteration=34000, train_loss=2.412825, test_loss=2.401058
# iteration=35000, train_loss=1.096738, test_loss=1.164325
# iteration=36000, train_loss=1.068461, test_loss=1.167516
# iteration=37000, train_loss=1.347616, test_loss=1.322912
# iteration=38000, train_loss=0.703911, test_loss=0.773619
# iteration=39000, train_loss=0.639585, test_loss=0.718574
# iteration=40000, train_loss=1.035201, test_loss=1.015316
# iteration=41000, train_loss=1.008395, test_loss=0.940181
# iteration=42000, train_loss=0.451526, test_loss=0.497103
# iteration=43000, train_loss=0.372167, test_loss=0.420462
# iteration=44000, train_loss=0.277915, test_loss=0.342406
# iteration=45000, train_loss=0.303090, test_loss=0.352691
# iteration=46000, train_loss=0.296434, test_loss=0.339092
# iteration=47000, train_loss=0.284601, test_loss=0.331590
# iteration=48000, train_loss=0.191158, test_loss=0.246930
# iteration=49000, train_loss=0.257471, test_loss=0.310993
# iteration=50000, train_loss=0.233970, test_loss=0.268649
# iteration=51000, train_loss=0.124467, test_loss=0.175280
# iteration=52000, train_loss=0.109644, test_loss=0.154408
# iteration=53000, train_loss=0.106794, test_loss=0.145030
# iteration=54000, train_loss=0.085608, test_loss=0.123104
# iteration=55000, train_loss=0.126112, test_loss=0.157678
# iteration=56000, train_loss=0.072322, test_loss=0.104549
# iteration=57000, train_loss=0.077062, test_loss=0.105689
# iteration=58000, train_loss=0.061651, test_loss=0.090357
# iteration=59000, train_loss=0.096619, test_loss=0.121360
# iteration=60000, train_loss=0.090710, test_loss=0.106855
# iteration=61000, train_loss=0.068548, test_loss=0.089295
# iteration=62000, train_loss=0.110503, test_loss=0.128183
# iteration=63000, train_loss=0.046608, test_loss=0.070036
# iteration=64000, train_loss=0.075769, test_loss=0.095603
# iteration=65000, train_loss=0.043128, test_loss=0.065249
# iteration=66000, train_loss=0.043186, test_loss=0.063533
# iteration=67000, train_loss=0.047083, test_loss=0.067533
# iteration=68000, train_loss=0.041852, test_loss=0.061105
# iteration=69000, train_loss=0.059480, test_loss=0.075813
# iteration=70000, train_loss=0.115104, test_loss=0.111513
# iteration=71000, train_loss=0.041395, test_loss=0.059173
# iteration=72000, train_loss=0.033520, test_loss=0.051462
# iteration=73000, train_loss=0.032956, test_loss=0.050165
# iteration=74000, train_loss=0.108146, test_loss=0.109766
# iteration=75000, train_loss=0.033708, test_loss=0.049993
# iteration=76000, train_loss=0.035928, test_loss=0.051398
# iteration=77000, train_loss=0.034707, test_loss=0.050985
# iteration=78000, train_loss=0.035927, test_loss=0.050281
# iteration=79000, train_loss=0.163702, test_loss=0.148946
# iteration=80000, train_loss=0.029060, test_loss=0.044112
# iteration=81000, train_loss=0.029838, test_loss=0.046320
# iteration=82000, train_loss=0.029711, test_loss=0.043326
# iteration=83000, train_loss=0.060143, test_loss=0.068626
# iteration=84000, train_loss=0.040933, test_loss=0.051453
# iteration=85000, train_loss=0.026406, test_loss=0.039973
# iteration=86000, train_loss=0.045321, test_loss=0.055481
# iteration=87000, train_loss=0.026394, test_loss=0.041393
# iteration=88000, train_loss=0.073285, test_loss=0.076518
# iteration=89000, train_loss=0.029509, test_loss=0.041361
# iteration=90000, train_loss=0.045776, test_loss=0.054895
# iteration=91000, train_loss=0.022478, test_loss=0.035303
# iteration=92000, train_loss=0.105626, test_loss=0.098223
# iteration=93000, train_loss=0.030669, test_loss=0.041161
# iteration=94000, train_loss=0.027511, test_loss=0.038661
# iteration=95000, train_loss=0.020974, test_loss=0.033011
# iteration=96000, train_loss=0.044865, test_loss=0.055080
# iteration=97000, train_loss=0.022019, test_loss=0.033573
# iteration=98000, train_loss=0.150216, test_loss=0.133562
# iteration=99000, train_loss=0.019785, test_loss=0.031176
# iteration=100000, train_loss=0.020761, test_loss=0.031767
# iteration=101000, train_loss=0.018782, test_loss=0.029810
# iteration=102000, train_loss=0.018117, test_loss=0.028627
# iteration=103000, train_loss=0.017479, test_loss=0.027519
# iteration=104000, train_loss=0.016926, test_loss=0.026586
# iteration=105000, train_loss=0.016598, test_loss=0.025921
# iteration=106000, train_loss=0.055641, test_loss=0.056362
# iteration=107000, train_loss=0.015575, test_loss=0.024327
# iteration=108000, train_loss=0.016355, test_loss=0.024829
# iteration=109000, train_loss=0.014821, test_loss=0.023099
# iteration=110000, train_loss=0.014488, test_loss=0.022554
# iteration=111000, train_loss=0.015964, test_loss=0.023738
# iteration=112000, train_loss=0.013874, test_loss=0.021558
# iteration=113000, train_loss=0.013593, test_loss=0.021103
# iteration=114000, train_loss=0.013697, test_loss=0.020943
# iteration=115000, train_loss=0.018816, test_loss=0.026025
# iteration=116000, train_loss=0.018447, test_loss=0.024953
# iteration=117000, train_loss=0.012751, test_loss=0.019682
# iteration=118000, train_loss=0.012376, test_loss=0.019174
# iteration=119000, train_loss=0.012214, test_loss=0.018883
# iteration=120000, train_loss=0.011961, test_loss=0.018516
# iteration=121000, train_loss=0.011769, test_loss=0.018221
# iteration=122000, train_loss=0.011685, test_loss=0.018013
# iteration=123000, train_loss=0.012520, test_loss=0.018458
# iteration=124000, train_loss=0.012591, test_loss=0.018522
# iteration=125000, train_loss=0.011073, test_loss=0.017121
# iteration=126000, train_loss=0.010979, test_loss=0.017100
# iteration=127000, train_loss=0.010757, test_loss=0.016707
# iteration=128000, train_loss=0.011551, test_loss=0.017309
# iteration=129000, train_loss=0.010451, test_loss=0.016203
# iteration=130000, train_loss=0.011459, test_loss=0.016838
# iteration=131000, train_loss=0.013094, test_loss=0.018244
# iteration=132000, train_loss=0.010051, test_loss=0.015572
# iteration=133000, train_loss=0.054342, test_loss=0.050585
# iteration=134000, train_loss=0.009818, test_loss=0.015241
# iteration=135000, train_loss=0.009684, test_loss=0.015047
# iteration=136000, train_loss=0.009561, test_loss=0.014870
# iteration=137000, train_loss=0.009465, test_loss=0.014741
# iteration=138000, train_loss=0.010672, test_loss=0.015599
# iteration=139000, train_loss=0.045156, test_loss=0.042844
# iteration=140000, train_loss=0.015348, test_loss=0.019616
# iteration=141000, train_loss=0.015941, test_loss=0.019072
# iteration=142000, train_loss=0.047243, test_loss=0.044464
# iteration=143000, train_loss=0.010006, test_loss=0.014748
# iteration=144000, train_loss=0.008796, test_loss=0.013683
# iteration=145000, train_loss=0.008891, test_loss=0.013794
# iteration=146000, train_loss=0.008565, test_loss=0.013399
# iteration=147000, train_loss=0.020875, test_loss=0.023258
# iteration=148000, train_loss=0.008417, test_loss=0.013185
# iteration=149000, train_loss=0.008319, test_loss=0.013024
# iteration=150000, train_loss=0.022944, test_loss=0.027123
# CPU times: user 11h 57min 30s, sys: 2h 33min 17s, total: 14h 30min 48s
# Wall time: 8h 35min 48s

# %% [markdown]
# ### iv) Plot losses over training

# %%
plt.figure(figsize=(8, 3.5), dpi=120)
plt.plot(train_losses, label='Train loss')
plt.plot(test_losses, label='Test loss')
plt.yscale('log')
plt.ylim(None, 200)
plt.title('Losses over training')
plt.xlabel("Train step") ; plt.ylabel("Mean squared error")
plt.legend() ; plt.show()

# %% [markdown]
# ## **Step 7: Visualize what the model has learned**
# In this section we'll run some basic sanity checks to see whether the model has learned something that resembles the Lagrangian of the system
#
# ### i) Plot predicted vs actual coordinates (we want a 1:1 mapping)

# %%
xt_pred = jax.vmap(partial(equation_of_motion, learned_lagrangian(params)))(x_test)

fig, axes = plt.subplots(1, 2, figsize=(6, 3), dpi=120)
axes[0].scatter(xt_test[:, 2], xt_pred[:, 2], s=6, alpha=0.2)
axes[0].set_title('Predicting $\dot q$')
axes[0].set_xlabel('$\dot q$ actual')
axes[0].set_ylabel('$\dot q$ predicted')
axes[1].scatter(xt_test[:, 3], xt_pred[:, 3], s=6, alpha=0.2)
axes[1].set_title('Predicting $\ddot q$')
axes[1].set_xlabel('$\ddot q$ actual')
axes[1].set_ylabel('$\ddot q$ predicted')
plt.tight_layout()

# %% [markdown]
# ### ii) Examine the model's performance over the full coordinate space

# %%
# make a meshgrid of possible angles
angle_range = -np.pi + 2 * np.pi * np.arange(100)/100
x_scanned = np.stack(np.meshgrid(angle_range, angle_range, [0.0], [0.0], indexing='ij'), axis=-1).reshape(-1, 4)

# %%
# %time xt_actual = jax.vmap(f_analytical)(x_scanned) # actual time derivatives
# Out:
# CPU times: user 381 ms, sys: 1.72 ms, total: 382 ms
# Wall time: 375 ms

# %%
# %time xt_predicted = jax.vmap(partial(equation_of_motion, learned_lagrangian(params)))(x_scanned) # predicted time derivatives
# Out:
# CPU times: user 3.28 s, sys: 941 ms, total: 4.22 s
# Wall time: 3.44 s

# %%
import xarray
dataarray = xarray.DataArray(np.stack([xt_actual.reshape(100, 100, 4),
                                       xt_predicted.reshape(100, 100, 4)]),
                             dims=['model', 'theta1', 'theta2', 'time_derivative'],
                             coords={'model': ['actual', 'predicted'], 'theta1': angle_range, 'theta2': angle_range})

# %%
dataarray.isel(time_derivative=2).plot.contourf(levels=31, col='model', x='theta1', y='theta2', vmin=-10, vmax=10)
print("Colorscale is \dot theta1")
plt.show()
# Out:
# Colorscale is \dot theta1

# %%
dataarray.isel(time_derivative=3).plot.contourf(levels=31, col='model', x='theta1', y='theta2', vmin=-10, vmax=10)
print("Colorscale is \dot theta2")
plt.show()
# Out:
# Colorscale is \dot theta2

# %% [markdown]
# ## **Step 8: Make predictions with the model**
# We should be able to simulate the double pendulum with reasonable degree of accuracy.

# %%
# choose an initial state
x1 = np.array([3*np.pi/7, 3*np.pi/4, 0, 0], dtype=np.float32)

t2 = np.linspace(0, 20, num=301)
# %time x1_analytical = jax.device_get(solve_analytical(x1, t2))
noise_coeff_3 = 1e-3
# %time x1_perturbed = jax.device_get(solve_analytical(x1 + noise_coeff_3 * noise, t2))
# %time x1_model = jax.device_get(solve_lagrangian(learned_lagrangian(params), x1, t=t2))
# Out:
# CPU times: user 473 ms, sys: 1.22 ms, total: 474 ms
# Wall time: 459 ms
# CPU times: user 13.5 ms, sys: 739 µs, total: 14.3 ms
# Wall time: 14.1 ms
# CPU times: user 1.68 s, sys: 44.7 ms, total: 1.73 s
# Wall time: 1.69 s

# %%
plt.figure(figsize=[6,6], dpi=120) ; plt.xlim(0, 20)
plt.subplot(2,1,1)
plt.title("Analytic vs Perturbed ($\epsilon$={})".format(noise_coeff_3))
plt.xlabel("Time") ; plt.ylabel("State")
plt.plot(t2, x1_analytical[:, 2], 'g-', label=r'$\theta_1$ exact')
plt.plot(t2, x1_analytical[:, 3], 'c-', label=r'$\theta_2$ exact')
plt.plot(t2, x1_perturbed[:, 2], 'g--', label=r'$\theta_1$ perturbed')
plt.plot(t2, x1_perturbed[:, 3], 'c--', label=r'$\theta_2$ perturbed')
plt.legend(fontsize=6)

plt.subplot(2,1,2)
plt.title("Analytic vs LNN")
plt.xlabel("Time") ; plt.ylabel("State")
plt.plot(t2, x1_analytical[:, 2], 'g-', label=r'$\theta_1$ exact')
plt.plot(t2, x1_analytical[:, 3], 'c-', label=r'$\theta_2$ exact')
plt.plot(t2, x1_model[:, 2], 'g--', label=r'$\theta_1$ LNN')
plt.plot(t2, x1_model[:, 3], 'c--', label=r'$\theta_2$ LNN')
plt.legend(fontsize=6)

plt.tight_layout() ; plt.show()

# %% [markdown]
# ## **Step 9: Make videos of the system**
#
# We'll use these to get an intuitive sense of how well our model has learned the dynamics
#
# ### i) First, we need to define functions for plotting the pendulum
# Sam used [this scipy tutorial](https://scipython.com/blog/the-double-pendulum/) and Stephan Hoyer's [wave equation demo for Jax on TPU](https://colab.research.google.com/github/google/jax/blob/master/cloud_tpu_colabs/Wave_Equation.ipynb) to write the following code.

# %%
def make_plot(i, cart_coords, l1, l2, max_trail=30, trail_segments=20, r = 0.05):
    # Plot and save an image of the double pendulum configuration for time step i.
    plt.cla()

    x1, y1, x2, y2 = cart_coords
    ax.plot([0, x1[i], x2[i]], [0, y1[i], y2[i]], lw=2, c='k') # rods
    c0 = Circle((0, 0), r/2, fc='k', zorder=10) # anchor point
    c1 = Circle((x1[i], y1[i]), r, fc='b', ec='b', zorder=10) # mass 1
    c2 = Circle((x2[i], y2[i]), r, fc='r', ec='r', zorder=10) # mass 2
    ax.add_patch(c0)
    ax.add_patch(c1)
    ax.add_patch(c2)

    # plot the pendulum trail (ns = number of segments)
    s = max_trail // trail_segments
    for j in range(trail_segments):
        imin = i - (trail_segments-j)*s
        if imin < 0: continue
        imax = imin + s + 1
        alpha = (j/trail_segments)**2 # fade the trail into alpha
        ax.plot(x2[imin:imax], y2[imin:imax], c='r', solid_capstyle='butt',
                lw=2, alpha=alpha)

    # Center the image on the fixed anchor point. Make axes equal.
    ax.set_xlim(-l1-l2-r, l1+l2+r)
    ax.set_ylim(-l1-l2-r, l1+l2+r)
    ax.set_aspect('equal', adjustable='box')
    plt.axis('off')
    # plt.savefig('./frames/_img{:04d}.png'.format(i//di), dpi=72)

def radial2cartesian(t1, t2, l1, l2):
  # Convert from radial to Cartesian coordinates.
  x1 = l1 * np.sin(t1)
  y1 = -l1 * np.cos(t1)
  x2 = x1 + l2 * np.sin(t2)
  y2 = y1 - l2 * np.cos(t2)
  return x1, y1, x2, y2

def fig2image(fig):
  fig.canvas.draw()
  data = np.fromstring(fig.canvas.tostring_rgb(), dtype=np.uint8, sep='')
  image = data.reshape(fig.canvas.get_width_height()[::-1] + (3,))
  return image

# %% [markdown]
# ### ii) Next, we'll make a movie of the pendulum's analytic dynamics

# %%
L1, L2 = 1, 1
theta1, theta2 = x1_analytical[:, 0], x1_analytical[:, 1]
cart_coords = radial2cartesian(theta1, theta2, L1, L2)

fig = plt.figure(figsize=(8.3333, 6.25), dpi=72)
ax = fig.add_subplot(111)

import warnings
warnings.filterwarnings("ignore")

images = []
di = 1
N = 300
for i in range(0, N, di):
  print("{}/{}".format(i // di, N // di), end='\n' if i//di%20==0 else ' ')
  make_plot(i, cart_coords, L1, L2)
  images.append( fig2image(fig) )
# Out:
# 0/300
# 1/300 2/300 3/300 4/300 5/300 6/300 7/300 8/300 9/300 10/300 11/300 12/300 13/300 14/300 15/300 16/300 17/300 18/300 19/300 20/300
# 21/300 22/300 23/300 24/300 25/300 26/300 27/300 28/300 29/300 30/300 31/300 32/300 33/300 34/300 35/300 36/300 37/300 38/300 39/300 40/300
# 41/300 42/300 43/300 44/300 45/300 46/300 47/300 48/300 49/300 50/300 51/300 52/300 53/300 54/300 55/300 56/300 57/300 58/300 59/300 60/300
# 61/300 62/300 63/300 64/300 65/300 66/300 67/300 68/300 69/300 70/300 71/300 72/300 73/300 74/300 75/300 76/300 77/300 78/300 79/300 80/300
# 81/300 82/300 83/300 84/300 85/300 86/300 87/300 88/300 89/300 90/300 91/300 92/300 93/300 94/300 95/300 96/300 97/300 98/300 99/300 100/300
# 101/300 102/300 103/300 104/300 105/300 106/300 107/300 108/300 109/300 110/300 111/300 112/300 113/300 114/300 115/300 116/300 117/300 118/300 119/300 120/300
# 121/300 122/300 123/300 124/300 125/300 126/300 127/300 128/300 129/300 130/300 131/300 132/300 133/300 134/300 135/300 136/300 137/300 138/300 139/300 140/300
# 141/300 142/300 143/300 144/300 145/300 146/300 147/300 148/300 149/300 150/300 151/300 152/300 153/300 154/300 155/300 156/300 157/300 158/300 159/300 160/300
# 161/300 162/300 163/300 164/300 165/300 166/300 167/300 168/300 169/300 170/300 171/300 172/300 173/300 174/300 175/300 176/300 177/300 178/300 179/300 180/300
# 181/300 182/300 183/300 184/300 185/300 186/300 187/300 188/300 189/300 190/300 191/300 192/300 193/300 194/300 195/300 196/300 197/300 198/300 199/300 200/300
# 201/300 202/300 203/300 204/300 205/300 206/300 207/300 208/300 209/300 210/300 211/300 212/300 213/300 214/300 215/300 216/300 217/300 218/300 219/300 220/300
# 221/300 222/300 223/300 224/300 225/300 226/300 227/300 228/300 229/300 230/300 231/300 232/300 233/300 234/300 235/300 236/300 237/300 238/300 239/300 240/300
# 241/300 242/300 243/300 244/300 245/300 246/300 247/300 248/300 249/300 250/300 251/300 252/300 253/300 254/300 255/300 256/300 257/300 258/300 259/300 260/300
# 261/300 262/300 263/300 264/300 265/300 266/300 267/300 268/300 269/300 270/300 271/300 272/300 273/300 274/300 275/300 276/300 277/300 278/300 279/300 280/300
# 281/300 282/300 283/300 284/300 285/300 286/300 287/300 288/300 289/300 290/300 291/300 292/300 293/300 294/300 295/300 296/300 297/300 298/300 299/300

# %%
import importlib
importlib.reload(proglog)
print("True (analytical) dynamics of the double pendulum:")
proglog.default_bar_logger = partial(proglog.default_bar_logger, None)
ImageSequenceClip(images, fps=25).ipython_display()
# Out:
# True (analytical) dynamics of the double pendulum:
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %% [markdown]
# ### ii) Now let's visualize the LNN's dynamics

# %%
L1, L2 = 1, 1
theta1, theta2 = x1_model[:, 0], x1_model[:, 1]
cart_coords = radial2cartesian(theta1, theta2, L1, L2)

fig = plt.figure(figsize=(8.3333, 6.25), dpi=72)
ax = fig.add_subplot(111)

images = []
di = 1
N = 300
for i in range(0, N, di):
  print("{}/{}".format(i // di, N // di), end='\n' if i//di%20==0 else ' ')
  make_plot(i, cart_coords, L1, L2)
  images.append( fig2image(fig) )
# Out:
# 0/300
# 1/300 2/300 3/300 4/300 5/300 6/300 7/300 8/300 9/300 10/300 11/300 12/300 13/300 14/300 15/300 16/300 17/300 18/300 19/300 20/300
# 21/300 22/300 23/300 24/300 25/300 26/300 27/300 28/300 29/300 30/300 31/300 32/300 33/300 34/300 35/300 36/300 37/300 38/300 39/300 40/300
# 41/300 42/300 43/300 44/300 45/300 46/300 47/300 48/300 49/300 50/300 51/300 52/300 53/300 54/300 55/300 56/300 57/300 58/300 59/300 60/300
# 61/300 62/300 63/300 64/300 65/300 66/300 67/300 68/300 69/300 70/300 71/300 72/300 73/300 74/300 75/300 76/300 77/300 78/300 79/300 80/300
# 81/300 82/300 83/300 84/300 85/300 86/300 87/300 88/300 89/300 90/300 91/300 92/300 93/300 94/300 95/300 96/300 97/300 98/300 99/300 100/300
# 101/300 102/300 103/300 104/300 105/300 106/300 107/300 108/300 109/300 110/300 111/300 112/300 113/300 114/300 115/300 116/300 117/300 118/300 119/300 120/300
# 121/300 122/300 123/300 124/300 125/300 126/300 127/300 128/300 129/300 130/300 131/300 132/300 133/300 134/300 135/300 136/300 137/300 138/300 139/300 140/300
# 141/300 142/300 143/300 144/300 145/300 146/300 147/300 148/300 149/300 150/300 151/300 152/300 153/300 154/300 155/300 156/300 157/300 158/300 159/300 160/300
# 161/300 162/300 163/300 164/300 165/300 166/300 167/300 168/300 169/300 170/300 171/300 172/300 173/300 174/300 175/300 176/300 177/300 178/300 179/300 180/300
# 181/300 182/300 183/300 184/300 185/300 186/300 187/300 188/300 189/300 190/300 191/300 192/300 193/300 194/300 195/300 196/300 197/300 198/300 199/300 200/300
# 201/300 202/300 203/300 204/300 205/300 206/300 207/300 208/300 209/300 210/300 211/300 212/300 213/300 214/300 215/300 216/300 217/300 218/300 219/300 220/300
# 221/300 222/300 223/300 224/300 225/300 226/300 227/300 228/300 229/300 230/300 231/300 232/300 233/300 234/300 235/300 236/300 237/300 238/300 239/300 240/300
# 241/300 242/300 243/300 244/300 245/300 246/300 247/300 248/300 249/300 250/300 251/300 252/300 253/300 254/300 255/300 256/300 257/300 258/300 259/300 260/300
# 261/300 262/300 263/300 264/300 265/300 266/300 267/300 268/300 269/300 270/300 271/300 272/300 273/300 274/300 275/300 276/300 277/300 278/300 279/300 280/300
# 281/300 282/300 283/300 284/300 285/300 286/300 287/300 288/300 289/300 290/300 291/300 292/300 293/300 294/300 295/300 296/300 297/300 298/300 299/300

# %%
import importlib
importlib.reload(proglog)
print("LNN-predicted dynamics of the double pendulum:")
proglog.default_bar_logger = partial(proglog.default_bar_logger, None)
ImageSequenceClip(images, fps=25).ipython_display()
# Out:
# LNN-predicted dynamics of the double pendulum:
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
def save_movie(images, path, duration=100, loop=0, **kwargs):
  images[0].save(path, save_all=True, append_images=images[1:],
                 duration=duration, loop=loop, **kwargs)

# Save GIF.
PIL_images = [Image.fromarray(im, mode='RGB') for im in images]
save_movie(PIL_images, 'double_pend_lnn.gif')
# The movie sometimes takes a second before showing up in the file system.
import time; time.sleep(1)

# Download animation.
from google.colab import files
files.download('double_pend_lnn.gif')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 12
#       9 import time; time.sleep(1)
#      11 # Download animation.
# ---> 12 from google.colab import files
#      13 files.download('double_pend_lnn.gif')
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# ## **Step 10: Conclusions**
# We just learned a double pendulum Lagrangian from data! Correction: we learned the double pendulum Lagrangian for a specific case where both arm lengths and both bob masses were 1. Furthermore, all of our train and test data was sampled from a single energy level of the double pendulum. But this is a good first step. These results are exciting because they are better than what an HNN or even a baseline neural ODE could achieve (we also made these comparisons in separate notebooks).
#
# For the purposes of our paper, we learned a model across different energy levels and added better network initializations, training techniques, and more. We also learned the Lagrangians of other physical systems including a 1D wave equation and a particle in a relativistic field. In theory, this approach should generalize well to other systems and to non-canonical coordinate systems such as the latent vector of a VAE.
#
# $\quad$
#
# Thanks for checking out our LNN tutorial, and please contact us with any questions.
